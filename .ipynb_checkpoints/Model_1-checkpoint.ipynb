# %% [markdown]
# ### Notes
#
# T5 Paper: https://arxiv.org/pdf/1910.10683.pdf
#
# T5 Tokenizer: https://github.com/huggingface/transformers/blob/master/src/transformers/tokenization_t5.py
#
# Important Tasks: https://docs.google.com/document/d/1weIZM6QTlnitpPQmpg-WeV2RW70TnYmDuogBQPr5mB0/edit

# %%
#James Chartouni
#Joey Park
#Raef Khan

import torch
import pandas as pd
import numpy as np
import pickle
import os, io, glob

import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import DataLoader

from torchtext.datasets.translation import TranslationDataset
from torchtext.data import Field, BucketIterator

import sentencepiece as spm

from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config

# %%
ls data/AD_NMT-master
# Out:
# LAV-MSA-2-both.pkl        Magribi_MSA-test.pkl      english-Arabic-train.pkl
# LAV-MSA-2-test.pkl        Magribi_MSA-train.pkl     english-arabic-test.pkl
# LAV-MSA-2-train.pkl       README.md
# Magribi_MSA-both.pkl      english-Arabic-both.pkl

# %%
file_path = 'data/AD_NMT-master/'

with open(file_path + "english-Arabic-train.pkl", 'rb') as handle:
    train_ds = pickle.load(handle) 
    
with open(file_path + "english-Arabic-test.pkl", 'rb') as handle:
    test_ds = pickle.load(handle) 
    
with open(file_path + "LAV-MSA-2-both.pkl", 'rb') as handle:
    data_LAV_MSA = pickle.load(handle) 

with open(file_path + "english-Arabic-both.pkl", 'rb') as handle:
    data_English_MSA = pickle.load(handle) 
    
with open(file_path + "Magribi_MSA-both.pkl", 'rb') as handle:
    data_Magribi_MSA = pickle.load(handle)

# %%
print(train_ds[0:5])
print(test_ds[0:5])
# Out:
# [['Tom was also there', 'كان توم هنا ايضا'], ['That old woman lives by herself', 'تلك المراة العجوز تسكن بمفردها'], ['He went abroad for the purpose of studying English', 'سافر خارج البلد ليتعلم الانجليزية'], ['There is a fork missing', 'هناك شوكة ناقصة'], ["I don't know this game", 'لا اعرف هذه اللعبة']]
# [["Where's your money?", 'اين مالك؟'], ['Be prepared', 'كن مستعدا'], ["I figured you'd be impressed", 'توقعت انك ستنبهر'], ['May I come in?', 'هل بامكاني الدخول؟'], ['Read through the article', 'اقرا المقالة']]

# %% [markdown]
# ## Prepare Datasets
#
# example: https://iwslt2010.fbk.eu/node/32/
#
# We need to take our training and test sets from the pkl files and create new .txt files that are formatted so that the standard torchtext Dataset class can read them

# %% [markdown]
# Data format:
# each line consists of three fields divided by the character '\'
# sentences consisting of words divided by single spaces
# format: <SENTENCE_ID>\<PARAPHRASE_ID>\<TEXT>
# Field_1: sentence ID
# Field_2: paraphrase ID
# Field_3: MT develop sentence / reference translation
# Text input example:
# DEV_001\01\This is the first develop sentence.
# DEV_002\01\This is the second develop sentence.
# Reference translation example:
# DEV_001\01\1st reference translation for 1st input
# DEV_001\02\2nd reference translation for 1st input
# ...
# DEV_002\01\1st reference translation for 2nd input
# DEV_002\02\2nd reference translation for 2nd input
# ...
# Languages:
# Arabic-English
# CSTAR03 testset: 506 sentences, 16 reference translations
# IWSLT04 testset: 500 sentences, 16 reference translations
# IWSLT05 testset: 506 sentences, 16 reference translations
# IWSLT07 testset: 489 sentences, 6 reference translations
# IWSLT08 testset: 507 sentences, 16 reference translations
# French-English
# CSTAR03 testset: 506 sentences, 16 reference translations
# IWSLT04 testset: 500 sentences, 16 reference translations
# IWSLT05 testset: 506 sentences, 16 reference translations
# Turkish-English
# CSTAR03 testset: 506 sentences, 16 reference translations
# IWSLT04 testset: 500 sentences, 16 reference translations

# %%
file_path = 'data/'

# %%
def pytorch_format(ds,src='en',trg='ar',datatype=''):
  src_formatted = src + '_formatted_' + datatype + '.txt'
  trg_formatted = trg + '_formatted_' + datatype + '.txt'
  with open(file_path + src_formatted, 'wt') as enpy, open(file_path + trg_formatted, 'wt') as arpy:
    for i, arr in enumerate(ds):
      enpy.write(datatype.upper() + '_' + str(i).zfill( len(str(len(ds))) - len(str(i))) + '\\01\\' + arr[0] + '\n')
      arpy.write(datatype.upper() + '_' + str(i).zfill( len(str(len(ds))) - len(str(i))) + '\\01\\' + arr[1] + '\n')

# %%
pytorch_format(train_ds, 'en', 'ar', 'train')
pytorch_format(test_ds, 'en', 'ar', 'test')
pytorch_format(data_LAV_MSA, 'lav', 'msa', '')
pytorch_format(data_English_MSA, 'en', 'msa', '')
pytorch_format(data_Magribi_MSA, 'mag', 'msa', '')

# %%
cat data/lav_formatted_.txt
# Out:
# _0000\01\لا انا بعرف وحدة راحت ع فرنسا و معا شنتا حطت فيها الفرش
# _0001\01\روح بوشك و فتول عاليسار
# _0002\01\لا لا لازم انه يكون عندك موضوع ما في اشي
# _0003\01\اوعي تبعدي من هون بلاش تضيعي
# _0004\01\قصدي صراحة يما انا كمان كرهته من يوم ما عملتيه زي ما بتعمله خالتي كرهته و صرت ما باطيقه بالمرة
# _0005\01\قلي موضوعك كويس و كل شي و بكرا بردلك خبر اذا بقبلك او لا
# _0006\01\كنت اذا بدي اقهر اخوتي اشتري كرتونة بوظة و بعدين اعمل حالي طيبة و اوزعها اخر الليل لاني متاكدة ما راح يصبح عليها صبح
# _0007\01\انا كمان لما بداوا يطيبوا في الدار مرضت فيه انا ما فهمتش ليش
# _0008\01\الكلمات حلوه والكليب احلى والاثنين بشجعوا على الحجاب وانا استغربت كتير من رايك بالاغنيه
# _0009\01\بس قصة انو شغل محترم يعني بيت وسيارة
# _010\01\المهم الي خايف من الحرب خايف مشان عندو شي خايف يخسرو
# _011\01\الجزائر
# _012\01\وعندك تبعت القصبة شوي
# _013\01\المشكلة هان
# _014\01\اشتغلي منيح
# _015\01\لا لا اعذريني مين انت من وين اجيت و ايش بتعرف و ايش لازم انك تعمله ايش مالك انت بتحسب انه الشغل سهل في بلادنا بالمرة
# _016\01\الله معك
# _017\01\انا هلء عم اكتب استدعائين لطالبين عندي
# _018\01\انا ما سمعتها ابدا
# _019\01\قالتلي انو يا دوب خلصنا من مراد قلنا سامي اخطبولي
# _020\01\بحكي شو الي انت عملتو حكالو لقيتك بتخلغ فيها شلتها مشان ما اتعبك
# _021\01\بس المهم يكون طري
# _022\01\قالتله لا رح ترجع عالبيت
# _023\01\شو هاد
# _024\01\اخدت الدولة ارضهن
# _025\01\ما بظن يا سليمة
# _026\01\واحنا شو سوينا
# _027\01\لما بديت اتفرج عيه شوفت الحلقة الثمانين
# _028\01\اه رسموها
# _029\01\المسكينة كتير تعذبت
# _030\01\كيف في ادارة
# _031\01\بس كمان مو هي البلد الي الشباب بيتعبوا وبيشقو فيها
# _032\01\انا اخترت شباط لانون رح يغيرولنا المقاييس
# _033\01\المشكلة هي في النظام كله
# _034\01\كل شي مكشوف
# _035\01\راح انجن وين اروح وين اهج
# _036\01\مزبوط ما فيش عنجد ما فيش
# _037\01\اكيد هاد نوع من التسويق
# _038\01\هذا مزبوط
# _039\01\طبعا لما بكون الموضع المنقول بيستاهل يعني في الصفات والاقتراحات  الي لسه شفيها من شوي شكرا الك اختي ايمي على الاهتمام
# _040\01\المهم الدنيا كلها تبقى اليوم هاد احمر في احمر وصياعه بقى
# _041\01\ممكن ترجع لكتب كتير وتقرا اجتهاد كل شيخ في التفسير
# _042\01\اه انا باسالك قلتلك انت اتصلتي فيها خالتي مويا والا لا
# _043\01\ويااارب يكون سامعني ياموني
# _044\01\الله معك
# _045\01\قلتلك مسلسل جديد ينعرض اول مرة في ابوظبي
# _046\01\وشو بتكلف رحلة لباريس مثلا يا سارة
# _047\01\عدت الامتحان و نجحت في الامتحان الكتابي
# _048\01\قضيت اربع ساعات عالكمبيوتر حتى انفجر راسي
# _049\01\انا مغرم و مش مجنون
# _050\01\درسنا ساعتين رياضة و ساعتين الاولى تاريخ و التانية رياضيات
# _051\01\صعب تلاقوها بس دوروا عليها عشان تتكلموا
# _052\01\اه اه
# _053\01\وين تلاقي العدل بين الناس  والناس مش ناس
# _054\01\وين بالماجستير
# _055\01\صباح الخير كيفك
# _056\01\في كتير طرق لتتخليهون يشتغلوا
# _057\01\طيب
# _058\01\اقترحت عليه بس ما رضي
# _059\01\وقفي الله بريء من هذا الظلم
# _060\01\لا لا مش صور اشعة دقيقة مش صور الاشعة الدقيقة المفروض انه اسيا راح تحددلي موعد هذا الاسبوع عشان هيك اما صور الاشعة السينية اخذت موعد بكرة في نص النهار و خلص
# _061\01\اللي يذبح لازم انه يضله اسبوع بلحيته زي الحجاج
# _062\01\من وين بشتري الئهوة
# _063\01\ففي وقتنا هذا صار الكل ينبهر بالمظاهر
# _064\01\رقصت
# _065\01\عيب تعيديه هذا الكلام
# _066\01\معلومات حلوه وروعه
# _067\01\لالالالالالالالالالالالالالالالا قصدي مشان ندرس كلنا
# _068\01\حتى انا كنت رايقة كان بودي نحكي و نضحك شوي
# _069\01\لاقاه والا
# _070\01\عشان اعرف بس انا بشو غلطت
# _071\01\خلصت انترسبيتش كمال شي انت بنانسي ولا بعدك بليون
# _072\01\زمان كنت العب احسن منك
# _073\01\وصلتك رسالتي مبارح
# _074\01\هي بتسعين الف
# _075\01\اي احسنلي اكتبو انا
# _076\01\اذا بدها تاخده فتاخده
# _077\01\قالتلي فريال الصبح شوفته في الحلم بيقولي بحبك كتير و لكن زي بنتي
# _078\01\تسعة الا عشر دقائق قصدي عشرة الا عشر دقائق
# _079\01\ما باليد حيلة
# _080\01\و تطلعي من الجامعة
# _081\01\اعطتني اياها اليوم فاخذتلها اياه
# _082\01\قلتلك وحدة لاماني
# _083\01\بامن فيه مو ما بامن فيه بس حب بدون رجولة مالو قيمة
# _084\01\شفتها انت معنا مبارح
# _085\01\بالضبط  هيك بنبين انه مجال علم الحاسوب فيه كتير من المفردات الفرنسية
# _086\01\صدقيني حتى لو كنتي عم تمزحي ما بتعرفي كيف بيوصلوها
# _087\01\بدك مساعده الاغنيه حلوه ومتعبه بصراحه
# _088\01\بس كمان مو سهلة عالوحدة تقول لجوزا رحو تزوج وحدة تانية
# _089\01\اتصلت فيا رابحة
# _090\01\فهاد بيطلب بحث و التاني بيعطيك تمرين و التالت بدو ياك تحضر الوظيفة او الاستجواب و بيطلعلك واحد بيطالبك بالحفظ
# _091\01\كنا نزور الشوارع القريبة منا
# _092\01\اذا بدها ياه تاخده
# _093\01\الحمد لله
# _094\01\شكرا لمرورك الكريم اختي العزيزة جعفرية وعلوية
# _095\01\ارحمنا يالله
# _096\01\ليكي بلادنا بلاد واسطة
# _097\01\حوار بين الحبيبين
# _098\01\فرجيني ايدك مسكتك
# _099\01\اذا كان محرم ح ياجلوا مرة تانية
# _100\01\لا هاد اتصال قديم من يوم عطيتو الرقم قلي استنى رح اتصل لاتاكد
# _101\01\وايمت رح يكتب الولد
# _102\01\شكرا
# _103\01\دكتور سيد
# _104\01\بتعرفي خجله كنت رح قلو كمان انا ما عندي فيسبوك هاد بس للتافهين
# _105\01\اي لان اختي كانت عمم تدرسها
# _106\01\انا بدي اقراه و بعدين اعطي رايي
# _107\01\بكره بستناه
# _108\01\روحي الله يوفقك
# _109\01\نحنا لازم نعرف اننا خسارنين ونعترف بهيك لكن لازم نعرف ان العدو مو  ممكن انو صديق ولازم نعلم ولادنا انو هاد عدونا
# _110\01\ابدوا بالحكي
# _111\01\رايي انا انه هذا مش استاذ
# _112\01\ضلك على حالك ضلك نزلهم ناحية الوادي نزلهم
# _113\01\مشان انا وانت نستفيد
# _114\01\و ايش هو تخصصك
# _115\01\نبيلة هالمسكينة هلكانة من شغب ولادها وين ما كانوا حتى بلبيت
# _116\01\وهي اخرتها لعب ولاد صحيح
# _117\01\انا طالب ماجستير في الفيزيا وبدي اطار نظري
# _118\01\اليوم صارو بيصرورو و بيبعتوا الصور
# _119\01\شكرا عيشة بامان الله
# _120\01\اي احتمال انها بطولي او اطول شوي بس المهم انها بتبين اسمن هيي بتلبس كعب عالي و بتبين اطول شوي
# _121\01\وشو الفرق
# _122\01\ما فيش
# _123\01\ولكن مش مشكلة  بنقدر نقسم مدونة اليوم لموضوعين : علم الحاسوب و السياسة
# _124\01\الله بعين
# _125\01\صدقيني انها احيانا بتحاكيني منيح بالاول
# _126\01\ان شاء الله  اذن ايش في عندك  في اشي جديد
# _127\01\ياريتني كنت قريت رسالة متل هي الايام دراستي
# _128\01\بكرة انا مسافر
# _129\01\تنطقها امي بطريقة خاصة كتير
# _130\01\قلتلا روحي اطبخي
# _131\01\اذا ليش طلبوا انه يرفق ملف التسجيل بظرفين بريد
# _132\01\باتذكر انها عملتها بعد عشرة ايام
# _133\01\وبدي اطلع الاجرة ومو عارفة وكنت عم افتح الشنطاي
# _134\01\بالشتوية اي منشان انشرالغسيل و شوف شو بدي لبس ولادي
# _135\01\ايش قررت
# _136\01\ما شفتوش بالمرة
# _137\01\ازهق من ايش من السفر او من المحادثة
# _138\01\انا عند الخاص حاليا
# _139\01\وشو ساويتو انا ما بطيق النطرة
# _140\01\وين انت سليمة
# _141\01\فتحت الشنتة اطلع الاجرة ما عرفت
# _142\01\اي اتنين بيحبو بعض ما عم تتجوزو
# _143\01\هيك رح تصير لغة عربية
# _144\01\شكرا السلام عليكم كيفك انت وين راحت الفرق نحنا هون فريق
# _145\01\و هو بقدر اني ادرس و اشتغل
# _146\01\بس بيلاقوه
# _147\01\لازم نتلاقى ان شاء الله عشان نتفق على طريقة الكتابة
# _148\01\اجا ليخطبها و هي هلق متزوجته
# _149\01\هذه بس اللي مش ممكن اني اتحكم فيها
# _150\01\بس في الحالة هي وفي القيادة رح يكون الحمل كبير كتير
# _151\01\اعتقد انه لازم انا نشتغل من خلال اجتماع
# _152\01\شوفي هلء بس لخلص باتصل فيكي
# _153\01\قصدي بشار المجنون
# _154\01\وجه لوجه
# _155\01\شو ما في شي منيح عم تقلك انها جابت لك رقم فلانة
# _156\01\اي بالمحافظة
# _157\01\اوعوا تسحبوها سيبنى ليفنى دغدغيها وبعيون صهيون
# _158\01\تعلمهون و اجا
# _159\01\امبارح يعني من زمان في الغناء
# _160\01\هيك عملت غلط هلقيت
# _161\01\ولا اي شي بصراحه هي قله ذوق مدام بتسلم على كل الناس
# _162\01\قوم قوم
# _163\01\صبيحة اللي ساكنة بعزابة
# _164\01\من المفروض انك بتعرف من الاول  ما تقول شي
# _165\01\بالماضي كان غسيل التياب مصيبة
# _166\01\مارح اكتب انت عم تضحك عليي بقك شي زبط لسانك لزبط خطي
# _167\01\اما عثماني باديس هذا فراح اجرب اني ازوره هذا الاسبوع
# _168\01\اي
# _169\01\صدقيني اني بحبك كتير كتير كتير
# _170\01\الصديق بكون دايما جنب صديقه في السراء والضراء وما بخجل منه وبفرح لفرحه وبحزن لحزنه وبيحاول يدله على الصح
# _171\01\راحت لعند نصيرة
# _172\01\احكيلنا قصص تفرح شوي زي قصه ام اربع واربعين او ابو رجل مسلوخه او امنه الغوله
# _173\01\مش عارفة ليش
# _174\01\شايفة السا مغيمة السبوع الجاي الله اعلم
# _175\01\والكبار موف اهيمين مع انو هنن متعلمين
# _176\01\في مرة من المرات قدمولهم عرض للدرك الوطني جابوا هديك الكلاب تبعتهم
# _177\01\كلمات حلوة  وكليب احلى وكله تشجيع على الحجاب  وانا استغربت من الكلام الغريب اللي انتي قلتي على الاغنية
# _178\01\بدرس بالقسم تمن ساعات متل باقي الطلاب
# _179\01\كيف حال امك بخير
# _180\01\و بطلب منك انك تلاحظي كتابتي  اظن قريبة من المثالية
# _181\01\ماشي مع السلامة لكن
# _182\01\اي لساتون عندي
# _183\01\نبعت اخوي عند ستي اذا
# _184\01\قلها انا اطول من نابليون بونابرت بتلاتة سانتيمتر
# _185\01\وشو لو قتلوني قدام ولادي
# _186\01\هلقيت هان كمان الموضوع غريب
# _187\01\بينادولك بكل مكان تارة انزلي لتحت
# _188\01\مابعرفها بس بعرف عيلتها
# _189\01\حسيت بس بغراضه بس
# _190\01\لا تفوتي
# _191\01\والله يحققلنا الي بنحلو فيه ويقدرنا نفرح الي حوالينا
# _192\01\كيف حالك
# _193\01\اجهزلك قرص
# _194\01\اه هديك
# _195\01\قلت له رح قلك شغلة اذا حملت كمبيوتر و لفيت عالصيدليات فيني احصل عليهن او لا
# _196\01\انطور انطور دئيئة
# _197\01\يا لطيف بعدا موجودة
# _198\01\السلام عليكم على فكره هدي اول مره بشارك في اشي بس حاسه انو ما في حدا موجود
# _199\01\و خاصة عنا اليوم قصير خصوصي في الشتا لما تطلع من المدرسة تتمنى لو ترتاحلك ساعة زمن وبس او تاخذلك سهوة صغيرة
# _200\01\انا كمان دائما في الروتين باتذكر انه الجمعة الماضية مرت روعة اما هذه الجمعة فسيئة كتير
# _201\01\انا برايي ان الانسان الساكت ما بيبقى هيك مع كل الناس
# _202\01\اه ببيصلي في مسجد بلال
# _203\01\متل ما عم قلك روحي دوري ع شغل و اشتغلي
# _204\01\قلك شي كملي شغلك و منشوف بعدين
# _205\01\يعني اشي ببسط
# _206\01\قالها جمال تعطي كل واحد منا متين مليون متين مليون
# _207\01\اسمع لان ربنا يعطيه قدرات
# _208\01\بتقولكم انها هان و انها حتعزمها هي و جوزها هلقيت
# _209\01\معناها كل الجزائر لازم يبطل عنها السحر بمية البحر
# _210\01\طلابنا كسلانين ما بيشتغلوا غير بالاجباري
# _211\01\من دارنا
# _212\01\ايوه هيك
# _213\01\كيف بدك اني اسكت و كل يوم في دم و حزن
# _214\01\انا
# _215\01\بختار اي مشرف و اي مشروع و بخلص دراستي  و ممكن تكملي مشروعك الخاص و تعرضه كلية الطب
# _216\01\عمرها تلاتين تقريبا بس بعدو شكلها بيوحي بنت عشرين سنة
# _217\01\سبعة من كانون الاول
# _218\01\صراحة عنابة صارت سيئة الاواعي غالية اي اشي تساعريه متين ثلاث مية اربع مية
# _219\01\انت منيح يا محمد
# _220\01\الماجستير الاول و الماجستير الثاني
# _221\01\هي بيدرسا بالنهار
# _222\01\دائما حطي حالك في الصورة انت فهمت حتى و اذا ما حبوكيش ما حبوكيش من المرة الاولى بعدين حيحبوكي و يعملوا زي ما بتعملي
# _223\01\ويا تطلع البطيخة قرعه يا قرعه
# _224\01\قعدوني وهدوني وفي الاخر روحت بعد ما خلوني انا الغلطانه
# _225\01\قوليلها انه كان عندي بس مضيعاه
# _226\01\لا رح يسالوك
# _227\01\اه فعلا احنا بنشجعهم على الاستهزاء بالاسلام لاننا بنهتم وبنحضر اللي بنشروه
# _228\01\هي هذه من القصبة ما بيعرفها الا القدام
# _229\01\عشان هيك
# _230\01\مين
# _231\01\لما يكون الشخص فاضي
# _232\01\اي ئلتلك انو ناوية ارخي شعري
# _233\01\اي
# _234\01\صدقني ما بعرفش انه لونها ازرق كبيرة شوي اذا تذكرت العطر
# _235\01\امتى نلتقي على السكايب
# _236\01\شو
# _237\01\لسه ماحدا لاقله علاج انا شخصيا بعاني منو من زمان كتير كتير
# _238\01\وين بدون يحطوون بيبقوا تلات سنين و بيتركوا الدور لغيرون
# _239\01\بتعرفي يا سارة انه رحلة على ليون بتكلف مليونين و خمسمية
# _240\01\قالولي طلع انه ابوه كان يتاجر في المخدرات
# _241\01\تمام انا حتى نوم ما اقدر او ممكن الدوا الي اخدته كان قوي
# _242\01\اشترولي بوط
# _243\01\من كم يوم كانت فريال زردازي عم تحكيلي عن الاستاذ بن سبع
# _244\01\بتمنى تجاوب عليه عنجد انا بتمنى اعرف
# _245\01\هديك البنت اللي شوفتها
# _246\01\وبيدرس يومين بالاسبوع
# _247\01\اه اقولك اشي لما تكوني في الدار شيلي البطارية اصلا و اعملي
# _248\01\مع انها ما اخذتش شنطتها
# _249\01\حيعيط وائل
# _250\01\اطلبي منها انها تخبر خواتها البنات لو سمحت يا كريمة
# _251\01\احنا بنقولك ما تصرخيش عشان ما تتضررش حبالك الصوتية
# _252\01\اذن مراد ايش اخبارك
# _253\01\هذا اللي بتقوله
# _254\01\انا حطيت كلمة سر معقدة كتير
# _255\01\ما هو الذوق كلمه حلوه بنخفف فيها عن انسان زعلان وممكن كمان  تسعده او نتجنب كلمه ممكن تاذي مشاعره
# _256\01\اي معلومات
# _257\01\شفت كيف بنتك بتعرف مع انها مو حلوة بس بنت احسن
# _258\01\لو كانت بهذا الشكل
# _259\01\قلا شلون يعني
# _260\01\وزاد الضغط على المصريين بعد تعريب الدواوين
# _261\01\لا مش قضية مسابقات مش هذا
# _262\01\و هو انا حالاقي وحدة قصيرة
# _263\01\اسفة مرت من بين اصابعي
# _264\01\قالتلي بوبة روحي و انتظري عند حماتك
# _265\01\انت بخير حسام بخير
# _266\01\يوم الخميس الجامعة دائما فاضية
# _267\01\حتى و اذا رحت لدكتور عام كويس يعطيك تعملي تحاليل
# _268\01\على اعتبار انو مبارك فرعون كمان الله ببعثله موسى
# _269\01\مساكين بتكذبي عليون و بتوعديون بالسكاكر و ما بتعطيون شي
# _270\01\تروحي لحالك
# _271\01\و وين هي عائشة
# _272\01\الي من بره اساسا
# _273\01\ما فيش اختبار مستوى
# _274\01\اي هاد بس الي بعرفه
# _275\01\صغار بس ما بيسمعوا الكلمة
# _276\01\بالتلفزيون دايما بيئولو الجزائر بيضا صح هالحكي
# _277\01\ليش
# _278\01\انا فكرت اني اشتري جزمة
# _279\01\مزبوط احنا محظوظين بشغلنا معه
# _280\01\الثاني بيشرب قهوته
# _281\01\قلت بسال حدا من هون قلي بوالكرعين هون قلي روحي لعند بنمهيدي قلي هالزلمة رائع و ما في احسن منو بس هو بيبلش عالعشرة و انا كنت مستعجلة
# _282\01\صباح الخير
# _283\01\انا بدي ساعتين على الاقل
# _284\01\انا كمان بدي اروح بدي اروح
# _285\01\احنا زي العرب اللي بيعرفوا انهم لازم يتفقوا و ما بيتفقوش
# _286\01\اه انتشر في وحدة من السنين و صاب الكل
# _287\01\لا انا ما سمعت هيك شي
# _288\01\تعمل اللي بدها اياه المطلقة مطلقة
# _289\01\على هالطريقة كلنا عايشين
# _290\01\معناه هذا الانسان القوي
# _291\01\عنجد
# _292\01\قلتلك اذا ضليتيك هيك رح تملي و يملوا منك
# _293\01\خالتي خيرة صارت بتعرف الاسلحة
# _294\01\ئليلها ما كان في وقت و هي رايحة لعند خالتي لتعزمها
# _295\01\امي ما فهمتش ليش صارت هذه البنت تحس بالسقعة اكتر من اللازم
# _296\01\ما في خشبات و ئريصات
# _297\01\ايمتى حكيتيلي ما بتذكر
# _298\01\الاستاز ي ابني هو اتداين الف وبعدها الف وما رح يرجع اشي
# _299\01\اذا ما سلمتيوش هذا الاستدعاء لابوه حتتعاقبي يلا بسرعة
# _300\01\وين ياخذها
# _301\01\احسبي فرق الساعات بين ادان العشي و ادان الصبح و قسمي المجموع ع تلاتة بتطلع معك النتيجة
# _302\01\لاباس مراد  نبين بس مش على الاحدعش بالليل
# _303\01\مزبوط انت قاعد
# _304\01\اما انا فراح امسح طاولة المطبخ و ادرس هان
# _305\01\بشوف فيلم بالمطعم شي رائع
# _306\01\شفت بالله
# _307\01\والاستاذ ابراهيم الدسوقي قال ان وقتك قليل
# _308\01\وانت الي الك الاختيار في الاول والاخير
# _309\01\قلها مافي داعي خليها للصبح
# _310\01\انا باشوف انه تمن ملايين اشي روعة هذا السيد دفع اوراقه و خلص جابوه فساب هذا الشغل و راح
# _311\01\احنا في فترة الامتحانات الاستدراكية
# _312\01\ههه بس هدول يا حرام من زمان خلصت قصتهم ههه
# _313\01\ليش ما عزمتك تنام عنا
# _314\01\جبتو حتى تشوف خولة اعلان المسابقة
# _315\01\ايش حاعمل فيه هذا مش بلد تطوير لو كنت انت في مكاني ايش كنت حتسوي
# _316\01\لهلقيت حكينا في كل اشي  حتى في السياسة
# _317\01\شلون هيك يا وداد ما قلتيلي ح يجي هو و ابوه ليروحوا مع خالي ليحكوا مع الامام
# _318\01\بضرب اذا ضايقني المدير
# _319\01\مبين هيك  يعني درس في الجامع و في المدرسة الفرنسية عشان هيك محفظتين
# _320\01\و المشكلة انه امه ما بتهسوش بالمرة
# _321\01\و عبدو هلقيت معهم
# _322\01\ما طلبوا معلوماتية
# _323\01\قالت فيه اشي ما بعرف شو  بنعمل للشخص يوم بخطب بحميه من السحر والشغلات هاي
# _324\01\انا مو بالفن
# _325\01\فيما يتعلق باطروحتك سليمة  شوف ادوات التجزئة المورفولوجية : مادا  مورفتاقر  سابا
# _326\01\ماشي يعني معزومة
# _327\01\اه  ليش ما عنديش سفن بتطلع للصيد
# _328\01\يعني تكتب مقالات وهيك قصص وقولنا الحل يا فرعون اكيد انت كمان بتنقل الموضيع الي بتكتبها
# _329\01\هي حرة لو اسمع منا ما بساوي شي ما بتحب شي
# _330\01\يا الهي و العياذ بالله
# _331\01\لكن كيف بيقولوا انو بيتفق مع المرة الجدي
# _332\01\هناك ينزل عيسى لان عيسى مش ميت زيي و زيك مرفوع وبس
# _333\01\كيف نروح معك هلقيت
# _334\01\رد الجوز بتتذكري لما اتواعدنا من 20 سنة
# _335\01\بهاء سلطان قلبك يا حول الله
# _336\01\من دون شك انت كمان انتخبيه
# _337\01\وايمت بتشتغلي لكن
# _338\01\هي ما بتسمع كل شي
# _339\01\اي
# _340\01\والله مزبوط انا بعرف انو بهداك الوقت رح اتلبك و تتشوش افكاري
# _341\01\وهي الصور
# _342\01\اعملك تلفزيون اذا
# _343\01\اتخربطت الاوضاع في مصر كمان قالوا انه هذه الحكومة الجديدة كملت مشوار مبارك
# _344\01\بتقول بعدين
# _345\01\و كيف احواله بخير
# _346\01\طلع لمكتبها تعرفت عليه و تجوزته
# _347\01\ما تعصبنيش بس صدقيني اني مشغول
# _348\01\حكيت مع ابن عمي بخصوص موضوع الزواج تفهم الموضوع و كلم والدو كمان
# _349\01\لا هي رجلا كبيرة
# _350\01\قسمك جاهز اتفضلي
# _351\01\بتقلك بتديقلك ياها شوي
# _352\01\رد الزلمه   بتتذكري يوم اتواعدنا قبل 20سنه
# _353\01\شفت شو رد الرئيس بوتفليقة على الصحفية الفرنسية لما قالتلو انت اقصر رئيس بالعالم
# _354\01\وتكره هاض  الموضوع مش بايدك
# _355\01\لكن نجحت
# _356\01\طلع ابوك
# _357\01\بكرة بصحى بدري
# _358\01\ونحن منستنى
# _359\01\لو كنت محلك لقلتله انا ما وجهتش الكلام الك
# _360\01\اتركيه بس شو عم تساويلو
# _361\01\كنا ما نطلع من بيتها ابدا و بتذكر كمان انو كان عندها سكرية بلور كبيرة كسرناها
# _362\01\بعدين حاصرهم في واحد من الاماكن المحوطة بالشجر الحشيش اشعلوا عليهم النار
# _363\01\لا الي بدو يسافر يروح على باريس او بلا
# _364\01\تعلم اليوم شي جديد
# _365\01\ممكن تسمع شهادات من بنات اتعرضوا للتحرش وتحط حالك مكانهم وتحس باللي تعرضوا اله من قلق وغثيان وغيره
# _366\01\انا بدعيلهم ليل و نهار
# _367\01\هذا مش مزبوط
# _368\01\اذن وين انتو
# _369\01\بيت
# _370\01\صح ريحتها متل ريحة العطر منيحة اول يوم بس بعدين
# _371\01\عطاني حبوب للصبر
# _372\01\يطرحن اسئلة زي ما كنا احنا من قبل
# _373\01\حيقولهم انه هذه البنت مش ممكن انها تكون طالبة في الجامعة
# _374\01\مش متذكره ناس متذكره اللي فوق الراس قبل االاعلان عن الحرب
# _375\01\اي بيصلي بمسجد بلال
# _376\01\تقاتل معو
# _377\01\لما اجيب الجوال انتو ما بتجوش
# _378\01\تعال احنا نوقف قدامهم احسن ما هم يجو يوقفو قدامنا
# _379\01\قالتلون بعمري ما شفتكون
# _380\01\انا مش اغلى من الجوهرة
# _381\01\بصراحة ما كنتش بفكر انها قادرة على هيك
# _382\01\استني حاحكي معهم
# _383\01\اي
# _384\01\سارة اعطيني اياها جبتها هلقيت بس
# _385\01\وبدون معرفه مسبقه ولا سابق انذار بقولك ممكن نتعرف ونصير اصدقاء
# _386\01\اه سليمة كيف حالك
# _387\01\يالله افرضي انا اللي عم يسالك
# _388\01\شو بدك تساوي لازم تتعودي
# _389\01\على فكرة الكامرون ما بدهمش اللعب معانا
# _390\01\ربحت برشلونة تلاتة واحد
# _391\01\ايش حاعمل يا اختي منال ما باليد حيلة
# _392\01\شو المعلومات
# _393\01\احنا لازم نعترف انا مغلوبين ولازم نعرف انو العدو مستحيل يكون صديق ولازم نحكي لولادنا مين هو عدونا
# _394\01\شو بدي قلها بكرة
# _395\01\اكيد ما هيي بالاطنان
# _396\01\بس هيك
# _397\01\والمفاجئة بقى انه احكي مرة وحدة فعلا عندو كرامة  تصورا
# _398\01\جماعة خالتي وردة حيتلاقوا والا لا
# _399\01\ليش مشكلة بالاتصال
# _400\01\بتتجاهلني بتتجاهلني ما قلت ايوب او اي شي واصل تجاهلك
# _401\01\سكرت الرسالة بسرعة و رجع فتحتا و بلشت اقراها من جديد
# _402\01\المفروض اظبط البيت كلو انا واختي
# _403\01\جيت عالتمانة
# _404\01\بالاضافة الى انو ممكن تكون مو منقاة وممكن يكون فيها اعشاب ضارة او سامة
# _405\01\ضربه الشيخ كف بقوة
# _406\01\صدقيني هي ما عندي ابدا
# _407\01\وقت قلتلا انو فريال رجعت اتصلت فيكي و انا رديت عليها قالتلي ليش رديتي
# _408\01\شو هو موضوع اليوم
# _409\01\كان بدي اسالكم  مش عشان الفضول بس عشان تكون المدونة متنوعة  احكولي شوي عن اللي عملتوه في هذه العطلة
# _410\01\اسلام حاج تحكي
# _411\01\الكلمات او الخربشات الي كتبتها مو معقول اديش حلوة
# _412\01\يا على هالخزوة
# _413\01\مرات بيجي عالغدا ياكل و هو واقف و يروح ما عندهمش وقت كتير من الاطنعش للوحدة و يرجعوا
# _414\01\طبعا سليمة  الله يشفيكي
# _415\01\ما بعرف ليش
# _416\01\منيح هو بيعرف والا ايش
# _417\01\من علي
# _418\01\اتصلي فيها و اتصلي باخي
# _419\01\تماما عم اسالك شو الفرق لو ماكان في فرق ماكانو حطوهن باختصاصين فهمت
# _420\01\تساوي شو ما بدها المطلئة مطلئة
# _421\01\وبعدها بيموت عيسى و بيصلوا عليه متل مابيصلوا عاكل العباد
# _422\01\جيت متاخرة
# _423\01\انتظيني ميمي جاي فورا و هلء احكولي
# _424\01\كل سنة وانت سالم
# _425\01\انا محتاج كتاب يعلمني الانجليزي بسهولة وكتابة ممكن الرد بسرعة لاني مسافر امريكا
# _426\01\حل عني يا كذاب
# _427\01\انا ما باتذكر
# _428\01\و هي روحتك الى باتنة حيكلفك خمسة الاف دينار
# _429\01\اذا لئطتك المرة الجاي بدي اشرطك نصين
# _430\01\قلت اكيد انو عم يدخل الخيط ليطالع الضرس
# _431\01\وفرحة العيد والعيديه
# _432\01\وقت اللي بيادن بتكون انت متكي عالحيط عم تتسلى فهمت ولا لاء
# _433\01\قولي يا رؤى تعشيتوا عند خالتك والا لا
# _434\01\ماشي
# _435\01\الختيارة و الختيار لحالهن
# _436\01\كملو حديثكوا كيف قضيتوا العطلة
# _437\01\حتاخذوها و ترجعوا لهناك
# _438\01\بس ما في مانع فينا نقسم المدونة اليوم لموضوعين المعلوماتية و السياسة
# _439\01\قوليلها بس هي رح تفهم و تضحك فهمت
# _440\01\اكيد يا ايوب
# _441\01\هذا عادي  انا كمان صحيت بدري وما ارتحتش  بس ايش نعمل اجسامنا تعودت
# _442\01\و انت هي سنتك الاولى ما عندك اي خبرة
# _443\01\انت اهلاوي اقبلي ولا بحري
# _444\01\فكرت زوجو بلكي الله بيرزقو
# _445\01\وحطيت في شريحة موبيليس
# _446\01\انت بعتتلي على c box وانا ما رديت
# _447\01\لاني لما كنت معا طفت الصوبيا
# _448\01\اه بس هذه علامة فرنسية
# _449\01\لما رجعت قلتلها شوفي ايش عملتي فيا يا صباح كنت حاضيع الباص
# _450\01\انا بتابعها لما كون مسافرة
# _451\01\ما فيش داعي للموضوع
# _452\01\امبارح اخذوا من فريد الرخصة
# _453\01\هي هيي الدنيا
# _454\01\شفت بالمسلسل هالجواكيت اللي بتلبسها ياسمين حلوة كتير
# _455\01\لارح نشغل ببحور ولاوزن
# _456\01\اه ياخذها على داره
# _457\01\اه صباح الخير شلونك
# _458\01\الله يبسط الفريق و يبسطنا معون
# _459\01\ميمي مرري الابريق لامي
# _460\01\و انت بتعرفي تستعمليه شوي
# _461\01\و انت عندك فكرة عن الاعلام الالي والا لا
# _462\01\يا رب سدد خطاهم يارب
# _463\01\وبدي اطلع الاجره وكنت فاتحه الشنته وما عرفتش
# _464\01\هي الفكره رح تفتح موضوع في البدايه الفكره موجوده واي حدا عندو شكوا يحطها في البدايه في الموضوع هدا
# _465\01\حكتيلي تعالي اجيت
# _466\01\بحكيلك لو سمحتي اعطيني ميه بس المدير بقول هاتي ميه
# _467\01\عفوا اخي لو سمحت
# _468\01\وخالد و مرتو بيشتغلوا
# _469\01\اه اختصاصي اعصاب
# _470\01\مفتوحة تماما العضم هش
# _471\01\انا بحب كل الناس بس ما بدي حد يسكن قلبي الا ربنا سبحانه وتعالى
# _472\01\طيب لكن بتدرسي يا اسبوع يا يومين هلء فهمت
# _473\01\مناح في شقاوة
# _474\01\راحوا اهل المرة بعد ما استانسوا و اكلو و بعدا امرت مرة الاب الخادمة انو تنضف البيت و راحت هي تنام و ما كلفت حالا حتى بالسؤال عن الصغير
# _475\01\بالواقع مو بس الشباب حتى الختيارة المتقاعدين بروحوا عكندا
# _476\01\الهجرة لما يترك الانسان بلده بطريقة غير شرعية او لا
# _477\01\بس راس السنة
# _478\01\اي اتصلنا فيها
# _479\01\امي كمان مرضت كتير بالايام الماضية متل ما بتعرفي هي معها وجع بالحلق و مشكلة بالغدة الدرقية
# _480\01\اه قالولي شهر اقسم بالله انها مشكلة
# _481\01\بدرس في القسم تمن ساعات زي باقي التلاميذ
# _482\01\صدقيني انو اللي بيضيع وقتو بالسرسرة بيخسر كتير و بيلاقي صعوبات يوم اللي بيقدم البكالوريا
# _483\01\مشان طرقة الحل غير عن طريقتو
# _484\01\كيف كيف
# _485\01\بتسجل حديث بالعامية و بتكتبو و بعدين بترجع بتكتبو بالفصحى
# _486\01\القصة بطيخ عالاخر
# _487\01\مزبوط هيك يعني ما فيش داعي للقلق المحاسبة بعدين بتخلصي الماجستير الثاني الرياضيات و علم حاسوب ما شاء الله
# _488\01\بتعرف لك صلاح ليش الكل بتطلع ريحة تمو
# _489\01\ايش قالولكم
# _490\01\مرتين وراء بعض و انت تردينني بسبب هذا القرص
# _491\01\لو انه يرجع يتصل فيكي هلقيت او اي اشي زي هيك قوليله اني قدرت اتصل فيها
# _492\01\انا بعرف المشوشة
# _493\01\انا شخصيا بدرس شهر و بضرب خمس طعشر يوم
# _494\01\وانا كمان كنت رح اطلب منكم ان نوقف
# _495\01\عنجد
# _496\01\ابوه نام و بنومو شاف مرتو الاولانية عم تقلو اهتم بابنك
# _497\01\انا حاطط قانون ما حدا يجيني بالخفافة و الميزر بينطرد عنا هيك النظام
# _498\01\يا صديقي بتذكر حادثة الملعب
# _499\01\اوعك يفكرك مجنونة بيقول بعدين ما بيجيني غير المجانين
# _500\01\شديد العقاب علي بيعصيه
# _501\01\اه انا حالمه وبس هذا بكفي
# _502\01\وقتيش
# _503\01\هذا مفتوح هداك تشتري من عنده بالعادة
# _504\01\اي بلشت حضر لشهادتي
# _505\01\بعد هيك ما حسيت باشي
# _506\01\هو ذكي كتير اكتر من الذئب
# _507\01\هذا ادمان
# _508\01\المسكين حطوه معا
# _509\01\لو شوفت ايش عمل بالولد الصغير
# _510\01\الي خلص تصليح يطالع غراضه او يتكتف او يلعب بالعجينة بدون صوت و الي ما خلص يخلص عالسريع لح يدء الجرص
# _511\01\تاني يوم لما رحت اشوف ايش بدي اشتريله لقيت كتاب بيحكي عن الاسلام بالانجليزية
# _512\01\منقدر نستعملو لنكتب بالعامية
# _513\01\شوفت قطع عند واحد منهم في المدينة
# _514\01\اشرحلي شوري علي شو ساوي يا بنتي
# _515\01\ديري هدليك اللي قبلها ماشي رح اكتبها بايدي
# _516\01\ما صار فيه بساطة زمان ولا الامان اللي منفتقدو اليوم
# _517\01\انا بحب هدا المجال كتير خاصه الشخصيات ومدى الاحساس وانتي تكتبي
# _518\01\اما نحنا فعنا شهر ايار منخصصو للمناقشات خلصنا كل الفحوصات التكميلية باخر السنة
# _519\01\لا تنسى انه بنحاول نكتب الدارجة قريبة من الفصحى
# _520\01\و كيف عرفت انها ما بتعرفش
# _521\01\كان في افكار اشتراكية ومقالات عصرية ما كانت عمزاجهم
# _522\01\تحت الصومعة علقوا الحجام
# _523\01\لا ما بظن هالحكي مزبوط روح و استفسر عن الموضوع
# _524\01\اتفضل الله يوفقكم للاستفسار
# _525\01\لا انا بستعمل جوالين
# _526\01\موافق
# _527\01\ولا لحظه عمره ما نسيها
# _528\01\وين ما بدك في الدار او في مكان تاني
# _529\01\بسبب العضلة صارت مايلة زي هيك
# _530\01\اهم اشي عندي اني بحب حياتي ولا مره بفكر في اللي فات وراح ولا في اللي جاي كمان
# _531\01\ما بتعرفيه
# _532\01\لا قصدي املاك الدولة
# _533\01\ح تدرسوا هالكام يوم و بس و بتعطلوا شهر و نص باول السنة
# _534\01\عملت
# _535\01\صدقيني شفت البنات عم يجو لعندها
# _536\01\ايش هو موضوع اليوم
# _537\01\انا خطيبها
# _538\01\هو و فاتورته و كل اشي باطنعش
# _539\01\السلام عليكم زكي انتي بخير هلا ميدو انتي بخير كادي
# _540\01\رجعنا
# _541\01\ليش
# _542\01\انت رح تدخل الجنة وانا رح ادخل النار ورح تعمل كل الحرام الي انا بعملو
# _543\01\بس تقاليدنا و تقاليد ابوي ما بتسمحش للبنت انها تعطي رايها
# _544\01\ليش انو تعود من وهو صغير يناقش ويحاور
# _545\01\هذا الاول والا التاني استاذة بتعرف ايش قالتلي
# _546\01\مو عارفة ساعات وبيكون مكان بيذكرني بحدث معين او حدا معين
# _547\01\مزبوط باتذكره
# _548\01\وفعلا بصير لانو الارض خصبة
# _549\01\و وصتني اني ابلغك انك تقولي لرفيقة اذا كان عندها فساتين سهرة لعمر حوالي اربع سنين و ستة سنين و نص
# _550\01\مشكورين حبايبي على الردود الحلوة
# _551\01\راح مراد مش عارف ليش
# _552\01\النوابغ اللي بدهم يطوروا عالمنا
# _553\01\لكن انا حبيتها بالسنة الاخيرة و الحمد لله اخدت البكالوريا و جبت علامات منيحة بالرياضيات و الفيزيا و العلوم
# _554\01\انيس ساكن ساكا
# _555\01\بعدين قلت حاتصل انا بمفيدة وبس
# _556\01\ديري بالك على حالك في اليومين الجايين وحاولي ما تبينيش
# _557\01\انا بعرف بالنسبه للبنات ما بكفي بس يا ريت تحملوا معكم اجهزة حمايه بالذات الصاعق عشان البخاخة ما بتنفع
# _558\01\واحد كان  زعلان من مرتو
# _559\01\عادي
# _560\01\حكيت مع اخواتي الكبار بس كمان ما في نتيجة
# _561\01\و اللي ما بيسمعش الكلام اقسم اني مش حاعطيه
# _562\01\صدقيني اني ما ساويتلها شي ما ساويتلها شي والله بيشهد
# _563\01\شيماء ادامك الي خلص شغله يتكتف او يطالع العجيني و يلعب بدون صوت
# _564\01\ما النا الا نقول الحمد لله مع الولاد تعبوني لانهن قليلين ترباية و ما بيسمعوا الكلام
# _565\01\انا ما بعرفها بالمرة
# _566\01\ههه قوية كتير
# _567\01\ولو ما في بيننا هيك شي يا عسولة
# _568\01\الابيض حلو اي
# _569\01\بس اسمعي دوريلي على عنوانه ما اعتطنيش اياه البنت
# _570\01\شفت حتى بن علي قصير كتير كمان
# _571\01\يعني هذه هي الشغلات اللي خلاها ربنا انه مستحيل تصل الها
# _572\01\و ليش لا
# _573\01\ليش ضربته
# _574\01\رح ابعت
# _575\01\اروح اه
# _576\01\عم يقولوا كريستيانو رونالدو رح يطالع اول البوم الو
# _577\01\كلمات حلوة  فيديو كليب احلى  وكلو بشجع على الحجاب  وانا جد استغربت عن حكيك عن الاغنية
# _578\01\وبالتالي مادامت البنت وافقت على الزواج من شب بعرف بنات قبلها هي حره وهي بتتحمل مسؤولية غلطها مش الشب
# _579\01\ما رضيش انه يحددلي تاريخ واضح
# _580\01\مبين انها مثقفة
# _581\01\لوين
# _582\01\اي ما عادو حد متل ما كان يا مو
# _583\01\اي يمكن بتجلي الصحون بس ما بتعترف
# _584\01\اه و امي عندها ضغط
# _585\01\مزبوط بعد الحفلة فورا بدي تاخدي سيتامول
# _586\01\ارحمنا يارب
# _587\01\عشان يعطينا علامة كويسة
# _588\01\انا و يسرا بالغرفة و هنن بالصالون
# _589\01\يالله الشر معبي عينيهم
# _590\01\لسه في عندك وجع
# _591\01\تكلمي على التليفون
# _592\01\كنت خايف انه توافق على المناقشة
# _593\01\هههه كتير كوول البسس تبعونك
# _594\01\كريمة كالعادة ضلينا لحالنا
# _595\01\من كذا يوم كانت فريال زردازي بتحكيلي عن الاستاذ بن سبع
# _596\01\والعصير مضر بالصحة
# _597\01\ولا تصدي انو في تلطيشات ولا شي
# _598\01\كمان بيقولو انو الدعاء بيطلع من الارض و بينزل القدر من السما فلما يكون الدعاء الطالع قوي و صادق بياثر عالقدر و بيغيرو
# _599\01\حلوة كتير
# _600\01\انا بمزح بس
# _601\01\بس لحظه يا رئيس لسه ضايل ناس بتشتري منك ارضنا
# _602\01\لا
# _603\01\بيجي عليه ناس من كل العالم ليتعلمو وفي شيوخ افاضل ما بصير نحكي ارهاب وارهابيين
# _604\01\نادتني و انا هونيك عم بقراه
# _605\01\تجوز ابوه بعد سبعة اشهر من وفاة مرته و جاب ابنه ليعيش معه
# _606\01\نحنا بفترة الامتحانات التكميلية
# _607\01\مع انه سهل تزبيطه
# _608\01\صدقيني انه هذه الايام صرت انسى كتير
# _609\01\كيف الصحة
# _610\01\ومبدئي وقناعتي اني ما بشتغل عشانهم ولا مره وبالعكس
# _611\01\اهلين حسام ليكك بخير
# _612\01\بتعرفي كبار و صغار بيتابعوا هداك المسلسل
# _613\01\كملت كوكة عمل البقلاوة
# _614\01\بارك الله فيك قلتلا مدام كل شي تعالج بالمعلوماتية بس بيضل في شوية امور اضافية لما بخلص شغلي لح خصص فصل اعمل فيه مقارنة بين شغل و شغل اللي قبلي و منقارن بيناتون معناها هي كمان سيبك منها
# _615\01\كيف حورية و البنات و كيف الرهرة
# _616\01\ما طلبتوش رايي اذا انا مش موافقة
# _617\01\هدير بالنسبة لردك انتي اكيد غلطانة انا الحمدلله عمري ما جربتو انتي شكلك نسيتي اني التالت عالدفعة
# _618\01\امسكه انت بس
# _619\01\هي بتعرف اساميهم حتقولهم
# _620\01\مزبوط
# _621\01\يا سهام
# _622\01\عشان نستفيد احنا الاثنين
# _623\01\المهم اولا الفيلم بايخ وتافه وممل ورزيل وقليل زوء
# _624\01\وطمنيني عملت شو في امتحاناتك
# _625\01\صارت تخينة عن اول و كانت لما تحب انها تشتري اشي تلاقيه ضيق فما بالك بهلقيت
# _626\01\اتركيه يا دكتوره هدا همه كتوي علاوره
# _627\01\شكرا كتير كتير يا زورو هيك بالزبط بدي الاغنيه لاني هيك بقدر اخليها رنه
# _628\01\تصبحوا على خير توصلوا بالسلامة
# _629\01\انا زينب بنت عمة نوري
# _630\01\من التعب
# _631\01\لا تخافي ما رح اخدلك ياه عم نحكي و بس
# _632\01\لا ما بدي العب
# _633\01\اكتبها بالعامية
# _634\01\علي صوتك
# _635\01\بس لا تينو بطل يبات في الاوضه
# _636\01\بتعرفي انا متاخرة ما فهمتش لهلقيت زدني يا كمال بستاهل
# _637\01\قالي حاقولك اشي حاخذ عطلة نشتغل سوا و نتقاسم بالنص
# _638\01\وانت شوفت يوم سماء سوداء
# _639\01\بتعجبني اخلاقو لهالشب
# _640\01\وصلتك رسالتي امبارح
# _641\01\سلام
# _642\01\جاوبت اه متذكره
# _643\01\انا ما سمعتهاش بالمرة
# _644\01\مزبوط
# _645\01\بتعرفي حتى لو انه الجمل مش مرتبة فهذا مش مشكلة
# _646\01\اي عين
# _647\01\لانها كانت فكرة في عقل الشلة
# _648\01\اي انها كانت مؤقتة بعدين تثبتت
# _649\01\اي لبيبة
# _650\01\ويا ريت الشباب يتعظوا من اللي صار مع هيثم ويرحموا اهلهم شوي
# _651\01\يللا اذا رايح تدرس
# _652\01\عندك تطبيق ولا شو
# _653\01\اصحابي الحلوين بحبكم كلكم
# _654\01\ماشي رح جبلك زلمة متل صواش
# _655\01\وبعدين بتصير مشاكل بتسبب طلاق
# _656\01\لازم نعرض النتائج اللي وصلنالها حتى لو ما كانت شي كتير كبير
# _657\01\اه
# _658\01\ماشي و هو كذلك
# _659\01\عمر
# _660\01\لازم ما كنا سلبيين طول الوقت
# _661\01\مرحبا فيك
# _662\01\اه انا في الماجستير الثاني
# _663\01\عم تحكي جد
# _664\01\ليش مو محجبة
# _665\01\قالتلي استخدميها لما بيجوك الضيوف
# _666\01\ما عندهمش عيدان
# _667\01\20 الف موظف في التموين بجهزو لاعتصام وبدي احكيلك معلومة
# _668\01\شكرا كتير على الرد الحلو بس كل القصة
# _669\01\فعلا مرات بنتوه
# _670\01\زبط الحواشي  اخدنا الدهب
# _671\01\بيكفي تعملوا دوشة احنا مش اتفقنا عالدوشة اللي بيحكي اللي بيتحرك راح احطله صفر
# _672\01\انا خايفة منه بس بدي عيش
# _673\01\الرفيس ناشف شوي يما
# _674\01\اذا الظروف بتسمح ببقى مافي مانع المهم اني احكم عقلي في الحب
# _675\01\ولو فريق عنو في المجلة يبقى شوفه
# _676\01\زي هداك اللي حكالنا عنه عبدو عنده ذيل قصير
# _677\01\مش هداك المحل
# _678\01\قلنا انا نكتب الالف واللام
# _679\01\يوم الخميس راح الوالد على تبسة
# _680\01\قلت يوم سبعة يا زينب
# _681\01\بيقول ما تتحججش بالعرض
# _682\01\رسائلك انا بكتبها
# _683\01\بالضبط متل جريمة اسلام نبيه في حق عماد الكبير
# _684\01\بتقبلي بوظيفة مخزن بيانات
# _685\01\ليكها يا امي كل الي ساويتيه انت حطيته هون
# _686\01\قالتلي هذه السنة الجديدة لازم انك تدفعي ستة اشهر
# _687\01\قال اسامة انه حيتاكد بالاول
# _688\01\عم تحكي جد هاد بيفحصوا فيه النسوان
# _689\01\بتروح عالمدينة ولا بترجع عالبيت
# _690\01\قلتلو قصدي شعر بنتك وسخ
# _691\01\اسكتي
# _692\01\منبعتلها اخي يجيبها لعندي
# _693\01\اه
# _694\01\ادواتكم بتلاقوها كلها جوا
# _695\01\بتعرفي ايش صرت اعمل
# _696\01\مساء الخير
# _697\01\في مجموعة منهم لسا عالموبايل
# _698\01\اي
# _699\01\كتكوتة مشاغبة عاملة دوشة
# _700\01\هما الخاسر الاكبر
# _701\01\اتصوري كنت مرتاح من قدارتك ورفيقيتي  حكت معي عالتلفون وبتسلم عليكي يا مشاغبة
# _702\01\كلشي فردي هون
# _703\01\من الطبيعي تئدمي شهادة الماستر الاول هو يعتبر شهادة
# _704\01\لا  اعطوا السلاح كريمة
# _705\01\كتير كتير مساحتها كبيره وتقيلة كتير
# _706\01\الله يهديها بتعرفي صار عندا كتير غيابات ما بتخاف يسرحوها
# _707\01\كل واحد الو شغلو ماحدا بياخد شغل حدا لا الرجال ولا المراة الله شخر كل انسان بقدرة معينة للشغل بشيء معين
# _708\01\اي واحد ابيض و التاني بنفسجي
# _709\01\بعدين نقعد قدام الدفاية و ناكله مع الخبز اللي بتعمليه انت
# _710\01\اي مزبوط بتحطها بالبراد و تاني يوم بتستخدمها و لما بتستخدمها ريحتها بتضل و مابتروح ابدا
# _711\01\سهام خلصي المكالمة بئا
# _712\01\اه هي اللي قالتلي صدقيني هي ما بتعرفش اني حاجيبلك عريس
# _713\01\يا بنت قومي و حضري قهوة لهداك المسكين
# _714\01\ما عندن خشيبات
# _715\01\و بجد لا تعتمدي ع حدا بهالدنيا
# _716\01\على الرغم من تبادل المشاعر بننا
# _717\01\شو يا قمر شو عاملة  مش رح تفتحي نت
# _718\01\اكيد انا بمزح بس
# _719\01\شفتي دموعي عخدودي  الفرحة بينت في عيني
# _720\01\سمعت انون ساووا عقود لمساعدة الشباب المتخرجين من الجامعات
# _721\01\و جبتيلي اللي طلبته منك
# _722\01\ديري بالك عحالك يا سهام
# _723\01\ايش قلتيلي ايش بدك تعملي في المستقبل ايش بدك تصيري
# _724\01\ما بيخاف
# _725\01\اه
# _726\01\اي لازم تجرب الفستان لانو بعض العالم بيكون مقاسون مختلف فهية بتظبطلون ياه على قياسون
# _727\01\بتعرف البقايا ما كان عندي فكرة عنهن اصلا مثلا المحاسبة  فقلتت باختار الاعلام الالي و توكلت عالله
# _728\01\و من هو سلطان الكباش
# _729\01\بعد بكير لك صلاح ما قصدي حتى شوف اتصل لما لا
# _730\01\زوج نادية كمان لما اجا ياخدها وقفوه اشخاص بوادي النيل نزلوه منها بالسيوف لحسن حظه عرفهم بعدين تركوه و الا ما كان نجي و نادية ضلت عنا اسبوعين من الصدمة
# _731\01\انا شخصيا ولادي مؤدبين لما يروحوا معي  ما بيتحركوش بالمرة اما اذا ما كان ابوهم في الدار فما بيروحوش معي بالمرة
# _732\01\ايمت
# _733\01\ي الزهرة
# _734\01\صحي مرعوب مرة تانية و سال مرتو عن الولد
# _735\01\في الكلام
# _736\01\روحت لهناك
# _737\01\لا اليمين لانها بتنمل من اكتر من سنة
# _738\01\مراد نايم بالعسل
# _739\01\و قوليلها انا ارجعنا اتصلنا فيكي امبارح او اول امبارح و لقوا تليفونك مسكر يا نرجس
# _740\01\روح و اشتريلي علبة صلصة
# _741\01\فوق هيك بتعرفي شو
# _742\01\منيح
# _743\01\انا ما وجعوني بس ورموا
# _744\01\انا ناوي اسجل فيه نهاية كانون الاول الجاري بس هو روعة
# _745\01\شبينة العروس
# _746\01\حتى انا شوف شو استعملتو اقل من ساعة
# _747\01\بيكون الحبل مربوط من جهة و التانية في ايدي
# _748\01\ومن شرهن هاد لما كانو طيبين وبحالن قال الله عنهم  ان كيدهن عظيم
# _749\01\بدي اعرف شوية معلومات عن الاحوال الجوية
# _750\01\المشكلة انا واثق انو اي حدا رح يقرا النصائح رح يحس انو كان يغلط قبل هيك زي حالاتي
# _751\01\وانا لما بقول هاد رايي الشخصي
# _752\01\عيشوشة مش حتيجي
# _753\01\انا كمان حفظت كيف نرسمهم
# _754\01\بع
# _755\01\و كنا قاعدين بنحكي عن الاختصاصات
# _756\01\هاي الصورة
# _757\01\ياربي مبلل و انا عم حط هاتفي عليه
# _758\01\انا حية انا باقدر اسامح
# _759\01\تروح على المدينة والا ترجع للدار
# _760\01\نحافظ على هذه النمط شهرين او ثلاثة بنصل للهدف
# _761\01\ايش بتعملي فيه
# _762\01\هديك الحسد حئ بس ما فيك تفسرها هيك ئدر الله
# _763\01\مسا الخير سليمة شلونك
# _764\01\اجى كمال ما بعتش اليوم رسالة العامية
# _765\01\صراحة عنابة صارت سيئة التياب غالية اي شي بتسوميه ميتين تلاتمية اربعمية
# _766\01\ماشي انت بس قول هيك و انا ح افهم
# _767\01\حسب الاختصاص اللي بدك تسجلي فيه فهمتي
# _768\01\شوفتي انه الابيض احلى
# _769\01\تماما و هادا بصلحو انا بعدين
# _770\01\مش عادي اختي او وحدة من قرايبي تحكي مع شب
# _771\01\وتبريرهم لهالموضوع ان الاجداد باعوا الارض وبالتالي اسرائيل بتدافع عن حقوقها او بصيغه اخرى بحقلها اللي بتعمله من انتهاكات
# _772\01\انا بتفق معك انو حب الاب والام حب حقيقي وانو حب الايام هي حب لعب ومسخرة
# _773\01\هي مو عامية مراد
# _774\01\نفس الاشي بالنسبة للثاء والحروف الثانية
# _775\01\فيكي تكتبي الفكرة مو اجباري تكتبيها كلمة كلمة
# _776\01\شو مستني من الحرامية
# _777\01\ما اتصلت غنية
# _778\01\على فكرة الصورة حلوة كتير ممكن اخد منها نسخة لو سمتحي
# _779\01\لازم انا نبدا نتفق على الاقل على الشغلات البسيطة
# _780\01\تضلك على خير
# _781\01\بتعرف اذا طلعت روح المجرم  كيف بيصير
# _782\01\في شغلات كتيرة
# _783\01\امبارح بديت كتابة رسائلك بالحروف العربية
# _784\01\لا بن عمر احسن تعودت عليها
# _785\01\لما تروح عالفحص عند الدكتور بالجزائر جبلها شوية تياب
# _786\01\حاشتري تنتين من النوعية الكويسة و اجيبهم
# _787\01\ممكن يزور موقعنا من اسف كينغ او يا كنغة
# _788\01\شو ما عندون رقم حبيبة
# _789\01\طيب شكرا كتير
# _790\01\بقلكم هي هون و رح تعزمها هي و زوجها هلا
# _791\01\الي بعرف مين انا رح اجبلو سكر جلاب من بلدنا نجع قطيه
# _792\01\وينا ليكا
# _793\01\وقبل ما اصل رن علي طلال الو هلا بندر
# _794\01\المهم قالوا خلص احنا بنروح لشيخ المساطيل
# _795\01\اذا كانت نيتك تشتريه
# _796\01\تبعت
# _797\01\ليش ما بتتصلي وما بتساليش عنا
# _798\01\وبعدين انا بدي انخطف ولا شو
# _799\01\هيها يما كل ما حضرته اجت و حطته هان
# _800\01\اللي بيظلم مرته لا بيفكر في اخته وما يفكر غير في حالو  يعني ما بيهمو لو حدا ظلم اختو ما بيهمو غير حالو
# _801\01\اساعدكم
# _802\01\امتى حيكون تسجيل الجامعة
# _803\01\اه قالتلي انها ترسمت في المستشفى
# _804\01\لما قلتلها انه رجعت فريال اتصلت فيكي و انه رديت على اتصالها قالتلي ما رديتش
# _805\01\سارة لمي اغراضك و روحي نامي وخليني في خالي
# _806\01\بتئلك انو كان عندها بس ضيعت تلفونها و الرقم
# _807\01\حاحطهم في الصالون او في البلكونة
# _808\01\لا مو هيك
# _809\01\لانك رح تعرض لحالك
# _810\01\من زمان كان وليد يقلي صحفيين الشروق رايحين عجهنم مباشرة
# _811\01\هي قالت لا بالاخر تعلم مضر
# _812\01\الحمد لله يا نرجس هيني كنت بحكي مع خالتي مويا قبل شوي و هي بتقولك انه رفيقة بتحاول تتصل فيكي على تليفونك من الصبح بس هو مسكر
# _813\01\اجا من ايطاليا كان عم يدرس بامريكا بعدين رجع لامريكا و بعدين تركيا
# _814\01\عنجد
# _815\01\شكلها كانو بالخمسينات
# _816\01\ايمت اشتريتي هالتياب
# _817\01\شوفي هرهرتي عالتخت
# _818\01\صرت خايفة حتى من ظلي
# _819\01\انا ما بشتريش جريدة الشروق بالمرة
# _820\01\ما سمعتيها من فترة
# _821\01\بالاول اشلح جزمتك في الطريق هذا بالاول
# _822\01\يما ايش رايك نشرب فيه الحليب
# _823\01\بس نجحت بالشفهي و ح تبلش دراسة بعد كم يوم
# _824\01\رح يصلوا شهر تقريبا
# _825\01\مكن يروح فيها لانو مبين اصلا بخيل
# _826\01\عشان الموسيقى جامده طحن فحت وردم
# _827\01\انت بخير سليمة
# _828\01\هديك يلي قلتلك تقريلي الراشتة تبعها تبع التوتر
# _829\01\ملت منا عن جد
# _830\01\اتركيه يا مو هو عم يحاول يئرئك و انت بتسمعيلو
# _831\01\معقول هذا يا بنيي
# _832\01\ايش لونه
# _833\01\كل الشغلات اللي صارت في الفيديو كليب
# _834\01\بس حسب ما شفت استعملوا الترتيب عشان يكتشفوا العامية
# _835\01\انا ما قلت حاج
# _836\01\الرسالة الي من هالنوعية انا بتشرف فيها وبخليها عندي على طول
# _837\01\هيو اول تشرين الثاني
# _838\01\ووقت بكون متضايقة بشوف الشفقة في الناس
# _839\01\قال الرجل اثبتلي ان الله موجود و انا ما بامن بالقضاء و لا بالقدر
# _840\01\بدي صر خ
# _841\01\وانتبه على حالكم العفريت عم ينصح كل واحد بسيارة وحدة بس
# _842\01\طيب مافي مشكلة
# _843\01\هاي كمان مشكلة
# _844\01\انا شفتها تمانية بس رح قول شو رح تنزل المرة هي مروان
# _845\01\انتي وين بعدين ما شفتك
# _846\01\وعلى صوتو شوي وقلو قدامك شجرة كمان ما رد عليه
# _847\01\بدكون ياها تصير بالاجباري مو عربية
# _848\01\وانا مصدقك في نظام حماية بالمنتدى
# _849\01\بتعرفي حتى لو الجمل مو مرتبة فهي مو مشكلة
# _850\01\كل اليوم و نحنا عم نتفرج عالجزيرة
# _851\01\لو تقوليلي العنوان
# _852\01\اه اقولك تصبحي على خير
# _853\01\ما بعرف انا طالعة جهز البنت و جايي
# _854\01\ابن خالتك
# _855\01\مو انيس الي كل ما بتجي الطابة على رجلو
# _856\01\قلتلك من ساعتين و احنا معهم
# _857\01\السلام عليكم
# _858\01\بتريحني وبتبعت على قلبي صبايا
# _859\01\لاني ما عنديش وحدة
# _860\01\اسال الله ان يهديها بتعرفي غابت كتير انت ما بتخاف ان يبطلوها
# _861\01\كنت ناطرك
# _862\01\اي فيني
# _863\01\بس لازم روح عالثانوية مشان عالاقل طالع كشف علامات البكالوريا
# _864\01\بتنتقلوا من غرفة لغرفة هيك و بتطلعوا عالاستراحة دائما
# _865\01\مش هان هيو بيدرس
# _866\01\بتذكري لما فتنا اول مرة قلتلك يا سوسن هاد مسلسل حلو عم ينبث عالساعة 8 بابو طبي شوفيه
# _867\01\اول شي اشلح من رجلك
# _868\01\يا مختار خليني اشفي فيه غليلي
# _869\01\تعي و بس وقعت و مشي الحال عم امزح معك بس
# _870\01\جهزتلها فراش و بعدين تصدقوا فيهم قالها مش حنعيش هان هلقيت
# _871\01\العين الحسد
# _872\01\هو انت قادرة على التدريس
# _873\01\اي صح فكرتك عم تحكي عن شبابنا
# _874\01\منضل معتمدين عاللياسمينة بس
# _875\01\شفتي مزبوط انا ح احضر عرس عبد النور
# _876\01\كانه جامعة
# _877\01\و انت ايش احوالك
# _878\01\بعد تسع سنين وكانت تطل على الشباك شافته مرة تانية
# _879\01\الكشري بدون عدس وغرقان بالدقة
# _880\01\قالولو انو متوحش كتير ما شفت شو ساوا بالكلب
# _881\01\ليش ضربتو
# _882\01\البناطرين اللي رح تسلت و الشعر المجعد
# _883\01\انظروا الو تبعت عائشة
# _884\01\متل الصينين واليانيين الي ما بيسمحو بالقشيش هي ابدا
# _885\01\لان ما عندي وحدة
# _886\01\حطهم في كيس
# _887\01\الله يعينك يا رضوى
# _888\01\هيك انا بلاقي صعوبة في الكتابة
# _889\01\ولد واحد ريتون لو كانو تلتاربع ولاد ترك ولد
# _890\01\هذا كلاشينكوف
# _891\01\شكرا استاز جمال وبتمنى ما تغيب عن الكتابة
# _892\01\احنا كبرنا يا زلمه دايما جاهز
# _893\01\لساتك تزار زي الاسد
# _894\01\بنمهيدي
# _895\01\قعدت بقاعة الانتظار و لاقيت كتير مرضى
# _896\01\عشان يطقو حنك ويجيبو سيرة الاكابر وبحقدو
# _897\01\حتى الاستاذة لما قلتلها قالتلي ما بتقدريش تعملي اشي تاني هذه الطريقة الوحيدة
# _898\01\انا عندي ما اتجوز ابدا احسن من جيزتي من واحد يغلبني وينكد علي عيشتي
# _899\01\امسح الثلاجة
# _900\01\صح عشرين الف مو مشكلة عادي رح اطلبهم
# _901\01\ايا حدا في يحضرلك ياه
# _902\01\لانو سرك كبير رح انسى هبلك
# _903\01\لا ابدا بالمرة
# _904\01\انت انت بتعرف انك عملت اشي
# _905\01\بيدا هونيك
# _906\01\مريم و الزهرة و ليليا و اخواتها و وردة و البنات
# _907\01\انت رح تدخل الجنه وانا بدخل النار حتى لو عملت نفس الحرام اللي انا عملته
# _908\01\و في منهم مستوى نهائي بيشتغلوا احسن مني بشكل عادي
# _909\01\مو مشكلة روحي جيبيا
# _910\01\والكل كان عم يضحك
# _911\01\ممكن اعصب لدرجه عاليه جداا
# _912\01\سليمة عم تنقلي المدونة بشكل منتظم
# _913\01\مش عارفة مراد لازم انا نحكي فيه كلنا
# _914\01\اهلا انسة ميودة اولا انتي لسا صغيرة عالجيزة
# _915\01\وكمان بتزانخ عليهم
# _916\01\لما رجعت قلتلا شوفي شو عملت فيني لك صباح كان رح يروح عليي الباص
# _917\01\ديروا بالكم الشيطان شاطر كل واحد سياره وحده بس
# _918\01\صباح الخير مين معي
# _919\01\صحي مرعوب و سال مرتو عن ابنو
# _920\01\بعتقد انو خاص  ستيك
# _921\01\فهمتك احتمال انه الها علاقة بالاعصاب
# _922\01\و انا اصلا هذا الاشي عشان يسمع الناس اني خطبت
# _923\01\لا منيحة
# _924\01\يا بنتي الي ئرصته الحية بخاف من الحبل
# _925\01\بنكتبها بس هيك ما بصير انو يبقى في موضوع اسمه عرف عن حالك وكل مشترك جديد بالمنتدى يعطينا ولو شي بسيط عن حياته
# _926\01\البروسيدنغ بتسميه الكتاب ولا المحضر
# _927\01\سندريللا بالله عليكي ما تجننيني اكتر من هيك  القصة بدهاش الهام شاهين
# _928\01\تفاجظات من كتر الردود الموجود في هالموضوع
# _929\01\بتعرف في نص ساعة فرق يا عشرة و نص ويا ادعش
# _930\01\كل برج و شو اهم ملامح شخصيتو و الابراج اللي بينسجم معا
# _931\01\احيانا الواحد بشوف الي قدامو زي ما هو بدو  خلال الفترة الي رح تفكر فيها ما لقيت
# _932\01\بخصوص هي انا حكيت مع عامل الاستقبال و ئلي لازم كل خميس
# _933\01\حكيت مع اخوتي الكبار كمان من دون فايدة
# _934\01\انا ما كنت بالبيت ما بعرف شو اخر الاخبار
# _935\01\حكيتلك عنا من قبل
# _936\01\و هو بينحسب اختباركم والا ايش
# _937\01\ولعيبة الزمالك رح يحاربو مشان يفوزو
# _938\01\لحالكون
# _939\01\ولازم نلقي نظرة على هالمدونة لناخد الامثلة
# _940\01\لازم تعرفوا انه جامعتين عربيتين مشاركين  انتو و التانية من الاردن
# _941\01\ماني من الوسط الموسيقي
# _942\01\لما جربتا جربتا فوق الجاكيت
# _943\01\قالولنا نخلص المكيفات و على حسب ما بعرفش هل لما نوصل للثلاجات نوقف والا يقولولنا تعالوا بكرة عشان تخلصوا المكيفات
# _944\01\منور المنتدى يا معلم
# _945\01\ما بتابع نشرة الاخبار كتير و ما بعرف اذا طلع كتير او قليل
# _946\01\شوفت فيلم روعة شوفتيه
# _947\01\صح سليمة واضحة مية بالمية
# _948\01\اجى علينا زمن صار فيه اللي بدو يثقف نفسه يروح للمكتبة او يعمل ابحاثه على شبكة الانترنت
# _949\01\يا جماعة ما تخلو الردود بس مشجعة خلوها كمان اضافة جديدة ومتعلقة بالموضوع
# _950\01\هو بيمثل منيح
# _951\01\قالي الشغل اللي بشتغله فكري و اذا اجيتي عشان ادرسها و ما عرفتش احتمال اني اصرخ في وجهها او اضربها
# _952\01\ومريم عم تحضر دكتواره
# _953\01\شكرا لمرورك اختي العزيزة جعفرية علوية
# _954\01\باي لهجة
# _955\01\لو ضل معو اشي زيادة بجمعها للظروف
# _956\01\وين وين رايح
# _957\01\مشان اقدر اعرف انا غلطت بشو
# _958\01\ايش اعمل يا بنتي يا سارة وراح اعمله على طول
# _959\01\انقلاب مكتمل الاركان
# _960\01\لا بس البرنامج بيعمل هيك لحاله والا انت
# _961\01\بس بضلني محتارة لحالي بقول يعني لو ما كان في هالعقود فهالشغل كلو حتساويه لوحدا
# _962\01\انت بتعرفني اذا لقيتني بكرا الصبح اعطيني اياها الصبح
# _963\01\ايامنا عشنا اللحظة بتفاصيلها و كل حدث يصير النا قصة و فيلم موثق و الف حكاية و رواية
# _964\01\سالو شوفير مين بتحب من المغنيين قال مازدا الرومي مايكل داتسون اسكودا الشمالي
# _965\01\امي قالت بيشتغل بالمحافظة
# _966\01\اما واحد من التونسيين لما تجوز مرة تانية اكتشفت مرته الموضوع فرفعت دعوة ضده
# _967\01\هو شخص شاطر باختصاصه و بس ينتقدني رح ينتقدني باشيا بستفيد منها اما ناجي فهاد مو اختصاصه ما رح ينتقد غير الغلاف و ترقيم الصفحات
# _968\01\طيب
# _969\01\خليني امر ايش عملتلهم
# _970\01\حتى صباح قالتلي انه الاستاذ اللي اشرف عليها السنة اللي فاتت كان يقولها بطلي تقليد سكان عنابة من البسباس و راح تظلي من البسباس
# _971\01\على فكره اللي بعرف انا مين بجيبله معي سكر جلاب من بلدنا نجع قطيه
# _972\01\شوفي هذا كل الله فهمه من الدرس
# _973\01\يمكن هالصابون سببلي حكة
# _974\01\مش معقول هذا
# _975\01\نظام لمد قصة تانية
# _976\01\ما ضل في مهرب من الموضوع
# _977\01\وحتى الولد سيد مدرس اللغة العربية في الكفراللي جنبنا
# _978\01\اذا هان حياخذها عنده
# _979\01\جد الف الف الف شكرا
# _980\01\وفعلا بصير لانو الارض خصبه
# _981\01\شو رايك
# _982\01\والله بدون مجامله يا عمرو انت مخرج عبقري
# _983\01\احنا بنستنى
# _984\01\بعطيك عيوني معهن
# _985\01\ما اجوش لسه
# _986\01\دفعت التمن غالي
# _987\01\اكيد انه هذا نوع من التسويق
# _988\01\من امتى عملت العملية
# _989\01\امريكا اول وحدة تعلمت درس من اشرف السادات
# _990\01\هاد يلي قدمك هلق ما في حدا بيحب امه قده
# _991\01\ليكي بدي قلك شغلة بلادنا ما بتنفع للشغل
# _992\01\زي ما بتعرفي لا جديد
# _993\01\نام اخوي وحاولت انو انام
# _994\01\ايمتا راحوا حتى انون ما تغدوا
# _995\01\مساء الخير سليمة  كيف حالك
# _996\01\خاصة لما بعيشوا التخلف ببلادهن
# _997\01\الله معكم
# _998\01\صرنا نعاني من ظاهرة جديدة بالمدارس و هي ظاهرة الاضراب
# _999\01\مثلا بوتفليقة محبوب من الكل
# _1000\01\لساتها بتدرس
# _1001\01\يمكن يكتبوها بالجريدة كمان
# _1002\01\في كل اليوميات
# _1003\01\لا تقوليلي انا اللي حسدتك
# _1004\01\انت لسانك طويل
# _1005\01\هو اللي قالي انه بيحب القانون الدستوري
# _1006\01\اكيد الحب جاي على الطريق ومش رح تستني كتير
# _1007\01\هذه
# _1008\01\عفوا اذا بتريد
# _1009\01\بدي شوف مقطع هالفيديو
# _1010\01\مزبوط معك حق سليمة
# _1011\01\بهالطريقة كل كلمة منرجعها لاصلها بالعربي
# _1012\01\اه مزبوط فكرتك بتحكي عن شبابنا
# _1013\01\كل واحد اله شغله ما في حدا بيوخذ شغل غيره لا الزلمه بيوخذ شغل المراه ولا العكس لانو الله سخر لكل انسان قدره معينه
# _1014\01\شو قالولكو
# _1015\01\يا ريت نصلح القطار  بس مش على حساب الفقرا الي بستخدموه
# _1016\01\اه جوزها شب مات لما راحوا لصلاة الفجر
# _1017\01\يرجع صدي صوتك ويرن ف وداني اسرح وادندن فيه واعيده من تاني
# _1018\01\ما صنفوها
# _1019\01\لا مش للصغار
# _1020\01\فراح عالمحامي
# _1021\01\ما فيش واحد خطه مزبوط
# _1022\01\ما تخافوش حشرد منهم ما تخافوش
# _1023\01\لا عن زين الهاربين
# _1024\01\قدمتله عرض
# _1025\01\وان شاء الله رح تكون كل ايامك خير وسعادة
# _1026\01\وين راح اسامة سمعته بيفوت
# _1027\01\قالتلي اخت شمام كيف حالك قلت بخير و الحمد لله
# _1028\01\صدقوني اني رحت اليوم عالجامعة غصب
# _1029\01\مع ايماننا هادا فليحفظنا الله
# _1030\01\بتكون النتيجة انو ذكائو عالفاضي
# _1031\01\و حطيت فيه شريحة موبيليس
# _1032\01\الحب اشي كتير كلو
# _1033\01\ما صارتش جرائم زي هذه في تاريخ البشرية كلها
# _1034\01\وبتذل في مين
# _1035\01\كمال كان على الانترنت  ما حكاش معك
# _1036\01\اي ماما
# _1037\01\فهمت منيح ولا اشي
# _1038\01\كتير حلوة
# _1039\01\اي وحدة
# _1040\01\اي صباح الخير
# _1041\01\ويصير الي يصيير
# _1042\01\لاقيت موقع لمنتدى فيه 362 صفحة امثال شعبية حملتها و رح عالجها
# _1043\01\اه السيارة الحمراء
# _1044\01\من ايمت
# _1045\01\اه يا الله لو اني كنت باعرف لوصيتك انك تساليها عن فساتين على مقاس اماني
# _1046\01\وين
# _1047\01\كيف و هي اللي بتربيه في حضنها و يفتح عينيه على وجهها
# _1048\01\و اسماء شوفتي قديش قاست قديش قاست قديش قاست
# _1049\01\احسن من قبل
# _1050\01\عندي تطبيق
# _1051\01\اه بادرس
# _1052\01\بالنسبه الي بتوقع انو الوضع رح يتغير للاحسن
# _1053\01\هاد منيح
# _1054\01\مساء الخير كمال
# _1055\01\هما يبقولوا انه انخطف من هدولاك
# _1056\01\اضرب من المغرب فكروا فيها
# _1057\01\حمزة كيف حالك
# _1058\01\كانت قاعدة لحالها و مزعوجة و جعتلي قلبي
# _1059\01\بتدرسي بالليل
# _1060\01\اما امي فلما تروح على دار ستي بتطنشك عالاخر و لما تتصلي فيها مع السلامة
# _1061\01\لما بوصل عالمدينة بحكي معك
# _1062\01\صدقيني ما بعرف وين كانت
# _1063\01\في ميدان عام بدون محاكمة رح تلقى كلو اتقي الله وما في حدا رح يغلط
# _1064\01\ان شاء الله على الوحدة و عشرين دقيقة
# _1065\01\و كل يوم نفس الموضوع
# _1066\01\وانو كان  قاعد بيدرس عند العامود
# _1067\01\الحب جايلك في الطريق وما بتستني كتير
# _1068\01\من امتى
# _1069\01\قصير من قدام بعدين بيبدا يطول
# _1070\01\حسبتكوا لحالكوا خفت عليكو من الغول
# _1071\01\ليش  مشكلة في الاتصال
# _1072\01\في متل مغربي بحبو كتير
# _1073\01\هاد الي بتعرفه بس الزنار
# _1074\01\القبر مكتوب على كل البشر
# _1075\01\فوتي على بيتكن يا بنت صار ليل
# _1076\01\بتذكر هالشي
# _1077\01\هو اقصر مني
# _1078\01\بالاول كنت مفكرة انون رايحين زيارة عادية و انون رح يخطبوا بعدين
# _1079\01\و لا تتوقعي بكرا حدا يصرف عليكي
# _1080\01\شهر ليش شهر ما هي مش صور اشعة دقيقة
# _1081\01\اه
# _1082\01\فوتي على داركم يا بنت اجى الليل
# _1083\01\شبك ركز بلمكان
# _1084\01\اي الجزائر العاصمة كبيرة كتير و سكانها كتار
# _1085\01\اي ممكن مثلا توصل عالعشرة ماكسيموم و بعدين تجيب ابن شهرة من ادام المدرسة فهمت
# _1086\01\ما بخفى عليك اشي
# _1087\01\في خمس الوان روعة روعة روعة
# _1088\01\وين ح يساووا العرس
# _1089\01\صدقني انا ما باصلي و الصلاة بتاثر فيك اكتر
# _1090\01\ولو كان ما بينفع ممكن يكون في كمان ميعاد للشباب
# _1091\01\بكرة اذن على التنتين ونص
# _1092\01\في وحدة روعة هديك اللي كلمتك عنها
# _1093\01\هداك اليوم ايمتى ياربي مبارح الاربعاء و اللي قبله التلاتا طفيت الضو و غمضت عيوني و شغلت بس التلفزيون ليونسني ما كنت عم شوف شي
# _1094\01\و هي حترح عند ربيعة رحمها الله
# _1095\01\شو ليش
# _1096\01\الحقيقة انو مابصلي كل يم
# _1097\01\سجل في منتديات المحترف وشارك معنا بارائك
# _1098\01\استنى ما فيش بحث هناك
# _1099\01\ليش هيك يا بطوط ماشى ياستى الله يسامحك
# _1100\01\لبسته
# _1101\01\الله يعينك ع لسانو
# _1102\01\بضرب اذا استاذ ضرب زميلي
# _1103\01\يا اسلام احسبها صح بتسافر صح
# _1104\01\و ايش دراني
# _1105\01\ما رضيتش اني اقولك قولي لمفيدة اجيت ادور على رقمها و ما لقيتوش
# _1106\01\وينن صرت بمشروع دراستك
# _1107\01\في الفايسبوك بيقولوا انه حسام راح يعرض
# _1108\01\وهمت وعصمت
# _1109\01\احتمال يجيبوا الاسبوع الجاي شغلات جديدة روح اسال
# _1110\01\وبيجي اخي او اختي لينط على هاد الحبل
# _1111\01\كنت رح تطحشي برؤوف عالسبعة
# _1112\01\بظن بعدين لازم نكتب الترجمة بالعربي اي موافقة لك سليمة
# ...
# _15432\01\بس هيك بين كاني غبية
# _15433\01\بس هوي زلمة
# _15434\01\شفتي شلون بينتبهوا
# _15435\01\حتى هي اللي جوزته
# _15436\01\ما درستش بالمرة و انا مبسوط
# _15437\01\اه ليش لا
# _15438\01\الا انا حنطشر من اولها  ولما يجي عيد الاضحى بيتوقف كل اشي
# _15439\01\البيضاء حلوة اه
# _15440\01\حكيت معهم كتير مزحت معهم كتير بس ما حكيت عن الاسلام
# _15441\01\دائما لما بتنخطب شي وحدة بيقلولها العاقبة الك دائما بمر بذهنها الشخص يلي شافته اول مرة
# _15442\01\ما في بايده شي
# _15443\01\حز بنفسي صحن الحمص و العزيمة عالمطعم
# _15444\01\قالتلي انو السنة الجديدة لازم تدفعي ست شهور
# _15445\01\امي ايش حتعملي اليوم عالغدا
# _15446\01\سمعي لبيبة
# _15447\01\الكل بيعرف
# _15448\01\هذا
# _15449\01\رحت عشان التحليل
# _15450\01\اما نحنا فكل اسبوع رح اطلع و شوف
# _15451\01\بينقال انه عنده اشي في جبهته بيشوفها المؤمنين بس اما الكافر فلا
# _15452\01\الي حضرتو الكم يوم وربع اولا محمود حميدة زلمة ما الو حل
# _15453\01\كيف قريبتو مش ملتزمة
# _15454\01\مزبوط سليمة مفهومة مية بالمية
# _15455\01\صدقني مش عارف
# _15456\01\في كتير اشياء بتحكيلنا نسكت وبتوقفنا
# _15457\01\فيلم غريب وبجنن
# _15458\01\حلو كتير يا ست قطر الندى يعني انا رح اتجوز وحدة جوهرة
# _15459\01\وهو فرد بس باذن الله في الكليه ممكن
# _15460\01\لا اصدي كل شي الشغل بشكل عام
# _15461\01\قبل رمضان
# _15462\01\ورفع صوته وقال قدامك شجره وكمان ما رد عليه
# _15463\01\لح حطون بالصالون او عالبرندا
# _15464\01\هو حر يزيد عليها و يشتري دار
# _15465\01\و هلقيت ايش هي التمارين اللي اعطوكم اياها و ايش حتعملوا بكرة
# _15466\01\وفي النهاية انت بتستحق اكتر من هيك بكتير
# _15467\01\برافو عليكي
# _15468\01\بابا
# _15469\01\اي خليكون عم تدوروا
# _15470\01\بينادوك في كل مكان مرة انزلي لتحت
# _15471\01\و انتو بخير لكن
# _15472\01\ويا ريت لو انها بنت الحج فلان
# _15473\01\انا بعرف انو هاد الموضوع بفرق معك كتير
# _15474\01\شي اربع خمس سنين
# _15475\01\ماشي و قولي لحورية مرة تانية
# _15476\01\خاصة اذا ضربوه  ان شاء الله يصيرله زي ما صار للقذافي
# _15477\01\صرت خايفة من خيالي
# _15478\01\احتمال ان يعملوا مسابقات
# _15479\01\لاصحابهم
# _15480\01\بس امراض النفوس الارواح الي رح تشوف ربها
# _15481\01\اه طيب لاني اتصلت فيكي الصبح اتصلت فيكي في جيزي و اتصلت فيكي في موبيليس
# _15482\01\المادة معاملها 1 بيفضلوا يعوضوا
# _15483\01\مانا الكون
# _15484\01\استعملته من قبل يعني انه عندي فكرة عنه
# _15485\01\مزبوط بس مش متذكرة شوفتها مرتين او ثلاثة بس مش متذكرة
# _15486\01\بس هما مزعجين بضلني ارفعهم خاصة في المكتب اتخبى في الزوايا عشان ارفعهم بدون ما يشوفني حدا منهم
# _15487\01\حكالي تتجوزها ولا اسجنك 20 سنة
# _15488\01\ليش ما بعرف
# _15489\01\شو نساوي هلق
# _15490\01\خدي
# _15491\01\بس ضيعت وقت كتير
# _15492\01\مع اني سخنتها قبل شوي بس
# _15493\01\عندي ملاحظة سليمة
# _15494\01\فهموني عن شو بدنا نحكي
# _15495\01\صاروا يجروا وراهم في الغابة و ما قدروش
# _15496\01\متى ما كان في ريحة لما تنام بيقولوا انو البكتيريا بتسبب ريحة التم
# _15497\01\اما السؤال الثاني
# _15498\01\احدعش
# _15499\01\اعطيني علبة السكر يا سارة
# _15500\01\بعدين رجعت اتصل فيكي حوالي تسعة او عشرة اتصلت بس ولا اشي
# _15501\01\لا ما نجحتش
# _15502\01\مش بعيدة كريمة
# _15503\01\كيف حاكتبها
# _15504\01\وكل اللي بدك اياه عشان تصيري جذابه قدروه صاحباتك
# _15505\01\مزبوط مزبوط بتمر عليكي اوقات لازمك تفضفض لشي حدا
# _15506\01\العشرة ونص او شوفوا اللي بيناسبكم
# _15507\01\قلتلها اف عليكو
# _15508\01\قالتلي البنت انو غالي كتير قالتلي الي عم يبيعوه لحم بغال بتعرفي البغل مو هيك
# _15509\01\لما يخلص العقد جددي عقد تاني عند الخاص
# _15510\01\بيسكرو عالطنعش و بيقتحو وحدة
# _15511\01\لما يجي حاقوله انه راح
# _15512\01\بس هي المسكينة ما قبلوش ملفها
# _15513\01\قلي بحكي روسي و كتير لغات
# _15514\01\متخيلين 7000ريال الناس كتير جدبة  بتفكر انو هاد حقيقة بس لاسف
# _15515\01\انا حطيت كلمة سر صعبة كتير
# _15516\01\هادا الارق بينقال انو بيتعب كتير و ما بتقدر تنام
# _15517\01\ايش قالت
# _15518\01\شوفته زي هيك قلت انه حيساعدني قالي انت صديقي ما تقلقش اخاترني وبس حاعملك التقرير بسرعة
# _15519\01\وفي الواقع هما بيحاولوا كمان انهم يقضوا على حزب الله اللبناني  ما نسيوش خسارة اسرائيل في الحرب الاخيرة
# _15520\01\المفروض انه في الشتا من كترة الاواعي تشتري وحدة مقاسها كبير
# _15521\01\الي مقتنع في اني ما بشتغل معهم ابدا
# _15522\01\رح نحطلك اغنية بحبك ياحمار
# _15523\01\طيب مو مشكلة بس هدوك القناني كتير صغار
# _15524\01\رح حاول
# _15525\01\اه
# _15526\01\قلهم مرتي بتشتغل و ما حدا بيتدخل مع انو عندهم المرا لا بتدرس و لا بتشتغل
# _15527\01\نتشارك بفكرة
# _15528\01\اسمعي بتقلك عقيلة انت اتصلي بحورية و بنتها
# _15529\01\رح تلائيها رح تلائيها
# _15530\01\حكالي هاي ام هريدي يا بيك
# _15531\01\قلتلا روحي و بس
# _15532\01\يعني بيعرف كل شي
# _15533\01\لكن اتصلي بستي عندها تلفون
# _15534\01\اكيد رح حطها
# _15535\01\قلا بعرف ما خلينا دوا ما اشترينالا ياه
# _15536\01\وبيعرفوا نعمة الصحة الي عم يضيعوها
# _15537\01\لا لا شبيهو
# _15538\01\و قديش بتكلف رحلة لباريس مثلا يا سارة
# _15539\01\موضوع تاني بعتقد انو لازم نكتب الواو مع الضمير احنا لهالسبب حطيتو بهي الرسالة
# _15540\01\ياربي ليش
# _15541\01\ما اجيت
# _15542\01\نحنا عاملين متل العرب اللي بيعرفوا انهون لازم يتفقوا و ما بيتفقوا
# _15543\01\شيماء حامد شو الحل
# _15544\01\قالتلي الانسة في وحدها شعرها مليان و قالب ابيض من كتر القمل
# _15545\01\اي بس ما عم يرد معناها مو هون
# _15546\01\احسن من قبل
# _15547\01\لا تقوليلي لساته عندك
# _15548\01\بتبين هيك يعني درس بالجامع و بالمدرسة الفرنسية لهيك شنتايتين
# _15549\01\بنت خالي محمد
# _15550\01\بتمنى حد يجاوب عليه  جد نفسي اعرف
# _15551\01\عشرة بالظبط
# _15552\01\كل سنة يجيب الحيوانات و يقاتلها لما كبر هدولاك الاخوة اللي بيشتغل في السيرك و التاني و لا بيعرفوا انهم اخوة
# _15553\01\تابعتو وانا مصدومة وهو بمشي عكس الشرع بهدوء وثقة غريبة  ما اتطلع وراه عشان يشوف شو رح اعمل
# _15554\01\اذن تصبحوا على خير ان شاء الله
# _15555\01\باي ساعة رح تكملو انتو
# _15556\01\لانو اذا ما اجا بيضل بمكانه بيشرب حليب او بيتعشى و ما بيتحرك حتى يروح
# _15557\01\حاعطيك واحد بيفهمه عنجد بتعرف الطاهر
# _15558\01\احسبي فرق الساعات بين اذان العشاء و اذان الصبح بعدين قسمي المجموع على ثلاثة و حتلاقي النتيجة
# _15559\01\الخط هو الكتابة ما بتاخذوش فيها تمنية من تمنية
# _15560\01\دئيت ل مويا على الارضي ماعم يشتغل و ما عم يرن
# _15561\01\ماشي
# _15562\01\الصورة كتير حلوة ممكن اخذ منها نسخة
# _15563\01\بظن معك حق كل شو بيجي و بيروح
# _15564\01\بتعرف شو هذه صعبة كتير بيلزمك خمس سنين من الدراسة
# _15565\01\من ثلاث او اربعة سنوات كبت عليها اختها مية سخنة
# _15566\01\مش عارف ليش المستوى في النازل
# _15567\01\ما تقولي انك بتبعزقي
# _15568\01\اول شي كيف يسقط
# _15569\01\لالا ابدا
# _15570\01\حطي فاصلة بعد كلمة بتقاتلوا
# _15571\01\اجيب الحليب
# _15572\01\المشكلة وين اخي مو هون
# _15573\01\يا اما بتفهم او بتفرجينا عرض كتافك
# _15574\01\انت متاكدة انو انضرب سليمة
# _15575\01\اكيد الطلاب
# _15576\01\مبينة سهلة كتير حاجربهم خاصة هداك الحلو
# _15577\01\انا الحمدلله من النوع اللي بصبر وبالي طويييل عالاخر
# _15578\01\لا تهمي بيها هي دائما زي هيك
# _15579\01\كل اشي تمام انت محظوظ
# _15580\01\وتروك كتابتي لتعريف شخصيتي فوق
# _15581\01\رح قلك شي خالتي زينب هون هلا
# _15582\01\اه اي مناح
# _15583\01\بوتفليقة في كل الرؤساء
# _15584\01\لما قلي انت اللي جبت احسن علامة تفاجئت
# _15585\01\صدقيني انا عم اشترط هلق
# _15586\01\بخير
# _15587\01\الحمد لله على كل حال كيف هما الاولاد
# _15588\01\عادي انه نحكي عن مسلسل
# _15589\01\لازم انه تترجم مراد
# _15590\01\الا اللي ايمانه قوي
# _15591\01\مو حب ممكن يكون احتاج للحب مو اكتر
# _15592\01\رشيدة رشيدة انت حلوة يالله عجلي نحن ناطرينك
# _15593\01\بتختاروا الرياضة والا الطب
# _15594\01\طيب
# _15595\01\اكيد انك حتكلمي استاذ
# _15596\01\هو حر بزيد عليهن و بيشتري بيت
# _15597\01\هو في حريه في اي متر في هالبلد ولا حتى في ربع متر
# _15598\01\مشان يسالوه ويحكوا معو وهيك
# _15599\01\يا رب ثبت قاواوي
# _15600\01\لما ببدا تشغيله بيخرب
# _15601\01\اي معك حق بهالشي
# _15602\01\بس يارب ما تطلعش الجوائز
# _15603\01\ليش عم تدوري على نوال
# _15604\01\احيانا الواحد ما بيكون معو مصاري
# _15605\01\لسا قدامي وقت لحتى اوصلك
# _15606\01\كاني ما بفكرش في غيرهم
# _15607\01\حتى هدول ما سلموش منهم
# _15608\01\بس اذا كان الواحد متمسك بدينه ايش اله دعوة في الناس التانين
# _15609\01\اهلين فيك سليمة
# _15610\01\بديت بالحفظ من اول درس درسناه
# _15611\01\عنجد
# _15612\01\طيب
# _15613\01\حسبي لحالك
# _15614\01\انا بدي انه ربنا يعطيه ولاد
# _15615\01\السبعة
# _15616\01\كلام الاب هو اللي بينفذ و الجيزة راح تكون غصبا عني
# _15617\01\هي هيك بتبقى بتطلع على واحد وقف وراك واكيد هو شافك
# _15618\01\طيب اسمعي قولي لحورية انها تعطيكي رقم تليفون حبيبة
# _15619\01\اي
# _15620\01\بالصدفه كان لارمله راجعه من دفن زوجها
# _15621\01\لازم تفوتي بمخاخون لتفهمي انون ما بيفهموا شي بيتابعوا و بس
# _15622\01\اما هي كلما طلعت لقطة حلوة بتبلش اسئلة
# _15623\01\وقلنا نحنا وين هي هالبنت
# _15624\01\تصبحي على خير ان شاء الله
# _15625\01\العظيم  ليش بيمشي هيك الله يرضى عليك
# _15626\01\راح باع الحمار بخمستالاف دينار و حط من جيبتو خمسطعش الف و دفع الغرامة
# _15627\01\بيلزم انك تعملي هيك كل يوم و تسجلي و ما تخليهم يحسوا لما تسجلي
# _15628\01\المهم انو تكون ارادتك قوية
# _15629\01\امين يارب
# _15630\01\وبعدين منقعود ادام الصوبا و مناكلو مع الخبز اللي بتساوي انت
# _15631\01\مو مشكلة رح اخد صورة معهن
# _15632\01\هان ما حدش بيعرف قصتك
# _15633\01\لا هذه لا هو في حد ذاته غبي
# _15634\01\اي اوراق هذه
# _15635\01\اي لو سمحت اعزميها ليش لا
# _15636\01\جميل ليشب تحذف تعليق انت كتبتو  انت ما بتامن بالراي والراي الاخر
# _15637\01\القصة هيك بنستفيد منها
# _15638\01\ما بعرف ليش بتحزفلي المواضيع وحذفت قبل هالمرة ومش عارف السبب
# _15639\01\انا و امينة
# _15640\01\قبل شوي قضيت ساعتين على الانترنت لتنويع المدونة كلامنا اللي هو كلام علميين وكمان الاحترام المتبادل فيما بيننا  بمنعنا من نحكي في عدة امور
# _15641\01\اللي انا مش قادره افهمه كيف بكون معك زميلك في العمل والمدير موجود
# _15642\01\تخصص شبكات
# _15643\01\في التلفزيون دائما بيقولوا الجزائر بيضاء مزبوط
# _15644\01\من الاطنعش و فوق اللي بيحاول يفوت مش حارحمه
# _15645\01\قلت لحالي ما لا بالعادة عيشة تساوي فيني هيك
# _15646\01\الحمد لله اني رجعت
# _15647\01\بشوف
# _15648\01\وينا سارة
# _15649\01\اسكتي
# _15650\01\ههه على كتابتي ورثة ابليس بتشرفني زيارتكم
# _15651\01\بس بتعرفي ايش المفروض وظيفة نائب مقتصد
# _15652\01\الاسد ما بيجعر الا ببابك يا امي
# _15653\01\انا نسيتك  انا سمعتك  عشت حياتي بستنى لمستك
# _15654\01\الصعيدي قلة انت بتعرف كيف
# _15655\01\ما عنديش اي فرق
# _15656\01\بيحبا متل بنتو
# _15657\01\وان شاء الله بتيجي وبتحكيلنا عن روحاتك وجياتك جوا قاعات المحاكم بكل مصر
# _15658\01\شو اسما
# _15659\01\طلعت شم شوية هوا رجعت ميتي من الخوف
# _15660\01\صباح الخير
# _15661\01\ليش
# _15662\01\لازم تحمسيهون
# _15663\01\اه قالتلها تضيقها من هان و من هان
# _15664\01\ومع نظام لمد بكمل الحساب
# _15665\01\دائما بيطلعوا من الاصبع الصغير
# _15666\01\وشو الفرق
# _15667\01\يمكن كمال خاصة اني اشبهها في كل اشي ليش لا في الغناء
# _15668\01\مبالي القانون مخصص بس للادبي
# _15669\01\شفت لو نمت بس روحك بتطلع عالسما
# _15670\01\كمان خالد و مرته بيعرفوا
# _15671\01\سوداء و بيضاء
# _15672\01\حتخيطها نصيرة
# _15673\01\و هلقيت اجيتوا عشان تتفرجوا
# _15674\01\كيف حالك وشو اخبارك
# _15675\01\كان حامل بايدو ابرة تخدير مديتلو ايدي
# _15676\01\مع شوية حفظ و شوية مراجعة كل شي بيكون تمام انشاء الله
# _15677\01\يا الله ايش عمل فيا من الصبح
# _15678\01\نبدا بالامور الظاهرة
# _15679\01\كل اشي بيموت و هو مسلم
# _15680\01\طلع انو في عياشي تاني عندو دقن
# _15681\01\بتعرفي ان كندا سهلة كتير خاصة اذا كنتي متزوجة او متزوج بالمستقبل
# _15682\01\انا شخصيا مستغربة كتير
# _15683\01\بخير
# _15684\01\عمر
# _15685\01\كتير قليل الشباب الي واصلين لدرجة النضج والتدين هاي
# _15686\01\وكثير انظلموا وعاشوا مخدوعين
# _15687\01\قالتلي الجزائر سجلت ضد الجزائر
# _15688\01\لا هو ما عندوش اي مشاكل لو كانو اخوته التانيين لقلتلك
# _15689\01\شو جابك لهون
# _15690\01\لا لبسته و اجت فيه عشان تبين طويلة
# _15691\01\امي بلال دخل مركز التكوين المهني و هلء عم يدرس ما هيك
# _15692\01\اهلين فيكي
# _15693\01\طن كلام ابن عمي بادني و قررت اشتريه خصوصي انو ما كان غالي
# _15694\01\قال انه حيبعتلنا الاواعي
# _15695\01\ايش يعمل الواحد
# _15696\01\ليش رجعت
# _15697\01\يا مو بشو بدي كييل
# _15698\01\تصوري الاستاذ رفيقي
# _15699\01\وشو كان بدك
# _15700\01\نسيت امك من المفروض انها حتروح تعمل اشعة
# _15701\01\في مثل ثاني من الجزائر بحبه  نقوله في الوسط الموسيقي
# _15702\01\لا تعلمين ما احوالها
# _15703\01\اماني
# _15704\01\السمك
# _15705\01\حمله
# _15706\01\هي قصة قمر صناعي ما بظن
# _15707\01\كنت بتبسة مات جدي
# _15708\01\كانت تمر لعندي قبل ما تروح عالبقالية و نشتري سوا من عند عبدو المصري
# _15709\01\شو قولك بالموضوع
# _15710\01\وشلون خطيتها
# _15711\01\الله يحمينا
# _15712\01\امي ما بتناديلي اذا كان فيلم بتناديلي عاللقطة الاخيرة و بتقلي روحي و ساوي هي و اشتري و اذا كان مسلسل بتناديلي عالحلقة الاخيرة
# _15713\01\وحتى اولاد اولادها هي بتدرسهم وما بيوخدوا دروس
# _15714\01\مو طبيعي هيك
# _15715\01\لا متل ما منقول هلق الدنيا مكاتيب و كل واحد و رزقه بس اتطلعي على احتمال ان بلدنا ما فيها هي الشغلات المنيحة و المستقبل فيها مجهول هل هاد منيح او لا بس الشي الموجود ببلدنا و ما رح تلاقيه هنيك شو هو
# _15716\01\استني مسحي هاد
# _15717\01\اي
# _15718\01\ليش بيقولوا انك لو كنت مشتركة بعرض فوري مثلا بتضلي بعرض فوري بس بتصير الشبكة لا سلكية
# _15719\01\لكن متلي
# _15720\01\الترسيم
# _15721\01\كل وحدة الها شغل ومن ضمنهم الختيار 11
# _15722\01\صحيح يما ليش بدك تصحي على الاربعة و نص
# _15723\01\بقدر يزور موقعه من معلش يا كينج او يا كنجة
# _15724\01\ممكن انها تاخرت عليهم ما اجتهمش
# _15725\01\وعالعموم يا ابوحميد انا كمان بفتخر فيك كاخ وصديق مقرب طبعا
# _15726\01\انت بديت الحفظ والا لا
# _15727\01\اي والله بسم الله الرحمن الرحيم انسطلت
# _15728\01\منيح نزل راسك انعدل
# _15729\01\قليلي كانت حلوة ولا لا
# _15730\01\مزبوط انا من بين كل مطربين الجزائر قروابي الو مكانة خاصة عندي
# _15731\01\قلت اخذ التوجيهي و لما اشوف معدلي باختار
# _15732\01\قلي و بس
# _15733\01\اكتب اكتب لا تتطلع عليي و لما بفلك اكتب بتكتب و انت ساكت
# _15734\01\اه تصاوب بقنبلة او مش عارف ايش
# _15735\01\قالها بديش اسمع هذا الكلام مرة تانية
# _15736\01\قلي انو اتصل فيه و مهدي وعدو يرجع يتصل فيه يوم الخميس انشاء الله
# _15737\01\روح و اشتريلي علبة بندورة
# _15738\01\الوشواشة عنا معناها الناموس قلتلك هالشي من قبل كمال شو نسيتا
# _15739\01\دكتور
# _15740\01\مهونة كمال
# _15741\01\هو الهوا فين عم يروح
# _15742\01\بتحطيلو ماء جافيل
# _15743\01\ما باليد حيلة
# _15744\01\لازم تقنع اي حدا بخالفك انه غلط وانت بس الصح
# _15745\01\اي عم بدرس
# _15746\01\جابت خولة معدل و هي اللي بتدرس بكلية الحقوق اما انا فجبت معدل  و انا بادرس في كلية الاقتصاد
# _15747\01\اشتريت شاحن عام
# _15748\01\المهم انا طلبت من نصيرة انو تعطيه السيارة ليجي فيا
# _15749\01\استني يا فريال استني حيكتبلياه
# _15750\01\تصبحوا على خير ان شاء الله
# _15751\01\صدقني ما بعرفش
# _15752\01\ريحة هالعطر كتير حلوة
# _15753\01\لا لو خبرتي حفيظة كمان لان ليليا ساكنة حدها
# _15754\01\قلي بابا وين مفتاح الكراج مفتاح الكراج
# _15755\01\لا ما بيتعلقش بالايمان ما بقدرش انه يسكنك
# _15756\01\اي موضة لك سليمة بتفكريهون ديوك مبللة
# _15757\01\ولا من الظلم والقهر اللي بشوفوا كل يوم وخلاني كرهت هالبلد
# _15758\01\ههههه بس هدول يا عيني قصتهم خلصت من زمان ههههه
# _15759\01\وئعتي عطرك
# _15760\01\نورت يا هبه وان شاء الله خير شكراا لمرورك العطر وبتمنى تكون ايامك سعيده بس هائم
# _15761\01\موضوعك حلو كتير يا حبيبتي
# _15762\01\ابيض
# _15763\01\كيف هو ابنك هو تحسن شوي
# _15764\01\انا كمان لدي ملاحظة شو هالالف اللي عم تضيفها متل نسييوا
# _15765\01\يا اخي ما فهمتش
# _15766\01\رحت عليه عند الكليه واعطيته بطاقتي الشخصيه وشافها
# _15767\01\صباح الخير مين معي
# _15768\01\لا لا
# _15769\01\زي عمتي كانت من قبل تربي واحد لكن كبر و صار يهاجمهم
# _15770\01\اي كمان ئلتلك تخبريها متل ما ئلتلك تئولي لعلي
# _15771\01\قالي اطلعي النسوان فوق فلقيت نسوان كتير
# _15772\01\بعرف انك بتوفي بالعهد
# _15773\01\شوفي اول اشي بيكون فقد ذاكرته بيصح هيك مش ممكن بالمرة
# _15774\01\لكن هدا ما بمنع المحجبه من حقها في انها تقدم يرامج
# _15775\01\بنت خالي محمد
# _15776\01\رح نروح كلنا سليمة انا كمان تعبت
# _15777\01\اه طيب لاني اتصلت فيكي اليوم الصبح اتصلت فيكي بجيزي و اتصلت فيكي بموبيليس
# _15778\01\الناس ما بيرحمو
# _15779\01\بعدين اخترت هندسة المعارف
# _15780\01\حسيت بتعبك
# _15781\01\انت بتعرفيها
# _15782\01\انا كمان بادور على جزمة
# _15783\01\الله يجزيك كل خير ويا رب القى موافقة من دكتورة عايدة ازاحبت الموضوع والله يجزيها الخير
# _15784\01\وبتيالي انو لو فكرت في اللي بتسمى الشخصيه الفلسطينيه رح اكزن بظلمهم
# _15785\01\من كتر ما عجبه ضله يصر عشان اشرحله
# _15786\01\لسه ما بديت معها
# _15787\01\قالتلي حاتصل فيهم و استفسر عن الموضوع
# _15788\01\لو انو في دراسة بالليل هيك
# _15789\01\والتانية قالت لنا جيبولي مغلف لنحط فيه بحوثنا
# _15790\01\شو قلهم عجبتني ايد الرئيس
# _15791\01\اكيد ما رح اطلب الطلاق بس لو الموضوع بسبب حزن للزوج فبعتقد اني الزواج على الاقل مشان ما احس بالذنب
# _15792\01\حتى هدينك ما سلمو منهن
# _15793\01\زيد عليها انو سوريا موضوع كويس انا من دون ما اطلب العلا بسهر الليالي
# _15794\01\ماشي
# _15795\01\شكرا سارة شكرا كتير
# _15796\01\روحي ارتاحي يا ست روحي ارتاحي
# _15797\01\ايش يعني السي سي اف
# _15798\01\نضلنا على التوقيت نفسه
# _15799\01\ما بقى فينا نتحمل
# _15800\01\وقفت الاقراص هي اللي وجعتني
# _15801\01\يسلمو ايديكي الحلوين وهداياكي الحلوة
# _15802\01\وبالذات لانك بتحكي مع برج المراقبه وبتحكي نفس اوامر المطارات بالضبط
# _15803\01\عندي افلام عربيه با لهبل «na3saa»  «@hotmailcom»
# _15804\01\وضايل شهور وايام ورح اقلع ان شاء الله

# %% [markdown]
# ## Build Vocabulary

# %% [markdown]
# Sentence Piece Google Colab
# https://github.com/google/sentencepiece/blob/master/python/sentencepiece_python_module_example.ipynb

# %%
len(data_English_MSA)
# Out:
# 10001

# %%
"""
Create a text file with all the MSA vocab available for SentencePiece to create a library 
"""

text_file_en = open("data/english_data.txt", "wt")
text_file_msa = open("data/arabic_data.txt", "wt")

MSA_text = ""
EN_text = ""

for line in data_English_MSA:
        english = line[0]
        english_words = english.split(" ")
        for count, word in enumerate(english_words):
            text_file_en.write(word)
        text_file_en.write("\n")
        
        arabic = line[1]
        arabic_words = arabic.split(" ")
        for count, word in enumerate(arabic_words):
            text_file_msa.write(word)
        text_file_msa.write("\n")


text_file_en.close()
text_file_msa.close()

# %%
spm.SentencePieceTrainer.train('--input=data/arabic_data.txt --model_prefix=data/msa --vocab_size=2000')
spm.SentencePieceTrainer.train('--input=data/english_data.txt --model_prefix=data/en --vocab_size=2000')
# Out:
# True

# %%
sp = spm.SentencePieceProcessor()
sp.load('data/en.model')
# Out:
# True

# %%
ls
# Out:
# Env_Setup_Instructions.txt  data/
# Model_1.ipynb               transformers/
# README.md

# %%
print(sp.encode_as_pieces('This is a test'))
print(sp.encode_as_ids('This is a test'))
# Out:
# ['▁This', '▁', 'is', '▁', 'a', '▁', 't', 'est']
# [89, 83, 12, 83, 8, 83, 6, 309]

# %% [markdown]
# ## TF Tokenizer
#
# https://huggingface.co/transformers/model_doc/t5.html#t5tokenizer

# %%
ls data/
# Out:
# AD_NMT-master/
# AD_NMT-master.zip
# PADIC.xml
# UNv1.0.ar-en.tar.gz.00
# UNv1.0.ar-en.tar.gz.01
# ar_formatted_test.txt
# ar_formatted_train.txt
# arabic-to-english-translation-sentences.zip
# arabic_data.txt
# en.model
# en.vocab
# en_formatted_.txt
# en_formatted_test.txt
# en_formatted_train.txt
# english_data.txt
# lav_formatted_.txt
# mag_formatted_.txt
# msa.model
# msa.vocab
# msa_formatted_.txt

# %%
msa_tokenizer = T5Tokenizer("data/msa.model")
en_tokenizer = T5Tokenizer("data/en.model")

# %%
input_ids = msa_tokenizer.encode('هل بامكاني الدخول؟ </s>', return_tensors='pt')

# %%
input_ids
# Out:
# tensor([[ 41,   4, 330,   6,  93, 964,   8,   4,   2]])

# %%
#decode to make sure you can go back and forth between the encoding properly 
#@raef can you verify the Arabic?

# %%
ls data/
# Out:
# AD_NMT-master/
# AD_NMT-master.zip
# PADIC.xml
# UNv1.0.ar-en.tar.gz.00
# UNv1.0.ar-en.tar.gz.01
# ar_formatted_test.txt
# ar_formatted_train.txt
# arabic-to-english-translation-sentences.zip
# arabic_data.txt
# en.model
# en.vocab
# en_formatted_.txt
# en_formatted_test.txt
# en_formatted_train.txt
# english_data.txt
# lav_formatted_.txt
# mag_formatted_.txt
# msa.model
# msa.vocab
# msa_formatted_.txt

# %% [markdown]
# ## Pytorch Data Set and Data Loader
#
# https://github.com/google-research/text-to-text-transfer-transformer
#
# pytorch dataset: https://pytorch.org/text/_modules/torchtext/datasets/translation.html
#
# pytorch dataset documentation: https://torchtext.readthedocs.io/en/latest/datasets.html#iwslt
#
# example dataset: https://iwslt2010.fbk.eu/node/32/

# %% [markdown]
# Field API: https://pytorch.org/text/data.html#torchtext.data.Field
# Field Source: https://pytorch.org/text/_modules/torchtext/data/field.html#Field

# %% [markdown]
# https://pytorch.org/text/_modules/torchtext/data/utils.html#get_tokenizer
#
# we need to pass our tokenizer as a function

# %%
SRC = Field(tokenize = T5Tokenizer,
            tokenizer_language="en",
            init_token = '<sos>',
            eos_token = '<eos>',
            lower = True)

TRG = Field(tokenize = T5Tokenizer,
            tokenizer_language="ar",
            init_token = '<sos>',
            eos_token = '<eos>',
            lower = True)

# %%
dataset = TranslationDataset(path='data/', exts=('en_formatted_.txt', 'msa_formatted_.txt'), fields=(SRC, TRG))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-58-fb12cae62def> in <module>
# ----> 1 dataset = TranslationDataset(path='data/', exts=('en_formatted_.txt', 'msa_formatted_.txt'), fields=(SRC, TRG))
#
# ~/anaconda/envs/fastai/lib/python3.7/site-packages/torchtext/datasets/translation.py in __init__(self, path, exts, fields, **kwargs)
#      38                 if src_line != '' and trg_line != '':
#      39                     examples.append(data.Example.fromlist(
# ---> 40                         [src_line, trg_line], fields))
#      41
#      42         super(TranslationDataset, self).__init__(examples, fields, **kwargs)
#
# ~/anaconda/envs/fastai/lib/python3.7/site-packages/torchtext/data/example.py in fromlist(cls, data, fields)
#      83                         setattr(ex, n, f.preprocess(val))
#      84                 else:
# ---> 85                     setattr(ex, name, field.preprocess(val))
#      86         return ex
#      87
#
# ~/anaconda/envs/fastai/lib/python3.7/site-packages/torchtext/data/field.py in preprocess(self, x)
#     213             x = Pipeline(lambda s: six.text_type(s, encoding='utf-8'))(x)
#     214         if self.sequential and isinstance(x, six.text_type):
# --> 215             x = self.tokenize(x.rstrip('\n'))
#     216         if self.lower:
#     217             x = Pipeline(six.text_type.lower)(x)
#
# ~/anaconda/envs/fastai/lib/python3.7/site-packages/transformers/tokenization_t5.py in __init__(self, vocab_file, eos_token, unk_token, pad_token, extra_ids, additional_special_tokens, **kwargs)
#     140
#     141         self.sp_model = spm.SentencePieceProcessor()
# --> 142         self.sp_model.Load(vocab_file)
#     143
#     144     @property
#
# ~/anaconda/envs/fastai/lib/python3.7/site-packages/sentencepiece.py in Load(self, filename)
#     116
#     117     def Load(self, filename):
# --> 118         return _sentencepiece.SentencePieceProcessor_Load(self, filename)
#     119
#     120     def LoadOrDie(self, filename):
#
# OSError: Not found: "_0000\01\Tom was also there": No such file or directory Error #2

# %%
#For testing dataset code errors. Delete when dataset is functioning properly 

path = 'data/'
exts=('en_formatted_.txt', 'msa_formatted_.txt')
fields=(' sentence ID', 'paraphrase ID', 'MT training sentence')

if not isinstance(fields[0], (tuple, list)):
    fields = [('src', fields[0]), ('trg', fields[1])]

src_path, trg_path = tuple(os.path.expanduser(path + x) for x in exts)

examples = []
with io.open(src_path, mode='r', encoding='utf-8') as src_file, \
        io.open(trg_path, mode='r', encoding='utf-8') as trg_file:
    for src_line, trg_line in zip(src_file, trg_file):
        src_line, trg_line = src_line.strip(), trg_line.strip()
        if src_line != '' and trg_line != '':
            print(src_line)
            print(trg_line)
            examples.append(data.Example.fromlist(
                [src_line, trg_line], fields))

# %%
train_data, valid_data, test_data = dataset.splits(exts=('en_formatted_.txt', 'msa_formatted_.txt'),
                                                    fields = (SRC, TRG))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-53a24ea72922> in <module>
# ----> 1 train_data, valid_data, test_data = dataset.splits(exts=('en_formatted_.txt', 'msa_formatted_.txt'),
#       2                                                     fields = (SRC, TRG))
#
# NameError: name 'dataset' is not defined

# %%
BATCH_SIZE =32

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data),
    batch_size = BATCH_SIZE,
    device = device)

# %% [markdown]
# ## Model Training
#
# https://huggingface.co/transformers/model_doc/t5.html#training

# %%
configuration = T5Config()

# %%
model = T5Model.from_pretrained('t5-base')

# %%
for i, batch in enumerate(train_iterator)

# %% [markdown]
# ## Model Inference
#
# https://github.com/huggingface/transformers/blob/master/examples/translation/t5/evaluate_wmt.py
