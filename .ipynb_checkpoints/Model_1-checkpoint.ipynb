# %% [markdown]
# ### Notes
#
# T5 Paper: https://arxiv.org/pdf/1910.10683.pdf
#
# T5 Tokenizer: https://github.com/huggingface/transformers/blob/master/src/transformers/tokenization_t5.py

# %%
#James Chartouni
#Joey Park
#Raef Khan

import torch
import pandas as pd
import numpy as np
import pickle

import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
ls data/AD_NMT-master
# Out:
# LAV-MSA-2-both.pkl        Magribi_MSA-test.pkl      english-Arabic-train.pkl
# LAV-MSA-2-test.pkl        Magribi_MSA-train.pkl     english-arabic-test.pkl
# LAV-MSA-2-train.pkl       README.md
# Magribi_MSA-both.pkl      english-Arabic-both.pkl

# %%
file_path = 'data/AD_NMT-master/'

with open(file_path + "english-Arabic-train.pkl", 'rb') as handle:
    train_ds = pickle.load(handle) 
    
with open(file_path + "english-Arabic-test.pkl", 'rb') as handle:
    test_ds = pickle.load(handle)

# %%
print(train_ds[0:5])
print(test_ds[0:5])
# Out:
# [['Tom was also there', 'كان توم هنا ايضا'], ['That old woman lives by herself', 'تلك المراة العجوز تسكن بمفردها'], ['He went abroad for the purpose of studying English', 'سافر خارج البلد ليتعلم الانجليزية'], ['There is a fork missing', 'هناك شوكة ناقصة'], ["I don't know this game", 'لا اعرف هذه اللعبة']]
# [["Where's your money?", 'اين مالك؟'], ['Be prepared', 'كن مستعدا'], ["I figured you'd be impressed", 'توقعت انك ستنبهر'], ['May I come in?', 'هل بامكاني الدخول؟'], ['Read through the article', 'اقرا المقالة']]

# %%
train_ds
# Out:
# [['Tom was also there', 'كان توم هنا ايضا'],
#  ['That old woman lives by herself', 'تلك المراة العجوز تسكن بمفردها'],
#  ['He went abroad for the purpose of studying English',
#   'سافر خارج البلد ليتعلم الانجليزية'],
#  ['There is a fork missing', 'هناك شوكة ناقصة'],
#  ["I don't know this game", 'لا اعرف هذه اللعبة'],
#  ['He likes fishing', 'انه يحب صيد الاسماك'],
#  ["I don't know how to handle children", 'لا اعرف كيف اتعامل مع الاطفال'],
#  ['Do you know who she is?', 'هل تعرف من هي؟'],
#  ['She asked him why he was crying', 'سالته لما كان يبكي'],
#  ['I called Tom up', 'اتصلت بتوم'],
#  ["I'm here for you", 'انا هنا من اجلك'],
#  ['Where is the mailbox?', 'اين صندوق البريد؟'],
#  ['The list is endless', 'القائمة لانهائية'],
#  ['Seriously?', 'اانت جاد؟'],
#  ['Birds of a feather flock together', 'الطيور على اشكالها تقع'],
#  ['Tom got these tickets for free', 'حصل توم على هذه التذاكر بالمجان'],
#  ['You talk too much', 'انك تتكلم كثيرا'],
#  ['Parents love their children', 'الاباء يحبون اولادهم'],
#  ['He placed the book on the shelf', 'وضع الكتاب على الرف'],
#  ['My uncle lives near the school', 'يعيش عمي قرب المدرسة'],
#  ['We are men', 'نحن رجال'],
#  ['I plan to invite a lot of guests to the opening ceremony',
#   'اخطط لدعوة ضيوف كثيرين الى حفل الافتتاح'],
#  ['I prefer going out to staying at home', 'افضل الخروج على البقاء في البيت'],
#  ['My mother is angry', 'امي غاضبة'],
#  ["I don't know this neighborhood too well", 'لا اعرف هذا الحي جيدا'],
#  ['I would rather stay home than go out with him',
#   'افضل البقاء في البيت على الخروج معه'],
#  ['Tom was extraordinarily handsome', 'توم كان وسيما للغاية'],
#  ['This is your key', 'ها هو مفتاحك'],
#  ["That's what happened here on Monday", 'هذا ما حدث هنا يوم الاثنين'],
#  ['She is very intelligent', 'انها ذكية جدا'],
#  ["Although I didn't like math I had to study logarithms",
#   'على الرغم من انني لم اكن احب الرياضيات كان علي دراسة اللوغاريتمات'],
#  ['I want an answer from you ASAP', 'اريد اجابة منك في اسرع وقت ممكن'],
#  ['Perhaps it will snow tomorrow', 'لربما تساقط الثلج غدا'],
#  ['Cancer can be cured easily if it is found in its first phase',
#   'يمكن معالجة السرطان اذا اكتشف في مرحلة مبكرة'],
#  ["He's talking on the telephone", 'انه يتحدث على الهاتف'],
#  ['You never change do you?', 'الا تتغير ابدا؟'],
#  ["I can't see anything", 'لا ارى شيئا'],
#  ['Rats carry the plague', 'تحمل الفئران الطاعون'],
#  ["The horse stopped and wouldn't move", 'توقف الحصان و رفض ان يتحرك'],
#  ['It was probably not true', 'كانت على الارجح غير صحيحة'],
#  ['He felt her hand on his shoulder', 'شعر بيدها على كتفه'],
#  ['All Tom really wanted was something to eat',
#   'كل ما كان يحتاجه توم حقا كان شيئا ما لياكله'],
#  ['She bent down', 'انحنت'],
#  ['I must hide', 'علي الاختباء'],
#  ["I'm relying on you to help us", 'اعتمد عليك لتساعدنا'],
#  ["I didn't hear my alarm clock", 'انا لم اسمع المنبه'],
#  ['I remember mailing the letter', 'اذكر اني بعثت بالرسالة'],
#  ['My father died of cancer', 'مات ابي بسبب السرطان'],
#  ['I have been here for a week', 'انا هنا منذ اسبوع'],
#  ["What're you saying?", 'ما الذي تقوله؟'],
#  ['My bag was stolen', 'سرقت حقيبتي'],
#  ['I appreciate this', 'انا اقدر ذلك'],
#  ['Tom seems OK now', 'يبدو توم بحال جيدة'],
#  ['How lucky you are!', 'كم انت محظوظة!'],
#  ['I need time', 'احتاج وقتا'],
#  ['Seeing the policeman the man ran away', 'هرب الرجل عقب رؤية الشرطي'],
#  ['Her ambition is to become an ambassador', 'طموحها هو ان تصبح سفيرة'],
#  ['He took a key from his coat pocket', 'اخرج مفتاحا من جيب معطفه'],
#  ["I'm not satisfied with the quality of your work",
#   'انا لست راضيا عن جودة عملك'],
#  ["I'll do anything I can for Tom", 'ساعمل ما بوسعي لاجل توم'],
#  ['Good evening', 'مساء الخير'],
#  ["Don't worry about my dog", 'لا تقلق بشان كلبي'],
#  ['I did not mean to disappoint her', 'لم اكن اقصد احباطها'],
#  ["He's come to make trouble", 'انه ياتي ليصنع مشكلة'],
#  ['Who is the woman dressed in pink?',
#   'من تلك المراة التي ترتدي فستانا ورديا؟'],
#  ['Your answer differs from mine', 'جوابك مختلف عن جوابي'],
#  ['Mary likes watching TV', 'تحب ماري مشاهدة التلفاز'],
#  ['Can I ride this horse for a while?', 'ايمكنني ركوب هذا الحصان قليلا؟'],
#  ['I would like to see it', 'اود ان اراها'],
#  ["Let's get out of here before Tom sees us",
#   'دعونا نخرج من هنا قبل ان يرانا توم'],
#  ['Please tell me about your trip', 'احكي لي عن رحلة سفرك من فضلك'],
#  ["I'll just leave this here", 'انا فقط ساترك هذه هنا'],
#  ['Go and speak to my colleague', 'اذهب وتحدث الى زملائي'],
#  ['The door is open', 'الباب مفتوح'],
#  ['The book is red', 'الكتاب احمر'],
#  ['You are my father', 'انت ابي'],
#  ['He is getting better day by day', 'انه يتحسن كل يوم'],
#  ['You may go anywhere', 'يمكنك الذهاب الى اين تشاء'],
#  ['Help me', 'النجدة! ساعدني!'],
#  ['Tom denied that he had been involved in the affair',
#   'انكر توم كونه متورط في القضية'],
#  ['Have you been shot?', 'هل اصبت بطلق ناري؟'],
#  ["I'm sure you're right", 'انا متاكد انك محقة'],
#  ['The tip of the spear was dipped in a deadly poison',
#   'راس الرمح كان مغموسا في سم قاتل'],
#  ['Where is the problem?', 'اين المشكلة؟'],
#  ['I like coffee hot', 'احب شرب القهوة ساخنة'],
#  ["I'm getting off the train at the next stop",
#   'سانزل من القطار عند المحطة القادمة'],
#  ["Who's the boy swimming over there?", 'من ذلك الصبي الذي يسبح هناك؟'],
#  ['Someone finally called 911', 'واخيرا اتصل احدهم ب 911'],
#  ['She lost her handbag', 'فقدت حقيبة يدها'],
#  ['What do you do in the afternoon?', 'ماذا تفعل ظهرا؟'],
#  ['You may come if you like', 'بامكانك المجيء ان احببت'],
#  ['I never wanted you to get involved in this mess',
#   'لم ارغب ابدا ان تتورط فى هذه الفوضى'],
#  ['Which bed do you want to use?', 'على اي سرير تريد ان تنام؟'],
#  ['One billion people speak English', 'مليار شخص يتكلمون الانجليزية'],
#  ["I don't want to talk to Tom right now",
#   'انا لا اريد ان اتحدث الى توم الان'],
#  ['Are you all ready?', 'هل الجميع جاهز؟'],
#  ['He promised me that he would come at four',
#   'لقد وعدني انه سياتي على الساعة الرابعة'],
#  ['Pick up your things and go away', 'اجمع اغراضك وغادر'],
#  ["It's not important", 'ليس هذا مهما'],
#  ["It's a secret", 'انه سر'],
#  ["Yes she'll probably come home", 'نعم على الارجح انها سوف تاتي الى المنزل'],
#  ['Shut the door', 'اغلق الباب'],
#  ['I had my money stolen', 'سرق مالي'],
#  ["It's more difficult than you think", 'انه اصعب مما تظن'],
#  ['He is in the tenth grade', 'هو في الصف العاشر'],
#  ["If you don't work you can't eat", 'ان لم تعمل لن تستطيع الاكل'],
#  ['What is the matter with your car?', 'ما مشكلة سيارتك؟'],
#  ['My father and my brother work in this factory',
#   'يعمل ابي واخي في هذا المصنع'],
#  ['Tom told me that he does thirty pushups every morning',
#   'اخبرني توم انه يقوم بتمارين الضغط بعدد 30 مرة كل صباح'],
#  ['He was wounded in the shoulder', 'جرح كتفه'],
#  ["You're still young", 'ما زلت يافعا'],
#  ['He really ticked me off', 'هو اغضبني حقا '],
#  ['You can skate safely on this side of the lake',
#   'يمكنك التزلج بامان على هذا الجانب من البحيرة'],
#  ["Don't lie", 'اياك و الكذب'],
#  ['They hated each other', 'يكرهان بعضهما البعض'],
#  ['My father gave me a game', 'اعطاني ابي لعبة'],
#  ["Let's take a look", 'لنلق نظرة'],
#  ['Life in a small town is boring', 'الحياة في قرية صغيرة مملة'],
#  ["You can't live without oxygen", 'لا يمكنك العيش من دون اكسجين'],
#  ["I don't know if he would have done it for me",
#   'لا ادري ان كان ليفعلها لاجلي'],
#  ['Few people know about the plan', 'القليل يعرف اي شيء عن الخطة'],
#  ['They shared the money', 'انهم اقتسموا المال'],
#  ['He is a daredevil', 'هو متهور'],
#  ['I turned off the radio', 'اطفات المذياع'],
#  ['Today is Sunday', 'اليوم هو الاحد'],
#  ["Whenever I find something I like it's too expensive",
#   'كلما وجدت شيئا يعجبني وجدته غاليا جدا'],
#  ['I will go to America tomorrow', 'ساغادر الى امريكا في الغد'],
#  ['What happened?', 'ما الذي حصل؟'],
#  ['She became a doctor', 'اصبحت طبيبة'],
#  ['May I introduce my friend to you?', 'اعرفك بصديقي'],
#  ['She has blue eyes', 'عيناها زرقاوتان'],
#  ['She turned down my request', 'رفضت طلبي'],
#  ['May I smoke here?', 'ايمكنني ان ادخن هنا؟'],
#  ["That's enough", 'كفى'],
#  ["Please don't cry", 'لا تبك من فضلك'],
#  ['Are you all right now?', 'هل انت بخير الان؟'],
#  ['How will we pay our debts now?', 'كيف سنسدد ديوننا الان؟'],
#  ['We need your help', 'نحتاج الى مساعدتك'],
#  ['Easy come easy go', 'ما ياتي سهلا يذهب سهلا'],
#  ["Those are our teachers' cars", 'تلك سيارات معلمينا'],
#  ["It's not his ability but his character that is at issue",
#   'ليست المشكلة في قدرته بل في شخصيته'],
#  ['Do your own work', 'قم بعملك بنفسك'],
#  ['He continued reading the book', 'استانف قراءة الكتاب'],
#  ["I've seen him before", 'لقد رايته من قبل'],
#  ['This surprised many people', 'فاجا ذلك الكثير'],
#  ['You should apologize to her', 'عليك ان تتاسف لها'],
#  ['I bought a red sports car', 'اشتريت سيارة رياضية حمراء'],
#  ['Do you think he made that mistake on purpose?', 'هل تظنه اخطا عمدا؟'],
#  ['He told me not to drive too fast', 'نبهني الا اقود بسرعة'],
#  ['I baked an apple pie', 'خبزت فطيرة تفاح'],
#  ["I can't understand what you're saying", 'لا استطيع فهم ما تقول'],
#  ['She asked me if I was all right', 'سالتني اذا كنت على ما يرام'],
#  ['Let me go', 'دعني اذهب'],
#  ['You make me happy', 'انت تجعلني سعيدا'],
#  ['Here comes the bus', 'ها قد اتت الحافلة'],
#  ["I'm going to find a place of my own", 'ساعثر علي مكان خاص بي'],
#  ['I did see him', 'لقد قابلته'],
#  ['It is believed that he was a brave soldier', 'يعتقد انه كان جنديا شجاعا'],
#  ['What are you cooking?', 'ماذا تطبخ؟'],
#  ["You'd better go to see your family doctor at once",
#   'يستحسن ان تذهب لرؤية طبيب العائلة حالا'],
#  ['You have no fever', 'ليس لديك اي حمى'],
#  ["It's time for me to go", 'حان وقت ذهابي'],
#  ['He rested his hand on my shoulder', 'وضع يديه على كتفي'],
#  ['Do you have the key to this door?', 'الديك مفتاح هذا الباب؟'],
#  ['Tom is one of our best detectives', 'توم واحد من افضل محققينا'],
#  ['We want peace in the world', 'نريد السلام في العالم'],
#  ["Tom isn't a good singer", 'توم ليس بمغن جيد'],
#  ["Hurry up or you'll miss your plane", 'اسرع و الا فاتتك الطائرة'],
#  ['Cancer can be cured if discovered in time',
#   'من الممكن علاج السرطان اذا اكتشف قبل فوات الاوان'],
#  ['They died one after another', 'ماتوا واحدا تلو الاخر'],
#  ['May I see your passport?', 'هل لي ان ارى جواز سفرك؟'],
#  ["I'll go if Tom goes", 'ساذهب ان ذهب توم'],
#  ['She married him for his money', 'تزوجته من اجل ماله'],
#  ["I've got no choice", 'لم احصل على خيار'],
#  ['This bus will take you to the airport', 'سياخذك هذا الباص الى المطار'],
#  ['Continue working', 'واصل العمل'],
#  ['What is his nationality?', 'ما جنسيته؟'],
#  ["Don't say such things", 'لا تقل مثل هذه الاشياء'],
#  ["It's too dangerous!", 'انه خطير للغاية'],
#  ["It's a popular tourist destination", 'انه مقصد سياحي مشهور'],
#  ['You should give up drinking and smoking',
#   'ينبغي ان تقلع عن الشرب والتدخين'],
#  ["What time did he say he'd come?", 'متى قال انه سياتي؟'],
#  ['You disappointed me', 'خيبت املي فيك'],
#  ['Please correct my pronunciation', 'صحح نطقي من فضلك'],
#  ['Please drive carefully', 'قد بحذر من فضلك'],
#  ['I want one too', 'انا اريد واحدة ايضا'],
#  ["I'm not going back", 'لن اعود'],
#  ['The students learned this poem by heart',
#   'حفظ التلاميذ هذه القصيدة عن ظهر قلب'],
#  ['Why did you keep it a secret?', 'لم ابقيته سرا؟'],
#  ['You are no better at remembering things than I am',
#   'لست احسن في تذكر الاشياء مني'],
#  ['I may be old but I can still ride a bike',
#   'لربما كنت كبير السن ولكنني لا زلت استطيع ركوب الدراجة'],
#  ['Let Tom go', 'دع توم يذهب'],
#  ['He can do it better than me', 'انه يستطيع ان يفعل هذا افضل مني'],
#  ["I'd like to introduce some friends of mine", 'اريد ان اعرفك ببعض اصدقائي'],
#  ["You'll have to use the rear door while the house is being painted",
#   'يجب ان تستخدم الباب الخلفي ريثما يجري صبغ البيت '],
#  ['Can we trust you?', 'ايمكننا الوثوق بك؟'],
#  ["Speaking English isn't easy", 'التحدث بالانجليزية ليس امرا سهلا'],
#  ['He died yesterday', 'مات البارحة'],
#  ['We will play football after school', 'سنلعب كرة القدم بعد المدرسة'],
#  ["Don't worry about things that aren't important",
#   'لا تقلق بشان الاشياء الغير مهمة'],
#  ['My father and mother have a big farm there',
#   'امي وابي عندهما مزرعة كبيرة هناك'],
#  ['Our house was robbed while we were away', 'سرق منزلنا عندما كنا مسافرين'],
#  ['She asked him for help', 'طلبت منه المساعدة'],
#  ["Where's the pharmacy?", 'اين الصيدلية؟'],
#  ['I have to stay in bed all day', 'علي ان الازم السرير طول اليوم'],
#  ['Stay thin', 'حافظي على جسم نحيف'],
#  ['Please call me up later', 'من فضلك اتصل بي لاحقا'],
#  ['Tom wants to know if it hurts', 'توم يريد ان يعرف م اذا كانت تؤلم'],
#  ['A pretty girl like you will definitely be noticed',
#   'فتاة حسناء مثلك حتما تكون قد لوحظت'],
#  ['She used to be a very shy girl', 'كان من طبيعتها انها فتاة خجولة جدا'],
#  ['This book is even more interesting than that',
#   'هذا الكتاب ممتع اكثر من ذاك'],
#  ['You can swim much better than he can', 'انت تسبح افضل منه بكثير'],
#  ['The majority of the committee were against the plan',
#   'اغلبية اللجنة كانت معارضة للخطة'],
#  ['I was happy yesterday', 'كنت فرحا بالامس'],
#  ['She took her own life', 'انتحرت'],
#  ['Tell me how to solve the problem', 'اخبرني كيف احل هذه المسالة'],
#  ['I have an Egyptian neighbor', 'انا لدي جار مصري'],
#  ["I've got a new bike", 'اشتريت دراجة جديدة'],
#  ["Tom hasn't yet told us about that", 'لم يخبرنا توم عن ذلك بعد'],
#  ['We immediately became friends', 'اصبحنا صديقين على الفور'],
#  ['Your English is improving', 'لغتك الانجليزية تتحسن'],
#  ['Mathematics is difficult for me', 'الرياضيات مادة صعبة بالنسبة لي'],
#  ['My children really like animals', 'اولادي يحبون الحيوانات كثيرا'],
#  ['She said goodbye', 'قالت وداعا'],
#  ["I'm a little tired", 'انني متعب قليلا'],
#  ["I shouldn't have eaten that", 'لم يكن علي اكل هذا'],
#  ["I'm not used to this kind of work", 'لست معتادا على هكذا عمل'],
#  ['The converse is also true', 'و العكس صحيح'],
#  ['I hated school', 'لقد كرهت المدرسة'],
#  ['He is old enough to drive', 'انه كبير بما فيه الكفاية ليقود سيارة'],
#  ["How's Tom?", 'كيف حال توم؟'],
#  ["I'm pleased to meet you", 'تشرفت بلقائك'],
#  ["You never should've let Tom go to Boston with Mary",
#   'كان عليك ان لا تسمح لتوم بالذهاب مع ماري الى بوسطن'],
#  ["I didn't study math at all", 'لم ادرس مادة الرياضيات على الاطلاق'],
#  ['I have been waiting for almost half an hour', 'انتظرت قرابة النصف ساعة'],
#  ["I'll be leaving in March", 'سوف اسافر في مارساذار'],
#  ['The program will finish with the national anthem',
#   'البرنامج سوف ينتهي بالنشيد الوطني '],
#  ['Do you have change for a fifty?', 'ايمكنك صرف خمسين؟'],
#  ["I don't remember what happened anymore", 'لم اعد اتذكر ما حصل'],
#  ["He's so young", 'انه صغير جدا'],
#  ['I really miss you', 'اشتقت اليك حقا'],
#  ["I'll be right with you", 'ساكون معك حالا'],
#  ['I learned to play guitar when I was ten years old',
#   'تعلمت العزف على الغيتار عندما كان عمري عشر سنوات'],
#  ['When will you leave?', 'متى ستغادر؟'],
#  ['I feel hungry', 'اشعر بالجوع'],
#  ["Tom didn't fire Mary", 'توم لم يطرد ماري'],
#  ['He saved the child at the risk of his own life',
#   'هو انقذ الطفل مجازفا بحياته'],
#  ["Tom can't decide whether to buy a new computer now or wait for a couple of more months",
#   'لا يستطيع توم ان يقرر هل يشتري حاسوبا جديدا الان ام ينتظر بضعة اشهر'],
#  ['I saw you outside', 'رايتك في الخارج'],
#  ['You can go home if you like', 'يمكنك العودة الى البيت لو اردت'],
#  ["Tom doesn't want me to talk about what we discussed yesterday",
#   'توم لا يريد مني التحدث عن ما ناقشناه بالامس'],
#  ['It was stupid of me to make such a mistake',
#   'كان من الغباء مني ان اقترف خطا كهذا'],
#  ['Tom is losing blood', 'توم يفقد كثيرا من الدم'],
#  ["It's really bothering me", 'انه يزعجني حقا'],
#  ['She asked him why he was crying', 'سالته لماذا كان يبكي'],
#  ["I'm not in a position to accept it", 'انا لست في وضع يسمح بان اقبلها'],
#  ['She rides a motorcycle well', 'قيادتها للدراجة النارية جيدة'],
#  ["I didn't like it", 'لم احبه'],
#  ['What is this fish called in English?', 'ما اسم تلك السمكة بالانجليزية؟'],
#  ['There has to be a way', 'لا بد من وجود طريقة ما'],
#  ["I'm not trying to deprive you of your rights", 'انا لا احاول سلب حقوقك'],
#  ["He couldn't possibly succeed", 'لم يكن هناك احتمال لنجاحه'],
#  ['This is an automatic door', 'هذا الباب اوتوماتيكي'],
#  ['This is a government project', 'هذا مشروع حكومي'],
#  ['Did it snow yesterday?', 'هل اثلجت البارحة؟'],
#  ['This book is yours', 'هذا الكتاب لك'],
#  ['I can swim', 'يمكنني السباحة'],
#  ['I know your father', 'اعرف اباك'],
#  ['Tom tried to avoid looking at Mary', 'حاول توم ان يتجنب النظر الى ماري'],
#  ['He seems to have been rich', 'يبدو انه كان غنيا'],
#  ['Tom died', 'توفي توم'],
#  ['May I borrow this book?', 'ايمكنني استعارة هذا الكتاب؟'],
#  ['Are you a teacher or a student?', 'امدرس انت ام طالب؟'],
#  ["I don't have a solution", 'لا حل لدي'],
#  ['Take a rest', 'استرح'],
#  ['Do you remember what you did last Friday?',
#   'اتذكر ما فعلت الجمعة الماضية؟'],
#  ["It's easier to have fun than to work", 'الاستمتاع اسهل من العمل'],
#  ['Who are you talking about?', 'عن من تتحدث؟'],
#  ['I have been working since six this morning', 'اعمل منذ السادسة صباحا'],
#  ['The drug smuggler was arrested at the airport',
#   'القي القبض على مهرب المخدرات في المطار'],
#  ['She screamed for help', 'صرخت طالبة المساعدة'],
#  ['What makes you so sure Tom was the one who stole your bicycle?',
#   'ما الذي يجعلك متيقنا بان توم هو الذي سرق دراجتك؟'],
#  ['Go brush your teeth', 'اذهبي واغسلي اسنانك'],
#  ['All you have to do is try your best', 'كل ما عليك فعله هو بذل جهدك'],
#  ['Call me again in two days', 'اتصل بي مرة اخرى خلال يومين'],
#  ['I stood at the end of the line', 'وقفت في اخر الصف'],
#  ['Is this radio yours?', 'هل هذا الراديو لك؟'],
#  ['Why not?', 'لم لا؟'],
#  ['I like the dog', 'احب ذلك الكلب'],
#  ["There isn't any hope", 'لا يوجد اي امل'],
#  ['I have a lot of dreams', 'احلم كثيرا'],
#  ["It's a very slow process", 'انها عملية بطيئة جدا'],
#  ['You should plan to come with us the next time we go camping',
#   'يجب عليك ان تخطط للقدوم معنا المرة المقبلة التي نذهب فيها للتخييم'],
#  ["He won't come will he?", 'لن ياتي اليس كذلك؟'],
#  ["In Canada you're not allowed to drink until you are 20",
#   'في كندا لا يمكنك شرب الكحول حتى تبلغ سن العشرين'],
#  ['Tom saved her from the fire', 'انقذها توم من الحريق'],
#  ['What do you want now?', 'ما الذي تريده الان؟'],
#  ['They hate you', 'انهم يكرهونك'],
#  ['I want to be alone!', 'اريد ان اكون وحيدا!'],
#  ['My scarf is blue', 'وشاحي ازرق'],
#  ['Tom thinks the same way', 'يفكر توم بنفس الطريقة'],
#  ['She is getting prettier and prettier', 'تزداد جمالا يوما بعد يوم'],
#  ["We're eating apples", 'نحن ناكل التفاح'],
#  ['They might hear us', 'قد يسمعانا'],
#  ['Chew your food well', 'امضغ طعامك جيدا'],
#  ['I was supposed to tell Tom where to go',
#   'كان من المفترض ان اخبر توم اين عليه الذهاب'],
#  ["I heard a crash at about ten o'clock last night",
#   'سمعت صوت اصطدام حوالي العاشرة ليلة الامس'],
#  ["It's never too late to start", 'ليس متاخرا جدا للبدء'],
#  ['Stay at home', 'ابق في البيت'],
#  ['When I saw his new hairstyle I tried hard to suppress my laughter',
#   'عندما رايت قصة شعره حاولت بان اخفي ضحكتي'],
#  ['Tom swam across the river', 'قطع توم النهر سباحة'],
#  ["He wouldn't allow me to drive his car", 'لم يسمح لي ان اقود سيارته اطلاقا'],
#  ['I need medical help', 'احتاج مساعدة طبية'],
#  ['What do you mean?', 'ماذا تعني؟'],
#  ['He tried to get me to help him', 'حاولت ان اجعله يساعدني'],
#  ['As soon as we sat down she brought us coffee',
#   'ما ان جلسنا حتى جاءت لنا بالقهوة'],
#  ['Tom gave me an apple', 'اعطاني توم تفاحة'],
#  ['Tom is absent', 'توم غائب'],
#  ['I listen to the radio every night', 'استمع الى الراديو كل ليلة'],
#  ["I have a feeling I've met her somewhere before",
#   'يراودني احساس باني قابلتها في مكان ما سابقا'],
#  ["Let's play tennis after school", 'لنلعب التنس بعد انتهاء الدراسة'],
#  ['How about you?', 'ماذا عنك؟'],
#  ["We're not afraid", 'لسنا خائفين'],
#  ['I met an old man near the station', 'قابلت رجلا عجوزا قرب المحطة'],
#  ["I can't tell her now It's not that simple anymore",
#   'لا استطيع ان اخبرها لم يعد الامر بسيطا'],
#  ['I saw him enter the room', 'رايته يدخل الغرفة'],
#  ['The girl screamed when she saw the flames',
#   'صرخت الفتاة حين رات السنة اللهب'],
#  ["Let's share the expenses", 'دعونا نتقاسم المصاريف'],
#  ['It is an endangered species', 'انه نوع مهدد بالانقراض'],
#  ['The store was not a big one was it?', 'لم يكن المخزن كبيرا اليس كذلك؟'],
#  ["I don't consider Tom a friend", 'لا اعتبر توم صديقا لي'],
#  ['Here they come', 'ها قد اتوا'],
#  ['The war finally broke out', 'اندلعت الحرب اخيرا'],
#  ['She began crying', 'اخذت تبكي'],
#  ['Can you count in Italian?', 'هل تستطيع ان تعد بالايطالية؟'],
#  ['What do you do in your free time?', 'ما الذي تفعله بوقت فراغك؟'],
#  ['Bring it back to me', 'اعيده الي'],
#  ['I have a cough', 'لدي كحة'],
#  ['Never in my life have I heard such a thing', 'لم اسمع في حياتي بهذا البتة'],
#  ['Are you alone?', 'هل انت وحدك؟'],
#  ['Go to church with your parents and pray for her',
#   'اذهب الى الكنيسة مع والديك وصل لها'],
#  ['He yelled with pain', 'صرخ الما'],
#  ["We're obedient", 'نحن مطيعون'],
#  ["I don't blame them", 'انا لا الومهم'],
#  ["Tomorrow I'll buy what I need", 'سابتاع غدا ما احتاج'],
#  ['He works in the car industry', 'انه يعمل في قطاع صناعة السيارات'],
#  ['He drank a little', 'شرب القليل'],
#  ['We were in a hurry', 'كنا علی عجلة من امرنا'],
#  ['He sells cars', 'انه يبيع السيارات'],
#  ["It's not polite to speak with your mouth full",
#   'ليس من الادب ان تتكلم و فمك ممتلئ'],
#  ['Did you pay for the book?', 'هل دفعت ثمن الكتاب؟'],
#  ["I don't know if we're going to be able to do that",
#   'لا ادري ان كان بامكاننا فعل ذلك'],
#  ['I intend to clean my room', 'انوي ان انظف غرفتي'],
#  ['Tom was not impressed', 'توم لم يكن متاثر'],
#  ['Stop hitting your brother', 'توقف عن ضرب اخوك'],
#  ['There is nothing to be scared of', 'لا يوجد اي شيء مدعاة للخوف'],
#  ['As soon as she heard the bell ring she answered the telephone',
#   'ما ان سمعت الجرس حتى ردت على الهاتف'],
#  ["I don't think that's correct", 'اشك في صحة ذلك'],
#  ["I can't find my pen", 'لا يمكنني ايجاد قلمي'],
#  ['He heard a shout', 'سمع صراخا'],
#  ['Does anyone speak English?', 'هل يتحدث احد الانجليزية؟'],
#  ["I've already given Tom his birthday present",
#   'سبق ان اعطيت توم هدية عيد ميلاده'],
#  ["Let's get out of here before Tom sees us",
#   'دعنا نخرج من هنا قبل ان يرانا توم'],
#  ['A woman without a man is nothing', 'المراة بلا رجل لا شيء'],
#  ['The bridge was built by the Romans', 'شيد الجسر على يد الروم'],
#  ["She didn't like him", 'لم تكن تحبه'],
#  ['How are you?', 'كيف حالك؟'],
#  ['I miss you', 'افتقدتك'],
#  ['The others will arrive in a few minutes',
#   'سيصل الاخرون في غضون دقائق قليلة'],
#  ['This book was easy', 'كان ذاك الكتاب سهلا'],
#  ['They lost their trust in Tom', 'لقد فقدوا ثقتهم في توم'],
#  ['This afternoon we will have an interview',
#   'بعد ظهر هذا اليوم سيكون لدينا مقابلة'],
#  ["I'm sure you're right", 'انا متاكدة انك محق'],
#  ['Do you love each other that much?', 'هل تحبان بعضكما بعضا الى ذلك الحد؟'],
#  ['Who owns this villa?', 'من يملك هذه الفلا؟'],
#  ['Do you still need tea?', 'هل مازلت تريد شايا؟'],
#  ["I'm so happy", 'انا سعيد جدا'],
#  ['You should go', 'من الافضل ان تذهب'],
#  ['My sister lives near Yokohama', 'اختي تسكن بالقرب من يوكوهاما'],
#  ['He is getting better day by day', 'انه يتحسن يوما بعد يوم'],
#  ['My uncle lives in an apartment', 'يسكن عمي في شقة'],
#  ["Don't forget about us!", 'لا تنسنا'],
#  ['What do you want then?', 'ماذا تريد بعد ذلك؟'],
#  ['Be creative', 'كن مبدعا'],
#  ['I have many friends', 'لدي الكثير من الاصدقاء'],
#  ['I have a stomachache', 'لدي مغص'],
#  ['Tom wants to go to Australia', 'يريد توم الذهاب الى استراليا'],
#  ['His large income makes it possible for him to travel overseas every year',
#   'دخله الكبير يمكنه من السفر كل سنة الى الخارج'],
#  ['Can I borrow your umbrella?', 'هل لي ان استعير مظلتك؟'],
#  ['Tom asked Mary if she would help him', 'سال توم ماري ان كانت ستساعده'],
#  ["I suppose you're hungry", 'اعتقد انك جوعان'],
#  ['I have to find it', 'علي ان اجدها'],
#  ['What does the word "get" mean in this sentence?',
#   'ما الذي تعنيه كلمة "get" في هذه الجملة؟'],
#  ['You can go home now', 'بامكانك العودة الى المنزل الان'],
#  ['Why is he angry about something like that?',
#   'لماذا هو غاضب بسبب شيء مثل ذلك؟'],
#  ["I'd be unhappy but I wouldn't kill myself",
#   'لن اكون سعيدا لكن لن اقتل نفسي'],
#  ['I am from Columbia', 'انا من كولومبيا'],
#  ['I chose to look the other way', 'فضلت ان انظر الى الجهة الاخرى'],
#  ['What year were you born?', 'في اي عام ولدت؟'],
#  ['I wish I could go to Japan', 'اتمنى الذهاب الى اليابان'],
#  ['He likes coffee without sugar', 'انه يحب القهوة من دون سكر'],
#  ["I'm going to teach you how to fish next Sunday",
#   'سوف اعلمك كيفية صيد السمك الاحد المقبل'],
#  ['Do you have a receipt?', 'هل عندك الفاتورة؟'],
#  ['I will sue you', 'ساقاضيك'],
#  ['Bees make honey', 'يصنع النحل العسل'],
#  ["Don't call him names", 'لا تسبه'],
#  ['What do you grow on your farm?', 'ماذا تزرع في مزرعتك؟'],
#  ["You'll never be alone", 'لن تصير وحيدا ابدا '],
#  ['Even children can understand it', 'حتى الاطفال يمكنهم فهم ذلك'],
#  ['Forgive me for being late', 'اعذرني على التاخير'],
#  ['Smile at the camera please!', 'ابتسم للكاميرا اذا سمحت!'],
#  ['The shop was busy', 'كان المتجر مكتظا'],
#  ['She loves Tom', 'انها تحب توم'],
#  ['Do you speak Albanian?', 'هل تتحدث الالبانية؟'],
#  ['Do you have one?', 'هل لديك واحدة؟'],
#  ['Why are you alone?', 'لم انت وحدك؟'],
#  ['Tom spends about an hour a day studying French',
#   'ينفق توم ساعة يوميا في تعلم الفرنسية'],
#  ['She is angry with me', 'انها غاضبة معي'],
#  ['My mother made me a cute skirt', 'صنعت لي امي تنورة جميلة'],
#  ["I don't care", 'لا اهتم'],
#  ['She has a son everybody loves', 'لديها ابن يحبه الجميع'],
#  ['Tom got here before sunrise', 'توم جاء الى هنا قبل الغروب'],
#  ['I doubt if he is a lawyer', 'انا اشك في انه محام'],
#  ['We should keep this information under wraps for the time being',
#   'علينا ابقاء هذه المعلومات في طي الكتمان في الوقت الحاضر'],
#  ["That's common sense", 'ذاك من البديهيات'],
#  ['When is school over?', 'متى ينتهي الدوام المدرسي؟'],
#  ['Can you pause the video for a moment?', 'هلا اوقفت الفيديو للحظة؟'],
#  ["It's recommended that you don't write your passwords down where others might see them",
#   'من الافضل الا تكتب كلمات المرور كي لا يراها الغير'],
#  ['The rear gate was open', 'كانت البوابة الخلفية مفتوحة '],
#  ["I'm sure I'll be fine", 'انا متاكد اني ساكون بخير'],
#  ["Why don't you come visit us?", 'لم لا تزرنا؟'],
#  ["It's my job", 'هذا واجبي'],
#  ["I'm old enough to make my own decisions",
#   'انا نضج كفاية لاتخذ قراراتي الخاصة'],
#  ["I'd like to study in Paris", 'اود الدراسة في باريس'],
#  ["We'll have to postpone the meeting", 'علينا تاجيل الاجتماع'],
#  ['I arrived in Tokyo yesterday', 'وصلت الى طوكيو البارحة'],
#  ['He reads a good deal', 'هو قارئ نهم'],
#  ['He has three sons', 'لديه ثلاثة ابناء'],
#  ['Tom noticed a police car in the rearview mirror',
#   'لاحظ توم سيارة الشرطة في مراة الرؤية الخلفية'],
#  ['Do you own a computer?', 'هل لديك حاسب الي؟'],
#  ['Tom likes brunettes', 'توم تعجبه السمراوات'],
#  ['You should read such books as will benefit you',
#   'ينبغي ان تقرا كتبا مشابهة اذ انها نافعة لك'],
#  ['We must finish everything before Tuesday morning',
#   'يجب علينا انهاء كل شيء قبل صباح الثلاثاء'],
#  ['That guy who was just here gave me this for you',
#   'الشاب الذي كان هنا اعطاني هذه لك'],
#  ['I told you the truth when I told you I loved you',
#   'اخبرتك بالحقيقة عندما بحت بحبي لك'],
#  ['Why did you turn down his offer?', 'لماذا رفضت عرضه؟'],
#  ['I just arrived now', 'وصلت للتو'],
#  ["I haven't eaten since breakfast and I'm very hungry",
#   'لم اكل مذ افطرت وانا جائع جدا'],
#  ['Are you through with the phone?', 'هل انتهيت من استعمال الهاتف؟'],
#  ['I have nothing to do with the matter', 'ليس لدي اي شان في هذا الامر'],
#  ['He rewrote the story into a completely different one',
#   'اعاد كتابة القصة فاحالها قصة مختلفة تماما'],
#  ['The tank has a capacity of fiftygallons', 'سعة الخزان خمسون جالونا'],
#  ["Come on! We'll be late", 'هيا بنا! سنتاخر'],
#  ['I never for a moment imagined that I would win',
#   'لم اكن اتخيل للحظة انني سوف افوز'],
#  ['I think this table takes up too much space',
#   'اعتقد ان هذه الطاولة تاخذ مساحة كبيرة'],
#  ['Tom gave the police a false address', 'اعطى توم الشرطة عنوانا خاطئا'],
#  ['Could you repeat that please?', 'ايمكنك ان تكرر ما قلته من فضلك؟'],
#  ['He looks like his father', 'يشبه اباه'],
#  ['Add a little milk', 'اضف القليل من الحليب'],
#  ['Who said that?', 'من قال هذا؟'],
#  ['I came here yesterday', 'كنت هنا البارحة'],
#  ["Tom wanted to explain but Mary wouldn't let him",
#   'اراد توم التوضيح ولكن ماري لم تدعه'],
#  ['There are many shrines in Kyoto', 'يوجد الكثير من المعابد في كيوتو'],
#  ['You may come if you like', 'ان احببت فتعال!'],
#  ['Nobody answered the telephone', 'لم يرد احد على الهاتف'],
#  ["Let's not watch TV", 'دعنا لا نشاهد التلفاز'],
#  ["Let's play something", 'هيا لنلعب'],
#  ["I'm just having some fun", 'انا اتسلى قليلا فقط'],
#  ["That's none of your business", 'ليس ذلك من شانك'],
#  ['I wrote three letters last night', 'كتبت ثلاث رسائل ليلة البارحة'],
#  ['Please introduce me to Tom', 'رجاء عرفني على توم'],
#  ["Don't tell anyone", 'لا تخبر احدا'],
#  ["I can't do it", 'لا استطيع ان افعل ذلك'],
#  ["It's too good to be true", 'انه افضل من ان يكون صحيحا'],
#  ['She should listen more to other people',
#   'ينبغي لها ان تستمع الى اراء الاخرين اكثر'],
#  ['I want to marry a girl like her', 'اريد ان اتزوج فتاة مثلها'],
#  ["I do hope you'll come again", 'اتمنى ان تاتي مرة اخرى'],
#  ['They are still children', 'ما زالوا صغارا'],
#  ['I got on the wrong bus', 'ركبت الباص الخطا'],
#  ['I saw you driving your new car', 'رايتك راكبا سيارتك الجديدة'],
#  ['You should not sleep', 'يجب ان لا تنام'],
#  ['How embarrassing!', 'يا للاحراج!'],
#  ['His bicycle is blue', 'دراجته زرقاء'],
#  ['This school has no heating', 'هذه المدرسة ليس لديها نظام تدفئة'],
#  ['Please correct me when I make a mistake', 'من فضلك صحح لي عندما اخطيء'],
#  ["When I woke us this morning I didn't want to get out of bed",
#   'عندما استيقظت هذا الصباح لم ارد القيام عن السرير'],
#  ['I bought a new computer last month', 'اشتريت حاسوبا جديدا الشهر الماضي'],
#  ["Sorry I didn't reply sooner", 'عذرا لعدم الرد ابكر'],
#  ['Please close the door quietly', 'من فضلك اقفل الباب بهدوء'],
#  ["I didn't mean to hurt you", 'لم اقصد ان اؤذيك'],
#  ["You'd better hurry up if you want to get home before dark",
#   'من الافضل لك ان تسرع اذا اردت ان تصل الى المنزل قبل حلول الليل'],
#  ['Continue digging', 'واصل الحفر'],
#  ["It's been stolen", 'لقد تم سرقتها'],
#  ['We should go to sleep', 'علينا الخلود الى النوم'],
#  ["I'm not your girlfriend", 'انا لست صدبقتك'],
#  ['We love each other', 'نحن نحب بعضنا البعض'],
#  ['I would like to speak to the head nurse', 'اود التحدث الى رئيسة الممرضات'],
#  ['Do you love each other very much?', 'هل تحبان بعضكما البعض بشدة؟'],
#  ["That's what I loved about Tom", 'هذا ما احببته بشان "توم"'],
#  ['Tom looked like he was rich', 'بدا توم وكانه ثري'],
#  ["Everything's going to be great as soon as Tom gets here",
#   'كل شيء سيكون على ما يرام حالما يصل توم'],
#  ["I'll drive you home", 'ساوصلك الى البيت'],
#  ["He's so young", 'انه شاب جدا'],
#  ['You can go home after you have finished this work',
#   'يمكنك الذهاب للبيت بعد انتهائك من هذا العمل'],
#  ["That doesn't even make sense", 'ليس ذلك منطقيا بتاتا'],
#  ["We'll talk about it tomorrow", 'سنتحدث حول ذلك غدا'],
#  ['I told you this was going to be boring', 'قلت لك ان ذلك سيكون مملا'],
#  ['Where do you think we should stay?', 'اين تظن ان علينا ان نبقى؟'],
#  ['Please be serious', 'كوني جادة ارجوك'],
#  ['I work for an oil company', 'اعمل لصالح شركة نفط'],
#  ['Tom thought he had all the time in the world',
#   'يعتقد توم انه كان في كل وقت في العالم'],
#  ["I didn't expect you to be here", 'لم اتوقع ان تكون هنا '],
#  ['What are you punishing them for?', 'ما الذي تعاقبهم عليه؟'],
#  ['She chose the red dress', 'اختارت الفستان الاحمر'],
#  ["It's your turn", 'انه دورك'],
#  ['I want to go to Australia one more time before my passport expires',
#   'اريد الذهاب لاستراليا لمرة اخرى قبل ان تنتهي صلاحية جواز سفري'],
#  ['He caught a large trout', 'التقط سمكة سلمون مرقط كبيرة'],
#  ['The birds flew away in all directions', 'حلقت الطيور في كل اتجاه'],
#  ['Check that', 'افحص ذلك'],
#  ['Are you busy tomorrow morning?', 'هل انت مشغول صباح الغد ؟'],
#  ['Beauty is but skin deep', 'الجمال جمال النفس'],
#  ['The Jacksons lived in Boston before they moved here',
#   'كان الجاكسونيون يعيشون في بوسطن قبل الانتقال الى هنا'],
#  ['Will you sell your house to him?', 'هل ستبيع منزلك له؟'],
#  ['Do you know how to open this box?', 'هل تعرف كيف تفتح هذا الصندوق؟'],
#  ["That's what makes me happy", 'هذا ما يشعرني بالسعادة'],
#  ['Drivers should be aware of the traffic rules',
#   'على السائقين ان ينتبهوا لقواعد المرور'],
#  ['How do you know that belongs to Tom?', 'كيف تعلم بملكية توم لهذا؟'],
#  ["Don't waste your time", 'لا تضع وقتك سدی'],
#  ['This makes no sense to me', 'هذا لا يبدو لي منطقيا'],
#  ['It was very hot this afternoon', 'كان الجو حارا جدا ظهيرة اليوم'],
#  ['Please sit down', 'من فضلك اجلس'],
#  ["That wouldn't surprise me", 'لن يفاجئني ذلك'],
#  ["I don't want a fulltime job", 'لا اريد وظيفة بدوام كامل'],
#  ['She does nothing but complain', 'كل ما تفعله هو التذمر'],
#  ["He's my older brother", 'انه اخي الاكبر'],
#  ['This is a dog', 'هذا كلب'],
#  ['He will come soon', 'سياتي قريبا'],
#  ["Hopefully Tom won't be as crazy as the rest of his family when he grows up",
#   'لنامل الا يكون توم بجنون عائلته عندما يكبر'],
#  ['Did you meet her?', 'هل قابلتها؟'],
#  ['She kept on working', 'بقيت تعمل'],
#  ['She has been dead for ten years', 'انها ميتة منذ عشر سنوات'],
#  ['We are men', 'اننا رجال'],
#  ["I don't worry so much about my resume",
#   'انا لست قلقا كثيرا بشان سيرتي الذاتية'],
#  ['I was reading a novel then', 'كنت اقرا رواية حينها'],
#  ['She says she will call you later', 'قالت بانها ستتصل بك لاحقا'],
#  ['When I got home I found I had lost my wallet',
#   'عندما عدت الى المنزل  اكتشفت اني اضعت محفظتي'],
#  ["They couldn't do anything but stand there and stare",
#   'لم يكن بامكانهم فعل شيء الا الوقوف والمشاهدة'],
#  ['I found the key that I was looking for', 'وجت المفتاح الذي كنت ابحث عنه'],
#  ["Tom's horse reared suddenly and threw him",
#   'شب حصان توم فجاة و القاه ارضا'],
#  ['You have a big nose', 'انت لديك انف كبير'],
#  ["Japan was one of the world's fastest growing economies in the 1980s",
#   'كان الاقتصاد الياباني واحدا من اسرع الاقتصادات نموا في عام 1980'],
#  ['We accept all major credit cards',
#   'نقبل الدفع باي نوع من بطاقات الائتمان المعروفة'],
#  ['My mother took my temperature', 'قاست امي حرارتي'],
#  ["Tom liked Mary's new hairstyle", 'احب توم تسريحة شعر ماري الجديدة'],
#  ['War broke out in 1939', 'اندلعت الحرب عام ١٩٣٩م'],
#  ['Why are you so tired today?', 'لم انت متعب اليوم؟'],
#  ["I'll leave the decision to you", 'ساترك القرار الاخير لك'],
#  ['Today is Wednesday', 'اليوم هو الاربعاء'],
#  ['Playing tennis is fun', 'لعب التنس امر ممتع'],
#  ['I treated her as my own daughter', 'عاملتها كانها بنتي'],
#  ["I'm sure Tom is planning to do that", 'متاكد بان توم يخطط لفعل ذلك'],
#  ['My aunt brought me some flowers', 'جلبت لي عمتي بعض الازهار'],
#  ['Go back to your seat', 'عد الى مقعدك'],
#  ['I like to eat watermelon', 'احب ان اكل البطيخ'],
#  ['How embarrassing!', 'كم هذا محرج!'],
#  ['We watched TV after lunch', 'شاهدنا التلفاز بعد الغداء'],
#  ['The old man starved to death', 'جاع الرجل العجوز حتى الموت'],
#  ["Let's just pretend like we don't know each other",
#   'دعنا فقط نتظاهر وكاننا لا نعرف بعضنا البعض'],
#  ['Welcome to Japan', 'اهلا و سهلا بك في اليايان'],
#  ['I smell something burning Mother', 'اشتم رائحة حريق يا امي'],
#  ["Didn't I tell you so?", 'الم اقل لك؟'],
#  ['You can rely on him', 'يمكنك الاعتماد عليه'],
#  ["I'm OK", 'انا بخير'],
#  ['One plus two equals three', 'واحد زائد اثنان يساوي ثلاثة'],
#  ['Will we be in time for the train?', 'هل سنلحق بالقطار؟'],
#  ['These are our desks', 'هذه مكاتبنا'],
#  ["I'm really tired", 'انا متعب جدا'],
#  ["My mother can't come", 'لن تسطيع امي القدوم'],
#  ['It tastes really good', 'انها لذيذة'],
#  ['What time does your watch say it is now?',
#   'ما الوقت الذي تشير اليه ساعتك الان؟'],
#  ['What do you want to talk about?', 'ما الذي تريد ان تتحدث عنه؟'],
#  ["If he doesn't come what'll you do?", 'ماذا ستصنع لو لم يات؟'],
#  ['Excuse me who is this woman?', 'المعذرة من هذه المراة؟'],
#  ['Take what you need', 'خذ ما تحتاجه'],
#  ['Tom easily convinced Mary that he was innocent',
#   'توم اقنع بسهولة ماري انه كان بريئا'],
#  ['I am thirsty', 'انا اشعر بالعطش'],
#  ['Wait I want to tell you something', 'انتظر اريد اخبارك بامر ما'],
#  ['I gave her all the money I had', 'اعطيتها كل المال الذي املكه'],
#  ['The opera starts at seven', 'تبدا الاوبرا في الساعة السابعة'],
#  ["It's fine today", 'طقس اليوم جميل'],
#  ["I'm not surprised", 'انا غير متفاجئة'],
#  ['He is afraid of his own shadow', 'انه يخاف من خياله'],
#  ['Place it wherever you like', 'ضعها اينما تريد'],
#  ['Are you by yourself or with someone?', 'هل انت وحدك او مع احد؟'],
#  ['She spent the weekend by herself', 'امضت نهاية الاسبوع كلها لوحدها'],
#  ['I wish to be a doctor', 'اتمنى ان اكون طبيبا'],
#  ['Tell me what you want me to do', 'وضح لي ما تريدني ان افعل'],
#  ['My father does not eat much fruit', 'لا يكثر ابي من اكل الفاكهة'],
#  ['Why is Tom even here?', 'مالداعي لوجود توم هنا اصلا؟'],
#  ['I will lend you money just this once', 'ساقرضك مال هذه المرة فقط'],
#  ['Which book is better?', 'اي كتاب افضل؟'],
#  ['When does it begin?', 'متى تبدا؟'],
#  ['English is studied in China too', 'تدرس الانجليزية في الصين ايضا'],
#  ['Come again', 'تعال مجددا'],
#  ['Please have someone else do it', 'اجعل احدا اخر يقوم بذلك اذا سمحت'],
#  ['You can go if you want', 'امكانك الذهاب اذا اردت'],
#  ['You might at least say "thank you"', 'على الاقل قل شكرا'],
#  ['Do you see the raccoon?', 'هل ترى الراكون؟'],
#  ['Who do you think you are?', 'من تظن نفسك؟'],
#  ['You have to change trains at the next stop',
#   'عليك ان تركب قطارا اخر عند المحطة القادمة'],
#  ['You can call me Tom', 'انت يمكنك ان تناديني توم'],
#  ['You should begin right away', 'عليك ان تبدا حالا'],
#  ['A wood floor is beautiful', 'ان الارضية الخشبية جميلة'],
#  ['The word downtown refers to the business quarter of any town',
#   'ان كلمة مركز المدينة تشير الى الجزء التجاري من اي مدينة'],
#  ['How many people did you see in the park?', 'كم شخصا رايت في المنتزه؟'],
#  ["We're in mourning", 'نحن في حداد'],
#  ['The hospital opened last month', 'افتتحت المستشفى الشهر الماضي'],
#  ['What did you do yesterday evening?', 'ماذا فعلت ليلة الامس؟'],
#  ['He read the letter over and over', 'قرا الرسالة مرة بعد مرة'],
#  ["I can't bear the noise any longer", 'لا يمكنني احتمال الضجيج اكثر من ذلك'],
#  ['I admit that I was careless', 'اعترف بانني كنت مهملا'],
#  ['Tom promised to be here at 230', 'وعدني توم بانه سيكون هنا عند 230'],
#  ['I have no words to express my gratitude',
#   'الكلمات لا يمكنها ان تعبر عن شكري لك'],
#  ['Are you talking to me?', 'هل تتكلم معي؟'],
#  ["I'll take the yellow one", 'ساخذ الاصفر'],
#  ['Bring it here', 'احضره الى هنا'],
#  ['Please make the bed', 'من فضلك رتب السرير'],
#  ['He left the door open', 'ترك الباب مفتوحا'],
#  ['I was hungry', 'كنت جائعا'],
#  ['Tell me what I can do to help', 'اخبرني ما الذي يمكنني فعله لمساعدتك'],
#  ["I don't know because I wasn't there", 'لا اعرف لاني لم اكن هناك'],
#  ["I'm looking forward to your Halloween party",
#   'انا اتتطلع لحفلة عيد القديسيين خاصتك'],
#  ['School begins at eightthirty', 'تبدا المدرسة الساعة الثامنة و النصف'],
#  ["You can't run my life", 'لا يمكنك التحكم في حياتي'],
#  ['I am 19 years old', 'عمري تسعة عشر عاما'],
#  ["I've never seen anything like that", 'انا لم ار شيئا مثل هذا'],
#  ["Let's flip a coin", 'دعونا نعكس العملة'],
#  ['Do you have anything to say regarding this?',
#   'هل لديك ما تقوله بخصوص هذا الامر؟'],
#  ['Many students took part in the contest', 'شارك كثير من الطلاب في المسابقة'],
#  ['Where is Paris?', 'اين تقع باريس؟'],
#  ['Now we know what happened', 'عرفنا الان ما حدث'],
#  ['I understood the reason for this', 'فهمت سبب هذا'],
#  ["Her answer couldn't be understood", 'جوابها لم يكن مفهوما'],
#  ["Don't give up yet I'm sure you can do it",
#   'لا تستسلم انا متاكدمتاكدة انك تستطيعتستطيعين فعل ذلك'],
#  ['Tom gave me some books', 'اعطاني توم بعض الكتب'],
#  ['Can I borrow your car?', 'هل لي ان استعير سيارتك؟'],
#  ['We have to do this every day', 'واجب علينا فعل ذلك يوميا'],
#  ['Who says that?', 'من يقول هذا؟'],
#  ['This is a pen', 'هذا قلم'],
#  ['Better late than never', 'ان تاتي متاخرا خير من الا تاتي'],
#  ['I must have my watch repaired', 'علي ان اخذ ساعتي لتصلح'],
#  ['I am from Ecuador', 'انا من الاكوادور'],
#  ['He measured the length of the bed', 'قاس طول السرير'],
#  ['The rain continued all day', 'استمر المطر بالهطول طوال اليوم'],
#  ["I've been busy", 'كنت مشغولا'],
#  ['Please let me take your picture', 'دعني اخذ صورة لك اذا سمحت'],
#  ["He's in a bad state", 'هو في حالة سيئة'],
#  ["You'll learn how to do it sooner or later",
#   'ستتعلم كيف تفعلها عاجلا او اجلا'],
#  ['You bought the food so if I buy the wine that will even things up',
#   'اشتريت الطعام فان اشتريت انا الخمرة فسنكون متعادلين'],
#  ['Rabbits have long ears', 'للارانب اذان طويلة'],
#  ['He attended the meeting as the company representative',
#   'لقد حضر الاجتماع كممثل للشركة'],
#  ['May I use your telephone?', 'هل لي ان استخدم هاتفك؟'],
#  ['We can do nothing about it', 'لا يمكننا فعل اي شيء حيال ذلك'],
#  ['Does the story have a happy ending?', 'اللقصة نهاية سعيدة؟'],
#  ['I was at a movie theater', 'كنت في دور عرض للسينما'],
#  ['Tom served two terms in Congress', 'خدم توم فترتين في الكونغرس'],
#  ['Who am I?', 'من انا؟'],
#  ['May I eat this cake?', 'هل لي ان اكل هذه الكعكة؟'],
#  ["Tom doesn't actually live within Boston city limits",
#   'توم حقيقة لا يعيش داخل حدود مدينة بوسطن'],
#  ['Why do you want to study abroad?', 'لماذا تريد الدراسة في الخارج؟'],
#  ['She sang better than him', 'غنت افضل منه'],
#  ["What's for dinner?", 'ماذا للعشاء؟'],
#  ['Please help me fill out this form', 'الرجاء مساعدتي في ملء هذا النموذج'],
#  ['When do you get up?', 'متى تستيقظ؟'],
#  ["I'll never forget you", 'لن انساك ابدا'],
#  ["Why don't you come visit us?", 'لم لا تات لزيارتنا؟'],
#  ['Can you find it?', 'ايمكنك ايجادها؟'],
#  ['I wanted red shoes', 'اريد حذاء احمرا'],
#  ['How are you?', 'كيف حالك؟'],
#  ['Eat your vegetables', 'كل خضراواتك'],
#  ["What's your real purpose?", 'ما هدفك الحقيقي؟'],
#  ["I don't watch TV very much", 'لا اشاهد التلفاز كثيرا'],
#  ['I guess you are right', 'اعتقد انك محق'],
#  ['My father and mother were sitting under a tree',
#   'كان ابي وامي جالسين تحت شجرة'],
#  ['Which came first the chicken or the egg?',
#   'ايهما جاء اولا الدجاجة ام البيضة؟'],
#  ["It's cold this morning", 'الجو بارد هذا الصباح'],
#  ["I'm looking forward to our ski trip", 'انا اتتطلع لرحلة التزلج خاصتنا'],
#  ['She ironed his shirts', 'كوت قمصانه'],
#  ['Who owns this house?', 'من مالك هذا البيت؟'],
#  ['It looks like we fell into a trap', 'يبدو اننا وقعنا في الفخ'],
#  ['The house is haunted', 'البيت مسكون بالاشباح'],
#  ['You only live once', 'انك تعيش مرة واحدة لا غير'],
#  ['You might not want to do that', 'انت قد لا تريد فعل ذلك'],
#  ["I think you're right", 'اظن انك محق'],
#  ['I bought him a clock', 'ابتعت له ساعة'],
#  ['I know he is watching me', 'اعلم انه يراقبني'],
#  ["I can't thank you enough", 'لا استطيع ان اشكرك كفاية'],
#  ['Look at those black clouds', 'انظر الى تلك الغيوم السوداء'],
#  ['She warmed herself by the fire', 'تدفات علي النار '],
#  ['You would do well to tell it to him in advance',
#   'سيكون حسنا منك ان تخبره مقدما'],
#  ['Do what Tom says', 'افعلى ما يقوله توم'],
#  ['Come back soon', 'عد قريبا'],
#  ['The popularity of a web site depends on its content',
#   'شعبية مواقع الانترنت تعتمد على محتوياتها'],
#  ['The female student that sat in front of the teacher is from Germany',
#   'الطالبة التي جلست امام المدرسة من المانيا'],
#  ["You're not fast enough", 'لست سريعا بما يكفي'],
#  ['Could you tell me how to get to the station?',
#   'هل يمكنك ان تخبرني كيف اصل الى المحطة؟'],
#  ["We're not dating", 'نحن لا نتواعد'],
#  ['My mother died when I was a kid', 'ماتت امي عندما كنت صغيرا'],
#  ['The maid made my bed', 'رتبت الخادمة سريري'],
#  ["It's getting warmer and warmer", 'حرارة الطقس تتزايد'],
#  ['He is too tired to study', 'لن يستطيع ان يدرس من شدة التعب'],
#  ['You must study hard', 'عليك ان تدرس جاهدا'],
#  ['Do you remember what day of the week Blue Sky Sports is closed?',
#   'في اي ايام الاسبوع يغلق بلو سكاي سبورت ابوابه؟'],
#  ['What is new?', 'ما الجديد؟'],
#  ["Don't put it on my desk", 'ليس على مكتبي'],
#  ['What are you up to tomorrow afternoon?', 'ماذا عندك بعد ظهر غد؟'],
#  ['Do you like apples?', 'هل تحب التفاح؟'],
#  ["That wasn't my intention", 'لم يكن ذلك قصدي'],
#  ['It is not easy to solve the problem', 'ليس من السهل حل المشكلة'],
#  ['No words can relieve her deep sorrow',
#   'الكلمات لا يسعها التخفيف عن حزنها العميق'],
#  ['Do you know what happened?', 'هل تعرف ما الذي حصل؟'],
#  ["I'm lefthanded", 'انا ايسر'],
#  ["That's not my wife", 'هذه ليست زوجتي'],
#  ["Mom Tom's hitting me!", 'امي توم يضربني'],
#  ['I had no choice but to stay in bed all day',
#   'لم يكن لدي خيار سوی الاستلقاء علی السرير طوال اليوم'],
#  ['Where is his clinic located?', 'اين تقع عيادته؟'],
#  ['When can I see you again?', 'متى يمكنني ان اراك مجددا؟'],
#  ['Please forgive me', 'سامحني من فضلك'],
#  ['You should quit smoking', 'عليك ان تقلع عن التدخين'],
#  ["It's my brother's", 'انها لاخي'],
#  ['I went to Osaka station', 'ذهبت الى محطة اوساكا'],
#  ['Look at those clouds', 'انظر الى تلك الغيوم'],
#  ['Tom is going to sell his house', 'سيبيع توم منزله'],
#  ['How could you not say something?', 'كيف يمكن ان لا تقول شيئا؟'],
#  ['I work every day except Sunday', 'اعمل كل يوم عدا يوم الاحد'],
#  ['My father goes to work by bike', 'يذهب ابي الى العمل بالدراجة'],
#  ['Which is your bag?', 'ايها حقيبتك؟'],
#  ['Do what Tom tells you to do and everything will be fine',
#   'افعلي ما يخبرك توم به لتفعليه وكل شئ سيكون بخير'],
#  ["Nobody's perfect", 'لا يوجد شخص معصوم'],
#  ["Complaining won't change anything", 'لن يغير التذمر شيئا'],
#  ['What time will you leave?', 'متى ستغادر؟'],
#  ['Did you do your homework by yourself?', 'هل حللت واجبك بنفسك؟'],
#  ['You can come with me', 'يمكنك المجيئ معي'],
#  ['Is this book yours?', 'هل ذاك الكتاب لك؟'],
#  ['I got up at sixthirty this morning',
#   'استيقظت الساعة السادسة و النصف هذا الصباح'],
#  ['That meat is chicken', 'ذلك اللحم لحم دجاج'],
#  ['I like dogs but my sister likes cats',
#   'انا احب الكلاب ولكن اختي تحب القطط'],
#  ['The purpose of our trip is to visit friends and see some tourist spots',
#   'الغرض من رحلتنا هو لزيارة الاصدقاء و رؤية بعض الاماكن السياحية '],
#  ["Tom's a bit freaked out", 'توم مذعور قليلا'],
#  ["He's a cat lover", 'انه من محبي القطط'],
#  ["It's on the eighth floor", 'انه في الطابق الثامن'],
#  ['Please wash your hands properly before eating',
#   'رجاء اغسل يديك جيدا قبل الاكل'],
#  ['Both Tom and Mary were absent today', 'كان كلا من توم وماري غائبان اليوم'],
#  ['Do you love music?', 'اتحب الموسيقى؟'],
#  ['Come on!', 'هيا'],
#  ['No problem at all!', 'لا مشكلة على الاطلاق!'],
#  ["Tom doesn't look convinced", 'لا يبدو على توم انه مقتنع'],
#  ["Don't be late for the meeting tomorrow", 'لا تتاخر عن اجتماع الغد'],
#  ['A cat came out from under the desk', 'خرجت قطة من تحت المكتب'],
#  ['When did you get back from your trip?', 'متى عدت من رحلتك؟'],
#  ["He's writing a long letter", 'انه يكتب رسالة طويلة'],
#  ['You must help your mother', 'عليك ان تساعد والدتك'],
#  ['Welcome home', 'مرحبا بك في المنزل'],
#  ['She thought that I was a doctor', 'ظنت اني طبيب'],
#  ['You must study hard', 'عليك ان تدرس بجد'],
#  ['We all make mistakes', 'كلنا نخطئ'],
#  ["What's your job?", 'ماذا تعمل؟'],
#  ['I came here yesterday', 'اتيت الى هنا البارحة'],
#  ["You shouldn't judge a person by his appearance",
#   'يجب عليك ان لا تحكمى على شخص من مظهره'],
#  ['Yesterday was my birthday', 'البارحة كانت ليلة عيد ميلادي'],
#  ["Let's meet again soon", 'لنلتقي مرة اخرى قريبا'],
#  ['I will be glad to help you anytime', 'سيسعدني ان اساعدك في اي وقت'],
#  ['I like sports', 'احب ممارسة الالعاب الرياضية'],
#  ['I hate politics', 'اكره السياسة'],
#  ['He told me not to drive too fast', 'اخبرني الا اقود بسرعة عالية'],
#  ['Prices have dropped recently', 'انخفضت الاسعار مؤخرا'],
#  ['You must join me', 'يجب عليك الانضمام لي'],
#  ['Do you think so?', 'اتعتقد ذلك؟'],
#  ['Has something happened?', 'هل حصل شيء ما؟'],
#  ['I can swim', 'بامكاني ان اسبح'],
#  ["Tom won't likely be able to cope with the situation",
#   'من غير المحتمل ان يكون توم قادرا على التعامل مع الوضع'],
#  ['Please come as soon as possible', 'من فضلك تعال باسرع ما يمكن'],
#  ["I've never met him", 'لم اقابله من قبل'],
#  ["They didn't know me", 'لم يعرفوني'],
#  ['Thank you for your kindness', 'شكرا لك على لطفك'],
#  ['Clearly you are mistaken', 'من الواضح انك مخطئ'],
#  ['Call me tomorrow', 'اتصل بي غدا'],
#  ['Did you miss me?', 'هل افتقدتني؟'],
#  ['It seems interesting to me', 'يبدو لي مثيرا للاهتمام'],
#  ['I like jazz', 'احب موسيقى الجاز'],
#  ["That's life", 'هكذا هي الحياة'],
#  ['I can jump', 'يمكنني القفز'],
#  ["You don't have to come tomorrow", 'ليس عليك ان تاتي غدا'],
#  ['My father bought this hat for me', 'اشترى لي ابي هذه القبعة'],
#  ['I have a lot of passwords to remember',
#   'لدي الكثير من كلمات السر لاتذكرها'],
#  ['I never played golf', 'لم العب الجولف بتاتا'],
#  ["I needed to make sure you'd come here", 'اردت ان اتاكد انك ستاتي الى هنا'],
#  ["I'm from Brazil", 'انا من البرازيل'],
#  ['Look it up in your dictionary', 'ابحث عنها في قاموسك'],
#  ['Is it windy?', 'هل الجو عاصف؟'],
#  ['What do you like?', 'ماذا تفضل؟'],
#  ['I can play tennis', 'بامكاني ان العب التنس'],
#  ['My uncle has completely recovered from his illness',
#   'تعافى عمي من مرضه كليا'],
#  ['Most Americans liked Roosevelt', 'احب اكثر الامريكيين روزفلت'],
#  ['That old woman lives by herself', 'تلك المراة العجوز تسكن لوحدها'],
#  ['Is there an elevator?', 'هل هناك مصعد؟'],
#  ['Tom finally stopped laughing', 'توقف توم عن الضحك اخيرا'],
#  ["It's too small", 'انها صغيرة جدا'],
#  ['She went down to the fifth floor', 'نزلت الى الطابق الخامس'],
#  ['He plays World of Warcraft', 'انه يلعب عالم من العلب'],
#  ['He told us an interesting story', 'حكى لنا قصة شيقة'],
#  ['No words can express her deep sorrow',
#   'الكلمات لا يسعها التعبير عن حزنها العميق'],
#  ['Are your hands clean?', 'هل يداك نظيفتان؟'],
#  ['Nobody cares about that', 'لا احد يهتم بهذا '],
#  ['The old man spoke to me in French', 'تحدث الي الرجل العجوز بالفرنسية'],
#  ['He is eating', 'انه ياكل'],
#  ["I have three cousins on my mother's side", 'لدي ثلاث اولاد خالة'],
#  ["I don't like her", 'انها لا تعجبني'],
#  ["Let's consider the worst that could happen",
#   'لنفكر باسوا ما يمكن ان يكون قد حصل'],
#  ['This is an extremely important point', 'هذه ملحوظة مهمة للغاية'],
#  ['I think he is angry', 'انا اعتقد انه غاضب'],
#  ['I saw him running', 'رايته يركض'],
#  ['Can you hear me?', 'ايمكنك ان تسمعني؟'],
#  ['She is learning how to drive a car', 'انها تتعلم قيادة السيارة'],
#  ['Is everything all right?', 'هل كل شيء على ما يرام؟'],
#  ['The shop is closed on Sunday', 'المحل مغلق يوم الاحد'],
#  ["I can't think of his name just now", 'لا استطيع تذكر اسمه الان'],
#  ['Do you wash your hands before meals?', 'هل تغسل يديك قبل الوجبات؟'],
#  ['There are some things that are difficult to translate',
#   'هناك بعض الاشياء التى من الصعب ترجمتها'],
#  ['Did something happen?', 'هل حصل شيء ما؟'],
#  ["Tom isn't a kid anymore", 'لم يعد توم طفلا بعد الان'],
#  ["It's cold", 'الجو بارد'],
#  ['I was hungry and thirsty', 'كنت جائعا و عطشا'],
#  ['I am curious', 'اود ان اعرف'],
#  ["It's none of your business", 'ليس ذلك من شانك'],
#  ['Do you like music?', 'اتحب الموسيقى؟'],
#  ['She can speak French fluently', 'بامكانها تحدث الفرنسية بطلاقة'],
#  ['The committee consists of four members', 'تتكون الهيئة من اربعة اعضاء'],
#  ['She screamed with terror', 'صرخت رعبا'],
#  ["Money isn't everything but if you have no money you can't do anything",
#   'المال ليس كل شيء لكن ان لم يكن عندك مال فانك لا تستطيع فعل شيء'],
#  ['Judging from the look of the sky it may rain this afternoon',
#   'يبدو من منظر السماء انها من الممكن ان تمطر اليوم بعد الظهر'],
#  ['Write your address here', 'اكتب عنوانك هنا'],
#  ["It's too hot", 'انه ساخن جدا'],
#  ['Would you play with me?', 'هل ستلعب معي؟'],
#  ["I'm not going to turn my back on Tom", 'لن ادير ظهري لتوم'],
#  ['She used to visit me regularly', 'كان من عادتها انها كانت تزورني باستمرار'],
#  ['I do not like science', 'لا احب مادة العلوم'],
#  ['Never mind!', 'لا عليك!'],
#  ['I live on the bottom floor', 'اعيش في الطابق الارضي'],
#  ['All of a sudden a dog began barking', 'فجاة بدا كلب بالنباح'],
#  ["You'll feel better if you take these pills",
#   'ستشعر بتحسن اذا تناولت هذه الحبوب'],
#  ["Let's make a trade", 'دعونا نصنع تجارة'],
#  ["Tell Tom that I'm busy", 'اخبر توم باني مشغول'],
#  ['My aunt was pleased with my success', 'فرحت عمتي بنجاحي'],
#  ['He combined two ideas into one', 'دمج فكرتين في فكرة'],
#  ["This isn't drinking water", 'هذه المياه غير صالحة للشرب'],
#  ['Be vigilant', 'توخى الحذر'],
#  ['Tom deserves a promotion', 'يستحق توم ترقية'],
#  ["Didn't it occur to you to shut the windows?",
#   'الم يخطر لك ان تغلق النوافذ؟'],
#  ["A boy like Tom doesn't deserve a girl like Mary",
#   'ولد مثل توم لا يستحق بنت مثل ماري'],
#  ['This bird cannot fly', 'هذا الطائر لا يمكنه الطيران'],
#  ['Earth is a beautiful planet', 'الارض كوكب جميل'],
#  ['I managed to get in', 'استطعت الدخول'],
#  ['I wanna go to Japan', 'اريد الذهاب الى اليابان'],
#  ['You disappointed me', 'خنت ظني فيك'],
#  ['I love California', 'احب كاليفورنيا'],
#  ['I work in a tourist agency', 'انا اعمل في وكالة سياحية '],
#  ['Is it a recent picture?', 'هل اخذت هذه الصورة حديثا؟'],
#  ['I walk to school', 'امشي الى المدرسة'],
#  ['Do you like it?', 'هل يعجبك ذلك؟'],
#  ['The child is afraid of the dark', 'الطفل خائف من الظلام'],
#  ['Tom likes playing chess', 'لم ينجحوا'],
#  ['You must fulfill your duty', 'عليك ان تقوم بواجبك'],
#  ["I wouldn't be calling if it weren't important",
#   'ما كنت لاتصل بك لولا ان الامر مهم '],
#  ['Let me try it', 'دعني اجربها'],
#  ['I have visited America', 'زرت امريكا'],
#  ['Get out of my room!', 'اخرج من غرفتي'],
#  ['I slapped his face', 'صفعت وجهه'],
#  ['She waited for hours and hours', 'انتظرت لساعات و ساعات'],
#  ["I'm just looking thank you", 'انا ابحث فقط شكرا لك'],
#  ['Hope is not a strategy', 'الامل ليس استراتيجية'],
#  ["I'm ready to leave now", 'انا مستعد للمغادرة الان'],
#  ['You look pale', 'تبدو شاحب الوجه'],
#  ['Who is that man?', 'من ذاك الرجل؟'],
#  ['Can we stay here?', 'هل يمكننا البقاء هنا؟'],
#  ['What do you suggest?', 'ماذا تقترح؟'],
#  ['He screamed for help', 'صرخ طالبا النجدة'],
#  ['What do you call this flower?', 'ماذا تسمى هذه الوردة؟'],
#  ['He is alone', 'انه وحده'],
#  ['He used his head', 'لقد استخدم راسه'],
#  ['What you did was wrong', 'ما فعلته انت كان خاطئا'],
#  ['My house is near the school', 'بيتي بالقرب من المدرسة'],
#  ['They have lost a lot', 'لقد خسروا الكثير'],
#  ['The lecture lasted for two hours', 'استمرت المحاضرة مدة ساعتين'],
#  ['How will he pay his debts?', 'كيف سيدفع ديونه؟'],
#  ["It's very big", 'انها كبيرة جدا'],
#  ['Do you know how to use a dictionary?', 'هل تعرف كيف تستخدم قاموسا؟'],
#  ["Don't talk like that", 'لا تتكلم هكذا'],
#  ['She has something in her hand', 'انها تمسك شيئا'],
#  ['Where have you been?', 'اين كنت؟'],
#  ['Yoga comes from India', 'جاءت اليوغا من الهند'],
#  ['This table is reserved', 'هذه الطاولة محجوزة'],
#  ['Do you have one a little bigger than these?',
#   'هل عندك واحد اكبر قليلا من هذه؟'],
#  ['Will he ever come back?', 'هل سيعود يوما ما؟'],
#  ["I thought you didn't believe in ghosts", 'ظننت انك لا تؤمن بوجود الاشباح'],
#  ['The man kept talking for an hour', 'استمر الرجل بالكلام لمدة ساعة'],
#  ['Can I use my credit card?', 'ايمكنني استخدام بطاقة ائتماني؟'],
#  ['We all had such a good time', 'قضينا وقتا ممتعا'],
#  ['By signing the contract I committed myself to working there for another five years',
#   'بتوقيعي للعقد عاهدت نفسي بالعمل هناك لخمس سنوات اخرى'],
#  ['Is there anything else you want to tell me?',
#   'هل يوجد اي شيء اخر تريد ان تخبرني به؟'],
#  ['Tom likes you', 'توم معجب بكي'],
#  ["There's nowhere to hide", 'ليس هناك مكان للاختباء'],
#  ['What was that noise?', 'ما تلك الضجة؟'],
#  ['Her father can afford to give her a big allowance every month',
#   'يستطيع ابوها اعطاءها مصروفا كبيرا كل شهر'],
#  ["I'm sorry", 'انا متاسف'],
#  ['Those three are his daughters', 'هؤلاء الثلاثة بناته'],
#  ['I tried to tell Tom', 'حاولت اخبار توم'],
#  ['Take care', 'اعتن بنفسك'],
#  ['Delivery of goods is done after a month of placing the order',
#   'تسليم البضاعة يتم بعد شهر من تسجيل الطلب'],
#  ['Where was the mistake?', 'اين كان الخطا؟'],
#  ["He's over thirty", 'هو تجاوز الثلاثين'],
#  ['You only have 24 hours left to decide', 'لديك فقط 24 ساعة اخرى لتقرر'],
#  ['What do you want to eat?', 'ماذا تريد ان تاكل؟'],
#  ['The plan backfired', 'انقلب السحر على الساحر'],
#  ['Your face is red', 'احمر وجهك'],
#  ['Tom had something important to say but Mary kept interrupting him',
#   'توم كان لديه شئ مهم لقوله ولكن ماري كانت تقاطعه باستمرار'],
#  ["You people go ahead We'll bring up the rear",
#   'ايها الناس امضوا قدما  نحن سوف نتبعكم '],
#  ['I came on foot', 'اتيت سيرا على الاقدام'],
#  ['I came on foot', 'جئت سيرا على الاقدام'],
#  ['They became professional soccer players', 'صاروا لاعبي كرة قدم محترفين'],
#  ['There is one apple on the desk', 'هناك تفاحة واحدة على المكتب'],
#  ['Save me some ice cream', 'اترك لي بعض المثلجات'],
#  ['He wants vengeance', 'انه يريد الانتقام'],
#  ['What are you looking at?', 'الام تنظر؟'],
#  ["Your hair's beautiful", 'شعرك جميل'],
#  ['Tell me about him', 'احك لي عنه '],
#  ['Stop pulling my hair!', 'توقف عن شد شعري'],
#  ['I love both cats and dogs', 'انا احب كلا من القطط والكلاب'],
#  ['She has a daughter who is a pianist', 'لديها ابنة تعزف على البيانو'],
#  ['She has been dead for ten years', 'مر على موتها عشر سنين'],
#  ['Do you hear any sound?', 'هل تسمع اي صوت؟'],
#  ['How lucky you are!', 'كم انت محظوظ!'],
#  ['Can I borrow your tennis racket today?', 'هل لي ان استعير مضربك اليوم؟'],
#  ["I'm your partner", 'انا شريكك'],
#  ['The question is where to buy the book',
#   'المشكلة هي اين يمكن ان يشترى الكتاب'],
#  ['The man you saw in my office yesterday is from Belgium',
#   'من قابلت في مكتبي بالامس بلجيكي'],
#  ["I'll take him", 'ساخذه معي'],
#  ["Let's go", 'هيا بنا نذهب'],
#  ['English is an international language', 'الانجليزية لغة عالمية'],
#  ['Close the door', 'اقفل الباب'],
#  ['What will become of Japan?', 'ماذا سيحصل لليابان؟'],
#  ['He gives her everything she asks for', 'اعطاها كل ما ابتغته '],
#  ["She can't play piano very well", 'لا يمكنها عزف البيانو بتلك المهارة'],
#  ['I prefer not to comment', 'افضل ان لا اعلق'],
#  ["You don't have to make an apology", 'ليس عليك الاعتذار'],
#  ["I've always trusted Tom", 'انا دائما اثق في توم'],
#  ['Mary plays the piano', 'ماري تعزف البيانو'],
#  ['I was laughed at by him', 'ضحك علي'],
#  ["It's a nice day", 'انه يوم جميل'],
#  ['Always tell the truth', 'قل الحقيقة دائما'],
#  ['What a relief!', 'يا لها من راحة'],
#  ['Some children were playing frisbee near the pond',
#   'بعض الاطفال كانو يلعبون لعبة الصحن الطائر قرب البركة '],
#  ['Is that even possible?', 'هل هذا ممكن؟'],
#  ['Pick up the pencil from the floor', 'ارفع القلم من على الارض'],
#  ['His daughter and my son are good friends', 'ابنته وابني صديقان جيدان'],
#  ['Mary worked as a babysitter when she was a teenager',
#   'عملت ماري مربية للاطفال عندما كانت مراهقة'],
#  ['Sorry for the interruption', 'المعذره على الازعاج'],
#  ['What are you concerned about?', 'ما الذي يقلقك؟'],
#  ['Bangkok is the capital of Thailand', 'بانكوك هي عاصمة تايلاند'],
#  ['You have a way with women', 'انك تعرف كيف تتعامل مع النساء'],
#  ['Stand back please', 'ارجع الى الوراء من فضلك'],
#  ['We are going downtown to eat pizza',
#   'نحن ذاهبون الى وسط المدينة لناكل البيتزا'],
#  ['I read a book while eating', 'قرات كتابا و انا اكل'],
#  ["Do whatever's required", 'افعل كل ما هو مطلوب'],
#  ['What a strong wind!', 'يا لها من زوبعة عاصفة!'],
#  ['What time is it now?', 'ما الساعة الان؟'],
#  ['Stay thin', 'ابقي نحيفة'],
#  ["As far as I know he's an excellent student", 'على حد علمي هو طالب ممتاز'],
#  ['Can you give me a lift to the station?', 'هل لك ان تقلني الى المحطة؟'],
#  ['I know your brother very well', 'اعرف اخاك جيدا'],
#  ['What are you talking about?', 'ما الذي تتحدث عنه؟'],
#  ['This is your book', 'ذاك كتابك'],
#  ['Come sit with us', 'تعال و اجلس معنا'],
#  ['I work for an oil company', 'اعمل لدى شركة نفط'],
#  ['I am from Russia', 'انا من روسيا'],
#  ['We succeeded!', 'نجحنا!'],
#  ['I went shopping', 'انا ذهبت للتسوق'],
#  ["I'm from Turkey", 'انا من تركيا'],
#  ['The competition is fierce', 'المنافسة قوية'],
#  ['Tom always did his best to help Mary',
#   'على الدوام قدم توم افضل ما يستطيع لمساعدة ماري'],
#  ['I looked around me', 'نظرت حولي'],
#  ['No one believes that anymore', 'لا احد يصدق ذلك بعد الان'],
#  ['Tell her not to get near the dog', 'قل لها الا تقرب الكلب'],
#  ['We may need some', 'قد نحتاج لبعضه'],
#  ["I've studied English for five years", 'درست الانجليزية لمدة خمس سنوات'],
#  ['Drop your weapons!', 'القوا اسلحتكم!'],
#  ['I am from Norway', 'انا نرويجي'],
#  ['Speak clearly', 'تكلم بوضوح'],
#  ['I am going to play tennis in the afternoon', 'سالعب التنس بعد الظهر'],
#  ["I don't know what to say", 'لا اعرف ماذا اقول'],
#  ...]
